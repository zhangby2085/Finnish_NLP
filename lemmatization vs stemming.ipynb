# %%
import pandas as pd
import json
import requests
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %config Completer.use_jedi = False
pd.options.display.max_columns = 40
pd.options.display.max_rows = 50

# %% [markdown]
# ## Lemmatization
#
# Load the lemmatized ESCO skill descriptions

# %%
df = pd.read_json('lemmatized_esco_data.json')
df.head()
# Out:
#                       preferredLabel              preferredLabelLemmatized  \
# 0            analysoida röntgenkuvia            [analysoida, röntgen#kuva]
# 1                      myydä kelloja                        [myydä, kello]
# 2  valvoa myynninjälkeisiä tilastoja  [valvoa, myynnin#jälkeinen, tilasto]
# 3     käyttää lakantuotantolaitteita       [käyttää, lakan#tuotanto#laite]
# 4           hoitaa kuivaustunneleita             [hoitaa, kuivaus#tunneli]
#
#    preferredLabelPOS            alternativeLabel  \
# 0       [VERB, NOUN]                          []
# 1       [VERB, NOUN]                          []
# 2  [VERB, ADJ, NOUN]  [seurata palautetilastoja]
# 3       [VERB, NOUN]                          []
# 4       [VERB, NOUN]                          []
#
#      alternativeLabelLemmatized alternativeLabelPOS  \
# 0                            []                  []
# 1                            []                  []
# 2  [[seurata, palaute#tilasto]]      [[VERB, NOUN]]
# 3                            []                  []
# 4                            []                  []
#
#                                          description  \
# 0  Analysoida röntgenkuvia potilaiden ongelmien s...
# 1  Myydä kelloja, rannekelloja tai niihin liittyv...
# 2  Pitää silmällä myynninjälkeistä palautetta ja ...
# 3  Lakan valmistuksessa käytettäviä raaka-aineita...
# 4  Hoitaa tunneleita, joissa kuivataan savituotte...
#
#                                descriptionLemmatized  \
# 0  [analysoida,  röntgen#kuva,  potilas,  ongelma...
# 1  [myydä,  kello,  , ,  ranne#kello,  tai,  se, ...
# 2  [pitää,  silmä,  myynnin#jälkeinen,  palaute, ...
# 3  [lakka,  valmistus,  käyttää,  raaka#aine,  su...
# 4  [hoitaa,  tunnel,  , ,  joka,  kuivata,  savi#...
#
#                                       descriptionPOS
# 0  [VERB,  NOUN,  NOUN,  NOUN,  NOUN,  CCONJ,  NO...
# 1  [VERB,  NOUN,  PUNCT,  NOUN,  CCONJ,  PRON,  V...
# 2  [VERB,  NOUN,  ADJ,  NOUN,  CCONJ,  VERB,  NOU...
# 3  [NOUN,  NOUN,  VERB,  NOUN,  VERB,  PUNCT,  VE...
# 4  [VERB,  NOUN,  PUNCT,  PRON,  VERB,  NOUN,  PU...

# %%
# For this lemmatization to work you need to start the TurkuNLP docker container in server mode by running
# docker run -d -p 15000:7689 turkunlp/turku-neural-parser:latest-fi-en-sv-cpu server fi_tdt parse_plaintext

def lemmatize(text):
    response = requests.post('http://localhost:15000', data=text.encode('utf-8'), headers={'Content-Type': 'text/plain; charset=utf-8'})
    
    lemmatized = []
    POS = []
    
    for line in response.text.split('\n'):
        if not line:
            continue
        if line[0] == '#':
            continue
        
        l = line.split('\t')
        lemmatized.append(l[2])
        POS.append(l[3])

    return lemmatized, POS

# %%
data = df[['preferredLabel', 'preferredLabelLemmatized', 'preferredLabelPOS', 'alternativeLabel', 'alternativeLabelLemmatized', 'alternativeLabelPOS', 'description', 'descriptionLemmatized', 'descriptionPOS']]
data.head()
# Out:
#                       preferredLabel              preferredLabelLemmatized  \
# 0            analysoida röntgenkuvia            [analysoida, röntgen#kuva]
# 1                      myydä kelloja                        [myydä, kello]
# 2  valvoa myynninjälkeisiä tilastoja  [valvoa, myynnin#jälkeinen, tilasto]
# 3     käyttää lakantuotantolaitteita       [käyttää, lakan#tuotanto#laite]
# 4           hoitaa kuivaustunneleita             [hoitaa, kuivaus#tunneli]
#
#    preferredLabelPOS            alternativeLabel  \
# 0       [VERB, NOUN]                          []
# 1       [VERB, NOUN]                          []
# 2  [VERB, ADJ, NOUN]  [seurata palautetilastoja]
# 3       [VERB, NOUN]                          []
# 4       [VERB, NOUN]                          []
#
#      alternativeLabelLemmatized alternativeLabelPOS  \
# 0                            []                  []
# 1                            []                  []
# 2  [[seurata, palaute#tilasto]]      [[VERB, NOUN]]
# 3                            []                  []
# 4                            []                  []
#
#                                          description  \
# 0  Analysoida röntgenkuvia potilaiden ongelmien s...
# 1  Myydä kelloja, rannekelloja tai niihin liittyv...
# 2  Pitää silmällä myynninjälkeistä palautetta ja ...
# 3  Lakan valmistuksessa käytettäviä raaka-aineita...
# 4  Hoitaa tunneleita, joissa kuivataan savituotte...
#
#                                descriptionLemmatized  \
# 0  [analysoida,  röntgen#kuva,  potilas,  ongelma...
# 1  [myydä,  kello,  , ,  ranne#kello,  tai,  se, ...
# 2  [pitää,  silmä,  myynnin#jälkeinen,  palaute, ...
# 3  [lakka,  valmistus,  käyttää,  raaka#aine,  su...
# 4  [hoitaa,  tunnel,  , ,  joka,  kuivata,  savi#...
#
#                                       descriptionPOS
# 0  [VERB,  NOUN,  NOUN,  NOUN,  NOUN,  CCONJ,  NO...
# 1  [VERB,  NOUN,  PUNCT,  NOUN,  CCONJ,  PRON,  V...
# 2  [VERB,  NOUN,  ADJ,  NOUN,  CCONJ,  VERB,  NOU...
# 3  [NOUN,  NOUN,  VERB,  NOUN,  VERB,  PUNCT,  VE...
# 4  [VERB,  NOUN,  PUNCT,  PRON,  VERB,  NOUN,  PU...

# %%
def get_documents(data):
    documents = {}
    for i in data.index:
        document_words = []
        
        preferred_label = data['preferredLabel'][i]
        preferred_label_lemmatized = data['preferredLabelLemmatized'][i]
        preferred_label_POS = data['preferredLabelPOS'][i]
        for j in range(len(preferred_label_lemmatized)):
            if preferred_label_POS[j].strip() in ['VERB', 'NOUN']:
                document_words.append(preferred_label_lemmatized[j].strip())
                
        alternative_label = data['alternativeLabel'][i]
        alternative_label_lemmatized = data['alternativeLabelLemmatized'][i]
        alternative_label_POS = data['alternativeLabelPOS'][i]
        for j in range(len(alternative_label_lemmatized)):
            for k in range(len(alternative_label_lemmatized[j])):
                if alternative_label_POS[j][k].strip() in ['VERB', 'NOUN']:
                    document_words.append(alternative_label_lemmatized[j][k].strip())
                
        description_lemmatized = [item for item in data['descriptionLemmatized'][i] if item != ' ']
        description_POS = data['descriptionPOS'][i]
        for j in range(len(description_lemmatized)):
            if description_POS[j].strip() in ['VERB', 'NOUN']:
                document_words.append(description_lemmatized[j].strip())
        
        document = ' '.join(document_words)
        
        documents[preferred_label] = document
        
    return documents

documents = get_documents(data)

# %%
documents
# Out:
# {'analysoida röntgenkuvia': 'analysoida röntgen#kuva analysoida röntgen#kuva potilas ongelma selvittäminen tulos tulkitseminen',
#  'myydä kelloja': 'myydä kello myydä kello ranne#kello liittyä tarvike asiakas mieltymys',
#  'valvoa myynninjälkeisiä tilastoja': 'valvoa tilasto seurata palaute#tilasto pitää silmä palaute seurata asiakas#tyytyväisyys valitus kirjata puhelu tieto analysointi',
#  'käyttää lakantuotantolaitteita': 'käyttää lakan#tuotanto#laite lakka valmistus käyttää raaka#aine sulata keittävä sekoittaa kone käyttäminen sekoittaa aines#osa kumi teollisuus#bensiini öljy',
#  'hoitaa kuivaustunneleita': 'hoitaa kuivaus#tunneli hoitaa tunnel kuivata savi#tuote tiili katto#tiili jatko#jalostus uuni',
#  'tutkia ilmastointijärjestelmää': 'tutkia ilmastointi#järjestelmä tarkastaa ilma#vaihto#järjestelmä toiminnallisuus palo#turvallisuus osa',
#  'huoltaa vedenkäsittelylaitteita': 'huoltaa veden#käsittely#laite tehdä vesi jäte#vesi puhdistus käsittely käyttää laite huolto#työ huolto',
#  'purkaa rehun raaka-ainetta': 'purkaa rehu raaka#aine ostaa raaka#aine vastaanottaminen purkaminen eläin rehu tuotanto materiaali siirtäminen vyöhyke ajo#neuvo',
#  'varastoida pyroteknisiä materiaaleja': 'varastoida materiaali varastoida lava#tehoste käyttää materiaali',
#  'levittää ruiskutettavaa eristevaahtoa': 'levittää ruiskuttaa eriste#vaahto levittää ruiskuttaa eriste#vaahto polyuretaani eristää tila',
#  'psykologian hoitotoimenpiteet': 'psykologia hoito#toimen#pide henkilö ryhmä suunnata psykologia hoito#toimen#pide pyrkiä parantaa hoito#taito välittää kulttuuri suku#puoli#näkö#kulma',
#  'lukea raideliikenteen kytkentäsuunnitelmia': 'lukea raide#liikenne kytkentä#suunnitelma kytkentä#suunnitelma lukeminen rakentaminen vian#etsintä kunnossa#pito testaus komponentti korjaaminen vaihtaminen aika kytkentä#suunnitelma ymmärtäminen',
#  'asentaa hissikuilun tukielementit': 'asentaa hissi#kuilu tuki#elementti asentaa varuste tarvita ohjata hissi liike kuilu helpottaa kunnos#sapito kiinnittää kisko kuilu sivu ohjata hissi liikkuminen asentaa huolto#tikas kunnos#sapito hätä#tilanne',
#  'noudattaa työaikataulua': 'noudattaa työ#aika#taulu työ toimittaminen sopia ajan#kohta tarvita työ hallinta noudattaa työ#aika#taulu',
#  'valvoa hedelmientuotantoryhmiä': 'valvoa hedelmien#tuotanto#ryhmä hedelmien#tuotanto#ryhmä valvominen suunnitella osoittaa arvioida ryhmä toiminta',
#  'valvoa ulkoliikuntavälineiden käyttöä': 'valvoa ulko#liikunta#väline käyttö seurata laite käyttö tunnistaa estää laite käyttö',
#  'seinä- ja lattiapäällysteteollisuus': 'seinä lattia#päällyste#teollisuus seinä lattia#päällyste#teollisuus markkina saada olla tuote#merkki toimittaja materiaali',
#  'raakaöljy': 'raaka#öljy öljy näkö#kohta poraaminen käsittely aines#osa käyttö#tarkoitus ympäristö#ongelma',
#  'tarjota multimediasisältöä': 'tarjota multi#media#sisältö kehittää multimedia#materiaali näyttö#kuva esitys dia#esitys animaatio video käyttää sisältö tieto#ympäristö',
#  'valmistaa juomissa käytettävät hedelmäainekset': 'valmistaa juoma käyttää hedelmä#aines valmistella koristelu käyttää hedelmä valmistella drinkki hedelmä#aines valmistella drinkki hedelmä valmistella juoma hedelmä leikata sekoittaa hedelmä juoma juoma#sekoitus aperitiivi valmistus koristelu',
#  'hoitaa sikarinleimauskonetta': 'hoitaa sikari#leimaus#kone hoitaa kone leimata sikari#kääre täyttää kone mustesäiliö asettaa esi#valmistaa etiketti kiinnittää sikari',
#  'kohdentaa ohjelmisto järjestelmän arkkitehtuureihin': 'kohdentaa ohjelmisto järjestelmä arkkitehtuuri sovittaa järjestelmä suunnittelu eritelmä ohjelmisto#arkkitehtuuri varmistaa järjestelmä osa integrointi yhteen#toimivuus',
#  'hoitaa tekstiilien värjäyskoneita': 'hoitaa tekstiili värjäys#kone hoitaa tekstiili#värjäys#kone pitää tehokkuus tuottavuus taso',
#  'hallita liiketoimintatietoa': 'hallita liike#toiminta#tieto hallita ICT#järjestelmä tieto hallita liike#toiminta tieto hallita tieto mallintaa ontologia hallita liike#toiminta#tieto perustaa rakenne jakelu#tapa mahdollistaa tieto hyödyntäminen parantaa käyttää työ#kalu poimia luoda laajentaa liike#toiminta#tieto hallinta',
#  'antaa veropolitiikkaa koskevaa neuvontaa': 'antaa vero#politiikka koskea neuvonta vero#politiikka käytäntö toiminta#linja täytäntöönpano koskea neuvo antaminen hallitus virka#mies',
#  'suorittaa työpaikkatarkastuksia': 'suorittaa työ#paikka#tarkastus tehdä tarkastus paikka varmistaa sääntö määräys noudattaa',
#  'valita ohjaustaulukomponentit': 'valita ohjaus#taulu#komponentti valita ohjaus#taulu osa valita ohjaus#paneeli#komponentti valita ohjaus#paneeli osa valita säätö#paneeli komponentti johto virra#katkaisin vaatimus täyttyä',
#  'antaa ohjeita oppimismenetelmistä': 'antaa ohje oppia#menetelmä antaa neuvo apu opiskelija opiskella tapa ehdottaa tekniikka korostaminen ääneen#puhuminen käyttö auttaa oppilas laatia yhteen#veto laatia opetus#ohjelma',
#  'makean veden ekosysteemien ymmärtäminen': 'vesi ekosysteemi ymmärtäminen vesi ekosysteemi ymmärtäminen',
#  'hotellitoimet': 'hotelli#toimi hotelli#järjestelmä toiminto hotelli järjestelmä toiminto hotelli#toimi toimi kyse asiakas#raja#pinta toimiminen talouden#hoito perus#kirjan#pito liittyä menettely',
#  'simuloida kuljetusongelmia': 'simuloida kuljetus#ongelma tuoda liikenne liittyä tieto ohjelmisto tieto#kone#malli liikenne#ongelma liikenne#ruuhka simuloiminen ratkaisu löytäminen',
#  'tukea sosiaalipalveluiden käyttäjiä määrätyissä viestintätarpeissa': 'tuki sosiaali#palvelu käyttäjä määrätä viestintä#tarvi tunnistaa henkilö erityis#toive tarve auttaa toimia vuoro#vaikutus ihminen seurata viestintä muuttua tarve tunnistaminen',
#  'käyttää ennakoivaa ajotapaa': 'käyttää ajo#tapa ajaa tie#liikenne#turvallisuus aika raha ihmis#henki säästäminen ennakoida tien#käyttäjä toiminta',
#  'harjoitella tanssiliikkeitä': 'harjoitella tanssi#liike tutkia harjoitella tuotanto tarvita tanssi#liike',
#  'asentaa vesiviljelyhäkin kiinnitysjärjestelmiä': 'asentaa vesi#vilje#lyhä kiinnitys#järjestelmä asentaa vesi#vilje#lyhä kiinnitys#järjestelmä suunnitelma',
#  'harjoittaa mobiilimarkkinointia': 'harjoittaa mobiili#markkinointi toteuttaa mobiili#markkinointi harjoittaa mobiili#markkinointi mobiili#laite kerätä tieto siirtää asiakas palvelu tavara myynti edistäminen',
#  'tehdä tieteellistä tutkimusta': 'tehdä tutkimus kerätä korjata parantaa tietämys ilmiö käyttää menetelmä tekniikka perustua mitata olla havainto',
#  'arvioida ulosmittauskelpoisia tavaroita': 'arvioida tavara omaisuus luonne laatu arvo arviointi viran#omainen toimi ulos#mita ottaa pakko#keino',
#  'tehdä hajusteita koskevaa tutkimusta': 'tehdä hajuste koskea tutkimus tutkia aines#osa hajuste kehittäminen',
#  'leikata johtoja': 'leikata johto leikata johto kone käsi#työ#kalu',
#  'tarkastaa matkalippuja': 'tarkastaa matka#lippu tarkastaa matkustaja matka#lippu tarkastus#kortti sisään#käynti yhteys tervehtiä matkustaja ohjata istuma#paikka hytti',
#  'laatia kalastuksen aikatauluja': 'laatia kalastus aika#taulu kalastus#tekniikka suunnittelu toteuttaminen sää#olo#suhde kalastus#menetelmä huomio ottaminen',
#  'käyttää polttouunia': 'käyttää poltto#uuni uuni lämpö#tila säätäminen odottaa loppu#tulos saavuttaminen savi#tyyppi kera#miikka#savi posliini#sapi vaatimus sintraus emali#väri huolehtiminen',
#  'tupakanlehtien tyypit': 'tupakan#lehti tyyppi tupakka#laji lajike ominainen#piirre tunto#merkki yhdistäminen sikari savuke#tuote#vaatimus',
#  'neuvotella sidosryhmien kanssa': 'neuvotella sidos#ryhmä neuvotella kompromissi sidos#ryhmä pyrkiä päästä yritys kanta loppu#tulos liittyä suhde muodostaminen toimittaja asiakkainen varmistaminen tuote',
#  'antaa selonteko oikeuden virkailijoille': 'antaa selon#teko oikeus virkailija antaa oikeus virkailija tuomari oikeuden#käynti#asian#ajaja edustaja selon#teko päivä tapahtuma päivä suunnitella tapaus oikeuden#käynti#asia#kirja läsnä#olija oikeuden#käynti koskea seikka',
#  'luoda riimirakenne': 'luoda riimi#rakenne luoda kehittää laulu tarkoittaa riimi#rakenne kirjoittaa lyriikka rakenne',
#  'eläinten neuroanatomia': 'eläin neuroanatomi eläin hermosto rakenne eläin keskus ääreis#hermosto osa elin näkö aisti kuulo liike#rata tutkimus',
#  'huolehtia kirjaston laitteista': 'huolehtia kirjasto laite ylläpitää puhdistaa korjata kirjasto#resurssi väline tila pyyhkiä pöly korjata tulostin paperi#tukos',
#  'huoltaa jätteenpolttouunia': 'huoltaa jätteen#poltto#uuni pitää uuni laitteisto käyttää jäte polttaminen suorittaa huolto#työ tunnistaa viko tehdä korjaus',
#  'pitää kirjaa huoltotoimenpiteistä': 'kirjaa huolto#toimen#pide kirja pitäminen korjaus kunnos#sapito#toimi lukea tieto käyttää osa materiaali',
#  'hoitaa synnyttäviä äitejä': 'hoitaa synnyttää äiti syntyä nainen hoitaminen kipu lievittää tarvita tuki lohtu tarjota',
#  'noudattaa lainsäädäntöä sosiaalipalveluissa': 'noudattaa lain#säädäntö sosiaali#palvelu toimi sosiaali#palvelu tarjoaminen liittyä toiminta#periaate vaatimus',
#  'käyttää jyvienpuhdistuslaitetta': 'käyttää jyvi#puhdistus#laite käynnistää puhdistus#laite puhaltaa seuloa jyvä vieras#hiukkanen lika oksa kivi siirtää jyvä säilytys#asti jatko#käsittely',
#  'viljan kuivausmenetelmät': 'vilja kuivaus#menetelmä jyvä kuivaus#menetelmä vilja kuivaus#menetelmä tekniikka vaatimus tuote lämpö#tila kuivuminen jyvä käsittely sääntely kuivaaminen',
#  'kehittää teknisten tekstiilien teknisiä tietoja': 'kehittää tekstiili tieto kehittää tekstiili eritelmä laatia tieto tuote ominaisuus',
#  'hävittää kuolleita eläimiä': 'hävittää eläin hankkiutua ero eläin eläin hävittäminen pitää liha lähde eläin hautaaminen tuhkaaminen omistaja toive syy peruste',
#  'arvioida vaatteen laatua': 'arvioida vaate laatu vaate ompelu rakenne lisä#varuste kiinnike koriste varjostus arviointi malli jatkuvuus yhteen#sopivuus arviointi nauha vuoraus arviointi',
#  'työskennellä itsenäisesti maataloudessa': 'työskennellä maa#talous hoitaa tehtävä karjan#hoito eläin#tuotanto#palvelu ala tehdä päätös apu hoitaa tehtävä puuttua asia ongelma apu',
#  'suhdetoiminta': 'suhde#toiminta PR#toiminta PR#suhde yritys yksilö imago mieli#kuva liittyä näkö#kohta hallinta sidos#ryhmä yhteis#kunta',
#  'huoltaa rautateiden merkinantolaitteita': 'huoltaa rauta#tie merkinanto#laite testata käyttää ylläpitää rauta#tie merkinanto#laite kytkin tasoristeys varoitus#laite',
#  'kehittää koulutusresursseja': 'kehittää koulutus#resurssi luoda kehittää koulutus#resurssi vierailija koululainen#ryhmä perhe erityis#ryhmä',
#  'kestää ulosteita': 'kestää uloste pystyä sietää uloste haju eläin jätös',
#  'neuvotella hintoja antiikkiesineille': 'neuvotella hinta antiikki#esine kommunikoida neuvotella antiikki#esine myyjä ostaja keskustella hinta ehto',
#  'valmistella raudoitustangot': 'valmistella raudoitus#tanko valmistella betoni#teräs valmistella raudoitus#tanko harja#teräs käyttää teräs#betoni#rakentaminen asettaa laatta pylväs betoni#valu käyttää kannatin rakennelma pysyä maa',
#  'kehittää urheilun kilpailustrategioita': 'kehittää urheilu kilpailu#strategia laatia kilpailu#strategia menestyminen mahdollisuus urheilu',
#  'tasapainottaa tietokantaresurssit': 'tasa#painottaa tieto#kanta#resurssi tasa#painottaa tieto#kanta työ#määrä resurssi valvoa tapahtuma kysyntä jakaa levy#tila varmistaa palvelin toiminta#varmuus kustannus riski#suhde optimoida',
#  'arvioida suunnitelman riskejä ja vaikutuksia': 'arvioida suunnitelma riski vaikutus arvioida kohde riski ehdottaa kehitys#toimi kohde järjestely vaikutus suunnitelma käytettävyys huolto turvallisuus',
#  'rannekellotyypit': 'ranne#kello#tyyppi ranne#kello tyyppi kello kvartsi#kello ominaisuus toiminto kalenteri sekunti#kello veden#kestävyys',
#  'valvoa hakkuuprojekteja': 'valvoa hakkuu#projekti varmistaminen metsän#hakkuu noudattaa sopimus sopia ehto menettely pyrkimys ratkaista toiminta aika tulla ongelma menetelmä parantaminen turvallisuus yritys hallitus sääntely noudattaminen varmistaminen',
#  'tehdä ruumiinavaus': 'tehdä ruumiina#vaus tehdä auto#psi tehdä obduktio avata kuolla henkilö keho poistaa elin tutkia tulkita tulos henkilö historia huomio ottaa',
#  'arvioida eläinten elinympäristöä': 'arvioida eläin elin#ympäristö arvioida eläin elin#ympäristö ilma#vaihto tila elin#ympäristö koko riittävyys peruste verrata oikeus oikeus tuntea nälkä jano oikeus tuntea epä#mukavuus oikeus tuntea kipu kärsiä vamma sairaus oikeus ilmentää käyttäytyminen oikeus tuntea pelko stressi',
#  'valmistella kalojen lääkintäsuunnitelmia': 'valmistella kala lääkintä#suunnitelma laatia terveyden#hoito#suunnitelma kala#tauti koskea vaatimus',
#  'valmistella taittoa': 'valmistella taitto käyttää tekniikka valmistella sivu järjestely paino#arkki painatus#prosessi kustannus aika säästäminen ottaa huomio painaa materiaali muoto sivu#määrä sitomis#tekniikka kuitu#suunta',
#  'tarjota yksityisiä kuljetuspalveluja': 'tarjota kuljetus#palvelu harjoittaa kuljetus#palvelu soveltaa vaatimus varmistaa työ suoritus kiinnittää huomio asiakas tarjota palvelu',
#  'mitata alusten vetoisuus': 'mitata alus vetoisuus mitata alus tilavuus selvittää alus rahti varasto#kapasiteetti mitata alus',
#  'tulkita taiteellisia tarkoituksia': 'tulkita tarkoitus tekijä tarkoitus tulkitseminen',
#  'toteuttaa eläinten koulutusohjelmia': 'toteuttaa eläin koulutus#ohjelma panna koulutus#ohjelma toteuttaa koulutus#ohjelma eläin perus#koulutus#tarkoitus saavuttaa tavoite laatia koulutus#ohjelma seurata eläin edistyminen asettaa tavoite tehdä kirjaus',
#  'koordinoida ostotoimintaa': 'koordinoida osto#toiminta koordinoida hallinnoida hankinta vuokraus#prosessi ostaminen vuokraus suunnittelu seuranta raportointi organisaatio taso',
#  'suunnitella maantiekaluston huolto': 'suunnitella maan#tie#kalusto huolto arvioida kalusto kunnossapito#ohjelma huoltaa kalusto toiminta häiriintyä',
#  'tarjota tukea itsehoitoon': 'tarjota tuki itsehoito tarjota asiakas näyttö perustua tieto strategia itsehoito',
#  'käyttää käsiporakonetta': 'käyttää käsi#pora#kone hajottaa materiaali käyttää käsi#pora#kone kiinnittää laitteisto liikkua osa',
#  'valita muottityyppejä': 'valita muotti#tyyppi valita muotti#laatikko tyyppi muotti#tyyppi koko valinta toiminta peruste',
#  'tarkastaa viemärijärjestelmiä': 'tarkastaa viemäri#järjestelmä määrittää paikantaa viemäröinti#järjestelmä tukos',
#  'työskennellä elintarvikejalostustiimissä': 'työskennellä elin#tarvike#jalostus#tiimi työskennellä ryhmä elin#tarvike juoma#teollisuus toimia elin#tarvike#jalostus ammattilainen',
#  'valmistella juhlatiloja': 'valmistella juhla#tila valmistella seremonia#tila valmistella tila seremonia#tarkoitus koristella huone tila juhla#meno hautajaiset tuhkaus häät ristiä',
#  'muuttaa strategia toimiksi ja tavoitteiksi': 'muuttaa strategia toimi tavoite toimeen#pasi strategia muuntaa strategia toiminta muuttaa suunnitelma tehdä tavoite toteuttaa tehtävä taso suunnitella aika#taulu saavuttaa suunnitella tulos tavoite',
#  'suorittaa geologisia tutkimuksia': 'suorittaa tutkimus suorittaa kaivos louhos#toiminta liittyä tutkimus alue ominaisuus selvittäminen malmi löytäminen',
#  'hallinnolliset tehtävät terveydenhuollossa': 'tehtävä terveyden#huolto tehtävä terveyden#huolto potilas rekisteröinti ajan#varaus#järjestelmä potilas#tieto rekisteröinti resepti uusiminen',
#  'huonekaluteollisuus': 'huone#kalu#teollisuus koti#talous#esine suunnittelu valmistus jakelu myynti osallistua yritys toiminto',
#  'asentaa kumitiivisteitä': 'asentaa kumitiiviste kiinnittää kumitiiviste ajo#neuvo tuuli#lasi ikkuna kehys tulla vesi#tiivi ei rämistä',
#  'tarkastaa oppilaitoksia': 'tarkastaa oppi#laitos tarkastaa toiminta käytäntö noudattaminen oppi#laitos hallinto varmistaa noudattaa koulutus koskea lain#säädäntö hallinnoida toiminta huolehtia opiskelija',
#  'laatia työohjelmia': 'laatia työ#ohjelma kehittää resurssi käyttö koskea työ#ohjelma hyödyttää ympäristö metsä tuotanto',
#  'retoriikka': 'retoriikka puhe#taito keskustelu#taito tarkoitus parantaa kirjoittaja puhuja mahdollisuus tiedottaa vakuuttaa motivoida yleisö',
#  'puhallettavat hioma-aineet': 'puhaltaa hioma#aine puhaltaa hionta#materiaali tyyppi ominaisuus puhaltaa hioma#aine alumiini#oksidi alumiini#oksidi',
#  'asettaa lasi telineisiin': 'asettaa lasi teline asettaa lasi uunitelineinen pihti',
#  'valvoa maastoaluetta': 'valvoa maasto#alue valvoa maasto#alue tapahtuma aika järjestelmä suojaaminen raportoida maasto#alue kunto vesistö kasvi järjestelmä#virhe aiheutua vahinko',
#  'laatia strategioita sähkönjakelun vikatapahtumia varten': 'laatia strategia sähkön#jakelu vika#tapahtuma laatia toteuttaa strategia varmistaa toiminta sähkö tuotanto siirto jakelu katketa sähkö#katkos lisääntyä kysyntä',
#  'käyttää aaltojuotoskonetta': 'käyttää aalto#juotos#kone käyttää aalto#juotos#kone elektroniikka#komponentti juottaminen piiri#levy levy siirtää juotos#aalta piiri#levy kulkea liitos kiinnittää piiri#levy',
#  'suunnitella soittimia': 'suunnitella soitin kehittää suunnitella soitin asiakas eritelmä',
#  'tietokanta': 'tieto#kanta tieto#kanta luokitus tieto#kanta tieto#kanta#tyyppi tieto#kanta tyyppi tieto#kanta ominaisuus tieto#kanta luokittelu kuulua käyttö#tarkoitus ominaisuus terminologia malli käyttö XML#tieto#kanta tieto#kanta teksti#tieto#kanta',
#  'huolehtia peruukeista': 'huolehtia peruukki järjestää ylläpitää korjata peruukki hius#lisäke',
#  'varmistaa potilaan oikea asento leikkausta varten': 'varmistaa potilas asento leikkaus luoda kirurgi ohje olo#suhteet potilas asento leikkaus varmistaa potilas olo#suhteet',
#  'käyttää ohjelmistosuunnittelun malleja': 'käyttää ohjelmisto#suunnittelu malli käyttää ohjelmisto#suunnittelu käytäntö käyttää ohjelmisto#suunnittelu kaava käyttää ohjelmisto#suunnittelu#malli käyttää ohjelmisto#suunnittelu#kaava hyödyntää ohjelmisto#suunnittelu malli hyödyntää ratkaisu käytäntö tieto viestintä#tekniikka kehittää#tehtävä liittyä ohjelmisto kehittäminen suunnittelu',
#  'määrätä lääkkeitä': 'määrätä lääke määrätä asiakas tarve lääke#hoito vaatia tieto perustua sairaala käytäntö erikoistua#ala',
#  'kehityspsykologia': 'kehitys#psykologia ihminen käyttäytyminen suoritus#kyky kehitys lapsuus nuoruus#ikä koskea tutkimus',
#  'lukea lämmitysmittareita': 'lukea lämmitys#mittari tulkita mittaus#laitteisto kirjata lämpö#energia kulutus mitata lämmön#siirto#aine lämpö#tila muutos kirjata tulos',
#  'tiedon rakenne': 'tieto rakenne infrastruktuuri#tyyppi määritellä tieto muoto jäsennellä jäsennellä',
#  'ohjelmoitavat logiikat': 'logiikka logiikka#ohjain logiikka PLC tieto#kone#ohjaus#järjestelmä käyttää panos tuotos seuranta valvonta prosessi automatisointi',
#  'muokata kipsiä': 'muokata kipsi muokata kipsi ominaisuus muoto koko',
#  'suunnitella avaruussatelliittihankkeita': 'suunnitella avaruus#satelliitti#hanke suunnitella satelliitti laukaiseminen lähettäminen pyydystäminen kierto#rata suunnitella laukais#uaika#taulu toimi onnistua hanke tarvita vaihe laukaisu#alusta valmistelu laukaisu#kumppani tehtävä sopimus',
#  'testata filmien kehittämiseen käytettäviä kemikaaleja': 'testata filmi kehittäminen käyttää kemikaali käyttää erikois#väline testata filmin#kehitys#kone astia olla kemikaali varmistaa toimia',
#  'kartoittaa vikoja putkistoinfrastruktuurista': 'kartoittaa viko putkisto#infrastruktuuri havaita viko putkisto#infrastruktuuri rakentaminen aika aika kulua havaita viko rakennus#via korroosio maa liike vahinko tehdä liitos',
#  'hoitaa mattoja': 'hoitaa matta tarkastaa matto harjata nukka matto#harja solmu käyttää puhdistus#aine valkais#uaine matto hapsu puhdistaminen kirkastaminen tahra haju poisto',
#  'analysoida tietojärjestelmiä': 'analysoida tieto#järjestelmä analysoida tieto#järjestelmä arkisto kirjasto tieto#keskus tehokkuus varmistaminen kehittää ongelma#ratkainen#ukekniikka järjestelmä tehokkuus parantaminen',
#  'muokata kumituotteita': 'muokata kumi#tuote käyttää väline laite kumi#osa kumi#tuote muotoilu leikata muotoilla liimata',
#  'työskennellä ammattikoulussa': 'työskennellä ammatti#koulu työskennellä ammatti#oppi#laitos työskennellä oppi#laitos opettaa opiskelija käytäntö kurssi',
#  'toimia potilaan hoitoon osallistuvan monialaisen tiimin vastuuhenkilönä': 'toimia potilas hoito osallistua tiimi vastuu#henkilö hallinnoida valvoa potilas hoito osallistua tiimi hoitaja vaihe lääkäri toimia tiimi kuulua viestintä varmistaminen työ järjestäminen tuki tarjoaminen ryhmä jäsen',
#  'siivota': 'siivota tehdä siivous tehdä siivous#toimi jäte keräys imurointi roska#kori tyhjentäminen työ#tila puhdistaminen siivous noudattaa tarvita terveys turvallisuus#määräys',
#  'pelisäännöt': 'peli#sääntö peli sääntö peli säädellä periaate sääntö',
#  'painovärin poistoprosessit': 'paino#väri poisto#prosessi paino#väri poisto#prosessi kelluttaminen valkaisu pesu prosessi käyttää muste poistaminen paperia paperi valmistus',
#  'C++': 'ohjelmiston#kehitys koskea tekniikka periaate analyysi algoritmi koodaus testaus ohjelma#paradigma laatiminen ohjelmointi#kieli',
#  'valita sopivia vaarojen hallintakeinoja': 'valita sopia vaara hallinta#keino vaara hallinta#keino valitseminen riski#hallinta',
#  'huolehtia kliinisistä tiloista': 'huolehtia tila varmistaminen ympäristö lukea laite materiaali valmistella ylläpitää käyttö työ#ympäristö valmistelu ylläpito varmistaminen laite materiaali käyttää',
#  'noudattaa hammaslääkärin ohjeita': 'noudattaa hammas#lääkäri ohje työskennellä hammas#lääkäri ohje',
#  'ottaa vastaan geenitestaukseen lähetteellä saapuvia potilaita': 'ottaa geeni#testaus lähete saapua potilas ottaa potilas saapua geeni#testaus asian#tuntija lähettää ottaa huomio potilas tila vaurio kehitys#häiriö autismi epilepsia',
#  'valmistella baarialue': 'valmistella baari#alue avata baari alue valmistella vuoro tarkistaa baari asettelu valmistella baari alue avata baari#alue valmistaa vuoro järjestää menettely baari#alue tiski laite sivu#piste sivu#pöytä vitriini vuoro',
#  'tutkia kilpailunrajoituksia': 'tutkia kilpailu#rajoitus tutkia yritys organisaatio käyttää kauppa kilpailu rajoittaa käytäntö menetelmä mahdollistaa yritys hallita markkinat seuraamus selvittäminen ratkaisu keksiminen käytäntö kieltäminen',
#  'tiedottaa asiakkaille toiminnan muutoksista ja peruutuksista': 'tiedottaa asiakas toiminta muutos peruutus kertoa asiakas muutos peruutus kertoa lento#aika#taulu muutos kertoa aika#taulu#muutos kertoa muutos peruutus tiedottaa asiakas suunnitella toiminta muutos viivästyminen peruutus',
#  'tasapainon fysiologia': 'tasa#paino fysiologia keho tasa#paino vastata tasa#paino#elin ominaisuus toiminto',
#  'noudattaa tarkasti tasoristeyksessä toimimista koskevia ohjeita': 'noudattaa taso#risteys toimiminen koskea ohje noudattaa tasoristeys toimiminen koskea ohje valo hälytys merkin#anto#väline käyttäminen onnettomuus ehkäiseminen käyttää laite laskea nostaa puomi pysyä liikkuminen aika',
#  'kehittää tuotesuunnittelua': 'kehittää tuote#suunnittelu sisällyttää markkinat vaatimus tuote#suunnittelu tuote#kehitys',
#  'kannustaa urheilemaan kouluissa': 'kannustaa urheilla koulu edistää urheileminen koulu',
#  'analysoida omaa esiintymistä': 'analysoida esiintyminen ymmärtää analysoida kuvata esiintyminen sijoittaa työ tyyli suuntaus kehitys arvioida työ harjoitus esitys',
#  'liikerakennusten turvallisuus': 'liike#rakennus turvallisuus turvallisuus liittyä toimi ominaisuus tehtävä riski kauppa#alue laitos pankki kauppa#keskus nähtävyys hotelli ravintolo',
#  'ottaa korkeimman tason vastuu sisämaan vesiliikenteessä': 'ottaa taso vastuu sisä#maa vesi#liikenne ottaa pää#vastuu sisä#maa vesi#liikenne ymmärtää alus päällikkö tehtävä liittyä vastuu#alue ottaa vastuu alus miehistö luotettavuus rahti matkustaja varmistaa toimia pitää',
#  'analysoida hoidon laatua': 'analysoida hoito laatu analysoida hoito laatu parantaa toiminta yleis#sairaan#hoitaja',
#  'koordinoida lentoaikatauluja': 'koordinoida lento#aika#taulu lento#aika#taulu ilma#alus toiminto hallinnointi tarkistaminen lähtö',
#  'käyttää eristysputken käämintäkoneitta': 'käyttää eristys#putki käämintä#kone käyttää kone laite tarkoittaa eriste#putki käämittäminen leikkaaminen',
#  'jakelukanavamarkkinointi': 'jakelu#kanava#markkinointi strategia käytäntö kanava myynti kuulua tuote jakaminen kumppani tuote saada loppu#kuluttaja käyttö',
#  'valmistella välineet diagnostista kuvantamista varten': 'valmistella väline kuvantaminen väline valmistelu kuvantaminen varmistaminen tila potilas',
#  'oikeustapausten hallinta': 'oikeus#tapaus hallinta oikeuden#käynti menettely avaaminen päättäminen asia#kirja laatia käsitellä oikeus#tapaus vaihe olla henkilö vaatimus täyttää käsittely päättää',
#  'vastata koneen säätölaitteen asetuksista': 'vastata kone säätö#laite asetus asettaa säätää laite asetus säätää olo#suhteet materiaali#virta lämpö#tila paine',
#  'osallistua elintarviketuotantolaitoksen toiminnan suunnitteluun': 'osallistua elin#tarvike#tuotanto#laitos toiminta suunnittelu elin#tarvike#laitos suunnittelu osallistuminen arvioida prosessi tila laite koskea tarve seuranta valvonta lukea',
#  'noudattaa kielioppi- ja oikeinkirjoitussääntöjä': 'noudattaa kieli#oppi oikein#kirjoitus#sääntö noudattaa kieli#oppi oikein#kirjoitus#sääntö varmistaa teksti yhdenmukaisuus',
#  'säätää jännitettä': 'säätää jännite säätää jännite sähkö#laite',
#  'kouluttaa louhintakoneiden hoitajia': 'kouluttaa louhinta#kone hoitaja louhinta#kone ominaisuus toiminto esitteleminen louhinta#kone hoitaja',
#  'ruoan tarjoilutoiminta': 'ruoka tarjoilu#toiminta elin#tarvike tarjoilu asiakas koskea seikka menetelmä tekniikka',
#  'testata terveydenhuollon laitteita': 'testata terveyden#huolto laite varmistaminen terveyden#huolto laite sopia potilas testaaminen arvioiminen varmistaminen toimia tarkoittaa tapa mukautus tekeminen sopivuus toimivuus mukavuus varmistaminen',
#  'hoitaa turvallisuus- ja valvontalaitteita': 'hoitaa turvallisuus valvonta#laite vastata turvallisuus valvonta#laite käyttö käyttää turvallisuus valvonta#laite valvoa alue turvallisuus hoitaa turvallisuus valvonta#laite hoitaa valvonta#laite tarkkaileminen ihminen tehdä alue varmistaa turvallisuus',
#  'kalastusalukset': 'kalastus#alus kalastus#alus osa varuste nimi',
#  'kerätä veroja': 'kerätä vero kerätä vero organisaatio yksilö määrä maksaa valtio asetus laskelma peruste varmistaminen että#ei maksaa vero maksaa',
#  'osoittaa ammatillista vastuuta': 'osoittaa vastuu varmistaa työ#tekijä asiakas kohdella vastuu#vakuutus',
#  'geotiede': 'geo#tiede maa#pallo tutkia tiede kuulua geologia meteorologia oseanografi astronomia sisältyä maa#pallo koostumus maa rakenne prosessi',
#  'valvoa potilaan terveyden tilaa': 'valvoa potilas terveys tila valvoa potilas kunto tutkia potilas terveyden#tila valvoa lääke käyttö raportoida potilas tila esi#mies potilas perhe',
#  'leikata tekstiilejä': 'leikata tekstiili leikata kangas leikata tekstiili asiakas toive tarve',
#  'korjata huonekalujen osia': 'korjata huone#kalu osa korjata lukko tappi tuki#kappale runko huone#kalu osa',
#  'tehdä lämpöenergiamittauksia': 'tehdä lämpö#energia#mittaus käyttää kalometri analysoida lämpö#kapasiteetti muutos mitata reaktio lämpö',
#  'käyttää sorkkienleikkaustyökaluja': 'käyttää sorkki#leikkaus#työ#kalu valita käyttää sopia työ#kalu väline nauta sorkki leikkaaminen',
#  'tehdä puunhakkuukoneiden säännöllisiä huoltoja': 'tehdä puun#hakkuu#kone huolto tehdä metsä#kone huolto tarkastaa puhdistaa huoltaa ylläpitää virta#yksikkö valmistaja vaatimus toimi#ala ohje tarkastaa virta#yksikkö osa ylläpitää hakkuu#järjestelmä valmistaja suositus vaihtaa vaurioitua puuttua kulua osa työ#kalu raportoida puute tehdä huolto tarkastaa kone käynnistys valmistella kone uudelleen#käyttää ketju#saha hakkuu#järjestelmä käyttö toiminta käyttö koskea standardi',
#  'suunnitella ruokalistoja': 'suunnitella ruoka#lista antaa neuvo ruoka#lista laadinta antaa neuvo menu laadinta auttaa ruoka#lista suunnittelu suunnitella menu auttaa menu suunnittelu suunnitella ruoka#lista ottaa huomio tila luonne tyyli asiakas#palaute kustannus aines#osa kausi#luonteisuus',
#  'ryöppäyskoneprosessi': 'ryöppäys#kone#prosessi kone lämmittää ruoka höyry vesi bakteeri kuolla väri säilyä ansailma poistua',
#  'huoltaa maatalouskoneita': 'huoltaa maa#talous#kone huoltaa maa#talous#kone varmistaa toimia huolehtia laite kunnossa#pito säätää korjata tarvita käsi sähkö#työ#kalu vaihtaa osa järjestelmä',
#  'analysoida soluviljelmiä': 'analysoida solu#viljelma analysoida solu#viljelma kasvattaa kudos#näyte seuloa irtos#olu#koe hedelmällisyys#ongelma havaitseminen',
#  'käyttää rusnauslaitetta': 'käyttää rusnaus#laite rusnaus#laite käyttäminen rusnaus#laite pora kiinnittää ajo#neuvo pudottaa irto#materiaali kaivos katto louhinta#pinta',
#  'järjestää tietoa': 'järjestää tieto organisoida tieto tieto järjestäminen sääntö tieto luettelointi luokittelu tieto ominaisuus',
#  'tallentaa puutavaran käsittelytietoja': 'tallentaa puu#tavara käsittely#tieto kirjata tieto puu käsittely soveltua tieto#järjestelmä raportoida henkilö',
#  'huolehtia kuvauslaitteista': 'huolehtia kuvaus#laite kuvaus#laite huoltaminen toimia',
#  'akustiikka': 'akustiikka tutkimus koskea ääni kaikuminen vahvistuminen imeytyminen tila',
#  'kosmeettiset hammastoimenpiteet': 'hammas#toimen#pide hammas kunnostus#menettely hoito parantaa potilas hammas ulko#näkö valkaisu emali ennallistaminen paikkaus posliini#pinnoite ulko#pinnot täyte#aine kruunu',
#  'määritellä teoksen visuaalinen maailma': 'määritellä teos maailma määritellä teos maailma maalata piirtää valo heijastus keino',
#  'huoltaa asennettuja laitteita': 'huoltaa asentaa laite huolehtia asentaa laitteisto paikka noudattaa menettely kone ajo#neuvo laite irrottaminen epä#huomio',
#  'huoltaa foliopainatuskonetta': 'huoltaa folio#painatus#kone huoltaa folio#painatus#kone painaa paperi laatta puristaa kosteus',
#  'ottaa huonepalvelun tilauksia': 'ottaa huone#palvelu tilaus ottaa huone#palvelu#tilaus koordinoida huone#palvelu#tilaus ottaa toimittaa huone#palvelu#tilaus vastata huone#palvelu#tilaus hoitaa huone#palvelu#tilaus hyväksyä huone#palvelu#tilaus ohjata vastata työ#tekijä',
#  'terästynnyreiden ja -astioiden valmistus': 'terästynnyri astia valmistus ämpäri tölkki tynnyri sanko laatikko valmistus metalli#työstö apu',
#  'kerätä tietoja GPS-laitteilla': 'kerätä tieto GPS#laite kerätä data GPS#laite kerätä tieto kenttä käyttää GPS#laite',
#  'käyttää levityskonetta': 'käyttää levitys#kone käyttää levitys#kone levittää kaivos#toiminta poistaa irto#maa kaato#paikka',
#  'koordinoida lastin käsittelyä': 'koordinoida lasti käsittely organisoida lasti käsittely suunnitella lasti jakautuminen alus johtaa lasti käsittely',
#  'neuvoa alihankkijoita': 'neuvoa ali#hankkija ali#hankkija neuvominen suunnitelma tulkinta muutos suosittelu tarvita',
#  'pujotella kangasvuoraus': 'pujotella kangas#vuoraus pujotella vesi kastella kangas#vuoraus muotti',
#  'säädellä rouhitun tupakan kulkua': 'säädä rouhia tupakka kulku säännellä tupakka kulku varmistaa savuke sisältää määrätä määrä hieno leikata tupakka',
#  'esitellä tuotteen ominaisuuksia': 'esitellä tuote ominaisuus osoittaa tuote käyttää tapa antaa asiakas tieto tuote ominaisuus hyöty selittää tuote toiminta käyttö huolto saada asiakas ostaa tuote',
#  'sosiaalisen ympäristön vaikutus terveyteen': 'ympäristö vaikutus terveys ihminen käyttäytyminen olo#suhteet vaikutus terveys yhteys',
#  'muokata koruja': 'muokata koru muokata koru kiinnitys',
#  'verrata maanmittauslaskelmia': 'verrata maan#mittaus#laskelma määrittää tieto tarkkuus verrata laskelma soveltaa standardi',
#  'suorittaa turvallisuustoimenpiteitä pienaluksella': 'suorittaa turvallisuus#toimen#pide pienalus antaa laiva ensi#hoito sairas loukkaantua henkilö vakiintua menettely vamma sairaus minimoida',
#  'käyttää käyttäjäkeskeisen suunnittelun menetelmiä': 'käyttää suunnittelu menetelmä käyttää suunnittelu#menetelmä käyttää suunnittelu lähtö#kohta käyttäjä toive tarve käyttää UCD#menetelmä hyödyntää käyttäjä näkö#kulma huomioida suunnittelu#menetelmä käyttää ucd#menetelmä käyttää suunnittelu#menetelmä tuote palvelu prosessi loppu#käyttäjä tarve rajoitus kiinnittää huomio suunnittelu#prosessi vaihe',
#  'valvoa museoesineiden siirtämistä': 'valvoa museo#esine siirtäminen valvoa museo#esine siirtäminen varmistaa turva',
#  'kuumasaumaustyypit': 'kuuma#saumaus#tyyppi olla olla kuuma#saumaus#tyyppi induktio#saumaus induktio#hitsaus kuuma#tanko#saumaus kuuma#saumaus impulssi#kuuma#saumaus ymmärtäminen materiaali käyttää',
#  'ottaa huomioon merenkulun rajoitteet': 'ottaa huomio meren#kulu rajoite ottaa huomio meren#kulu rajoite laiva enimmäis#syväys väyli kanava syvyys vuoro#vesi kuormitus vaikutus laatia skenaaria sisällyttää meri#liikenne suunnittelu',
#  'toimia kuiskaajana esityksissä': 'toimi kuiskaaja esitys toimia kuiskaaja esiintyjä teatteri ooppera#esitys',
#  'käyttää tarkkuusmittausvälineitä': 'käyttää tarkkuus#mittaus#väline mitata tarkastaa osa merkitä standardi käyttää tarkkuus#mittaus#väline mitta#saksi mikro#metri mitta#väline',
#  'analysoida kuvia': 'analysoida kuva arvioida kuvantamis laite skannata ottaa kuva',
#  'liittää metalleja': 'liittää metalli yhdistää metalli#kappale juotos hitsaus#materiaali',
#  'asentaa tihkukastelujärjestelmä': 'asentaa tihku#kastelu#järjestelmä asentaa tippa#kastelu#järjestelmä liittää tihku#kastelu#järjestelmä osa lukea suodatin#laite anturi venttiili asettaa kastelu#putki peitto#alue suunnitelma',
#  'käyttää näyttämön liikutusjärjestelmää': 'käyttää näyttämö liikutus#järjestelmä käyttää näyttämö liikutus#järjestelmä lento#mekanismi käyttää järjestelmä',
#  'korjata nosturikalustoa': 'korjata nosturi#kalusto nosturi nosturi#laite korjaaminen komponentti osa järjestelmä korvaaminen tarvita käsi sähkö#työ#kalu',
#  'taidehistoria': 'taide#historia taide taiteilija historia suuntaus vuosi#sata aika nyky#kehitys',
#  'asettaa äänilevyetikettejä': 'asettaa ääni#levyeti#ketti äänilevyeti#ketti asettaminen paino keskus ylä ala#tappi käsi lakka apu',
#  'tilata optisia laitteita': 'tilata laite tilata laite materiaali kiinnittää huomio tuote hinta laatu soveltuvuus',
#  'puhdistaa aluksia': 'puhdistaa alus pestä laiva poistaa alus lika lakaista harjata pestä kansi tila',
#  'kehittää markkinoinnin työvälineitä': 'kehittää markkinointi työ#väline laatia mainos#materiaali tehdä yhteis#työ mainos#teksti video valo#kuva tuotanto laatia mainos#materiaali järjestys',
#  'antaa nitraattien aiheuttamaa pilaantumista koskevia neuvoja': 'antaa nitraatti aiheuttaa pilaantuminen koskea neuvo dityppioksidi#päästö lisätä maa ultravioletti#säteily suojata otsoni#kerros häviäminen maa#talous#maa levittää kivennäinen#lannoite lannoitus viinin#viljely ekosysteemi päästä määrä typpi',
#  'tutkia saastumista': 'tutkia saastuminen tutkia kontaminaatio suorittaa testi alue pinto materiaali saastuminen ominaisuus tutkiminen määrittää saastuminen syy luonne riski vahinko laajuus',
#  'hankkia luvat julkisten tilojen käyttöä varten': 'hankkia lupa tila käyttö pitää yhteys kaupunki viran#omainen saada hankkia tila käyttö koskea lupa tarkoitus',
#  'spesifikaatiot meijerituotteiden valmistuksessa': 'spesifikaatio meijeri#tuote valmistus meijeri#tuote valmistus noudattaa määritelmä säännös standardi tuote turvallisuus raaka#aine pakata tuote',
#  'vihanhallinta': 'vihan#hallinta menetelmä pyrkiä tunnistaa vihka tausta olla syy tunne#elämä oire keino hallita viha elämä#tilanne',
#  'valvoa kasinohenkilökuntaa': 'valvoa kasino#henkilö#kunta seurata valvoa aika#tauluttaa kasino#työ#tekijä tehtävä',
#  'elektronisten laitteiden periaatteet': 'laite periaate laite käyttö vian#määritys periaate elektroniikka toiminta periaate laite ominaisuus toiminta teoria elektroniikka toiminta#periaate integroida piiri sähkö#järjestelmä sähkö#energia elektroni valvonta periaate koskea tutkimus',
#  'käyttää ICT-lippujärjestelmää': 'käyttää ICT#lippu#järjestelmä hyödyntää erityis#järjestelmä seurata organisaatio ongelma rekisteröinti käsittely ratkaisu laatia ongelma lippu rekisteröidä henkilö saada tieto seurata muutos esittää lippu tila asia saada päätös',
#  'psykosomatiikka': 'psykosomatiikka lääke#tiede haara ottaa huomio käyttäytyminen koskea asenne vaikutus ihminen prosessi',
#  'kirjoittaa ohjekirjoja': 'kirjoittaa ohje#kirja laatia ohje laite kone järjestelmä käyttö',
#  'urheiluetiikka': 'urheilu#etiikka urheilu liittyä toiminta#linja urheilu#johtaminen koskea näkö#kohta varmistaa peli urheilu#henki kunto kilpa#urheilu',
#  'tutkia kielenomaksumista': 'tutkia kieleno#maksuminen tutkia ihminen oppia kieli lapsuus elämän#vaihe tieto toimia vuoro#vaikutus prosessi vaihdella kieli alue',
#  'vahata karvoja': 'vahata karva poistaa karva levittää iho vaha poistaa karva liuska vaha jähmettyä painaa liuska vaha irrottaa vasta#karva',
#  'valmistaa alusta lasille': 'valmistaa alku lasi valmistaa alku lasi metalli#tarjotin levittää kipsi tela paletti#veitsi',
#  'varmistaa putkistoinfrastruktuurin säädöstenmukaisuus': 'varmistaa putkisto#infrastruktuuri säädösten#mukaisuus huolehtia putkisto#infrastruktuuri säädösten#mukaisuus varmistaminen putki#johto#toiminto koskea sääntö noudattaa varmistaminen putkisto#infrastruktuuri toimeksianto putki kuljettaa hyödyke koskea määräys noudattaa',
#  'kertoa suuterveydestä ja sairauksien ehkäisystä': 'kertoa suu#terveys sairaus ehkäisy kertoa potilas suu terveys suu sairaus ehkäiseminen kertoa hammas harjaaminen hammas#väli puhdistaminen hammas#hoito menetelmä etu hammas#lääkäri valvonta ohje',
#  'mainostaa tuotteita mainoksissa': 'mainostaa tuote mainos osallistua mainos esitellä vaate asuste kauneuden#hoito#tuote tuote kuunnella valokuvaaja ohjaaja ohje',
#  'hoitaa anodisointikonetta': 'hoitaa anodisointi#kone hoitaa metallin#työstö#kone asema muodostaa anodi#elektrodi osa anodisointi#prosessi sisältyä käämi syöttö esi#käsittely puhdistus#säiliö anodisointi#säiliö jälki#käsittely hoito seurata käyttää prosessi määräys',
#  'asentaa metallikattoja': 'asentaa metalli#katta asentaa alus#kerros pää#katto päällyste#materiaali jää vesi#suoja muotoilla ruuvata kiinnitys#lista räystä kääntää reuna ruuvata metalli#paneeli varmistaa että#ei mennä viimeistellä katto kiinnittää kiinnitys#lista liitos#kohta',
#  'kehittää liikekumppanuuksia': 'kehittää liike#kumppanuus kehittää liike#suhde luoda suhde organisaatio osa#puoli tavara#toimittaja jakelija osakkeen#omistaja sidos#ryhmä antaa tieto organisaatio tavoite',
#  'uskontotiede': 'uskonto#tiede käyttäytyminen vakaumus instituutio koskea tutkimus perustua ala antropologia sosiologia filosofia menetelmä',
#  'suorittaa lastaamis- ja purkamistoimintoja': 'suorittaa lastaaminen purkaa#toiminto lastata purkaa säiliö materiaali käsi väline lastata tavara sup#pila säiliö syöttö#kone kuljettaa tuote käyttää haarukka#trukki ruuvi#kuljetin imu#portti lapio hanko',
#  'koristella kynsiä': 'koristella kynsä käyttää teko#kynsä lävistys koriste mukauttaa malli asiakas kynsä koristelu',
#  'geofysiikka': 'geofysiikka tieteen#ala käsitellä maa#pallo koskea prosessi ominaisuus geofysiikka käsitellä ilmiö analyysi magneetti#kenttä maa rakenne vesi kierto#kulku',
#  'arvioida osakkeen arvo': 'arvioida osake arvo yritys osake arvo analysointi laskeminen arviointi menetelmä käyttö arvo määrittäminen muuttuja huomio ottaa',
#  'tunnistaa uusien mallien kohdemarkkinat': 'tunnistaa malli kohde#markkinat kohde#markkinat määrittäminen ottaa huomio tekijä ikä suku#puoli asema',
#  'kaupunkialueilla käytettävien ajoneuvojen mekaaniset vaatimukset': 'kaupunki#alue käyttää ajo#neuvo vaatimus vaatimus tunteminen ajo#neuvo täyttää toimia kaupunki#alue ajo#neuvo osa#järjestelmä osa tarkastaminen kunnos#sapito ajo#neuvo turvallisuus luotettavuus ajo#mukavuus varmistaminen',
#  'valmistaa tilaukset': 'valmistaa tilaus valmistaa ruoka juoma tilaus valmistaa asiakas ruoka juoma#tilaus ruoka juoma#tilaus valmistaminen asiakas tarjoilla',
#  'tarkastaa virallisia asiakirjoja': 'tarkastaa asia#kirja tarkastaa henkilö asia#kirja ajo#kortti henkilöllisyys#todistus varmistaa lain#säädäntö noudattaa tunnistaa arvioida henkilö',
#  'antaa tukea sopeutumisessa fyysiseen vammaan': 'antaa tuki sopeutuminen vamma auttaa henkilö sopeutua vamma seuraus ymmärtää vastuu riippuvuus',
#  'analysoida kokeellisia laboratoriotuloksia': 'analysoida laboratorio#tulos analysoida tieto tulkita tulos laatia havainto raportti yhteen#veto',
#  'ostaa automateriaaleja': 'ostaa auto#materiaali ostaa ajo#neuvo materiaali hankkia tilata auto osa tarvike ajo#neuvo kori linja#auto rakentaminen',
#  'tarkistaa kaiverruksen tarkkuus': 'tarkistaa kaiverrus tarkkuus tarkistaa kaiverrus tarkkuus työstää kaiverrus tarvita',
#  'kehittää ratkaisuja haitalliseen käytökseen': 'kehittää ratkaisu käytös tutkia käyttö tupakointi kehittää strategia menetelmä ehkäiseminen ratkaiseminen',
#  'tehdä virkistystilojen käyttöaikataulu': 'tehdä virkistys#tila käyttö#aika#taulu laatia aika#taulu virkistys#tila käyttö',
#  'suunnitella sairaanhoitoa': 'suunnitella sairaan#hoito suunnitella hoito päättää tehtävä hoito#toimi kiinnittää huomio terveys#kasvatus ennalta#ehkäistä toimen#pide varmistaa hoito jatkuvuus kattavuus',
#  'hydrografia': 'hydrografi meren#kartoitus tieteen#ala tutkia mitata vesistö valta#meri järvi joki ominaisuus nyky#tilanne tarkastelu navigointi#tarkoitus muutos#ennuste laatiminen tulevaisuus',
#  'valaa korumetalleja': 'valaa koru#metalli kuumentaa sulattaa korumateriaali kaataa materiaali muotti koru#metalli valaminen käyttää korun#valmistus#väline ruuvia#vaima pihti puristin',
#  'pitää varasto järjestyksessä': 'varasto järjestys huolehtia varasto siisteys varasto pohja#piirros suunnittelu toteutus järjestys takaaminen korjaus korvaus#toimen#pide määrääminen',
#  'puhua julkisesti': 'puhua kuuntelija#ryhmä puhuttelu tiedottaminen heät vaikuttaminen vakuuttaminen',
#  'kiinnittää aluksia laituriin': 'kiinnittää alus laituri kiinnittää alus laituri vakio#menettely hallita viestintä alus ranta',
#  'oikomishoito': 'oikomis#hoito hammas oikomis#hoito hammas epä#säännöllisyys ehkäisy korjaus#toimi tutkia diagnosoida hoitaa purenta#vika suuontelo poikkeavuus hammas#rauta apu',
#  'järjestää työnhaun työpajoja': 'järjestää työ#haku työ#paja ryhmä#työ#tilaisuus järjestäminen työ#hakija opettaa työ#haku#tekniikka auttaa parantaa ansio#luettelo haastattelu#taito',
#  'käyttää pumppauslaitteita': 'käyttää pumppaus#laite pumppaus#laite käyttö kaasu öljy kulkeutuminen valvominen poraus#kaiva jalostamo varasto',
#  'viljellyt helmet': 'viljellä helmi helmä valmistus#prosessi asettaa kangas osteri luoda helmä valvoa olo#suhteet syntyä luonnon#helma',
#  'hankkia keskeisiä tietoja projekteista': 'hankkia tieto projekti kehittää idea keskustella vaatimus asiakas tiedotus#tilaisuus määrittää hanke aika#taulu',
#  'syöttää materiaaleja uuniin': 'syöttää materiaali uuni ladata materiaali uuni varmistaa sijainti kiinnitys tasa#painotus tarvita',
#  'sekoittaa ainesosia lateksiin': 'sekoittaa aines#osa lates sekoittaa määrittää yhdiste lates käyttää sekoitin',
#  'puhdistaa ilmastointijärjestelmiä': 'puhdistaa ilmastointi#järjestelmä poltto ilmastointi#järjestelmä liittyä laite puhdistus palamis#jäte poistaminen hakata raapia polttaa',
#  'täyttää öljylähdettä koskevia tietolomakkeita': 'täyttää öljy#lähde koskea tieto#lomake valmistella öljy#lähde koskea tieto#lomake laatia tieto#lomake luetella tieto öljy#lähde lukea sijainti resurssi tyyppi lämpö#tila analyysi tehdä lähde syvyys',
#  'louhintatekniikat': 'louhinta#tekniikka kaivaus#tekniikka maan#kaivaa#tekniikka kivi maa#perä poisto#menetelmä käyttää louhos liittyä riski',
#  'seurata henkilökunnan poissaoloja': 'seurata henkilö#kunta poissaola seurata työ#tekijä lomi sairaus#poissaola poissaola kirjata arkistoida asia#kirja todistus',
#  'asentaa laskettu sisäkatto': 'asentaa laskea sisä#katto asentaa katto#tiili valmistella profiili erottaa katto jäädä tila',
#  'mausteiden valmistusprosessit': 'mauste valmistus#prosessi mauste mauste#valmiste valmistus#prosessi tekniikka tekniikka majoneesi etikko mauste#yrtti tuote tuottaminen',
#  'valmistaa puolijohdekiteitä': 'valmistaa puoli#johdekide ladata uuni puoli#johde raaka#materiaali piisi sula piisi pyörittää upokas lisätä silikonikide#alkio pyörittää suunta sulaa pii antaa jäähtyä kide#alkio poistaa tulos saada puoli#johde#kide halkaisija milli#metri',
#  'käyttää betoniharkkojen valukonetta': 'käyttää betoni#harkka valu#kone käyttää betoni#harkka valu#kone varmistaa lajittelu pinoaminen#malli noudattaa',
#  'käyttäytyä hillitysti': 'käyttäytyä käyttäytyä huomio',
#  'estää petollista toimintaa': 'estää toiminta kauppa#toimi toiminta tunnistaminen estäminen',
#  'käyttää merenkulun englantia': 'käyttää meren#kulu englanti viestiä englanti käyttää tilanne laiva satama laivaus#ketju',
#  'valmistaa kolmiulotteisia jalkineprototyyppejä tietokoneavusteisesti': 'valmistaa jalkine#proto#tyyppi valmistaa 3D#jalkine#proto#tyyppi pystyä lukea ymmärtää elementti suunnitelma tieto#kone laatia luonnos kuva piirros digitoida skannata lesti luoda lesti muoto vastata malli asiakas mitta#vaatimus tehdä jalkine 3D#mallinnus käyttää CAD#ohjelma toiminnallisuus virtuaali#kuva tuottaminen käsittely testaus jalkine 3D#suunnittelu tuottaa malli kehittää malli mallisto tehdä esittely#kuva kuvasto',
#  'putkikuljetusta koskevat määräykset': 'putki#kuljetus koskea määräys putki#kuljetus koskea määräys tunteminen soveltaminen putki#ala putki#kuljetus koskea määräys soveltaminen toimi#paikka rakentaminen',
#  'hoitaa tiilipuristinta': 'hoitaa tiili#puris#tinta hoitaa tiili#puris#tinta puristaa savi#tuote tiili putka',
#  'asentaa ikkuna': 'asentaa ikkuna ikkuna asettaminen valmistella paikka seinä seinä peittää ikkuna tapaus lattia mittaus#väline käyttäminen varmistaminen ikkuna linja',
#  'käyttää irrotusveistä': 'käyttää irrotus#vie käyttää painatus pinnoitus#prosessi irrotus#vie paino#väri poistaminen',
#  'dokumentoida turvatoimenpiteet': 'dokumentoida turva#toimen#pide kirjata terveys turvallisuus parantaminen toteuttaa toimi arviointi vaara#tilanne#selvitys suunnitelma riski#narviointi',
#  'erottaa epävakaat elementit vedessä': 'erottaa elementti vesi käyttää laite erottaa vesi elementti rauta rikki#yhdiste suodattaa dekantoida',
#  'nähtävyystiedot': 'nähtävyys#tieto tieto nähtävyys antaa matkailu#tieto matkailu#kohde nähtävyys#tieto',
#  'tehdä aistinvaraista arviointia': 'tehdä arviointi arvioida ruoka juoma laatu ulko#näkö haju maku ominaisuus peruste ehdottaa parannus vertailla tuote tuote',
#  'kirkastaa öljyä saostamalla': 'kirkastaa öljy saostaa kirkastaa öljy saostaa antaa öljy seistä öljy#tynnyri astia päivä aine laskeutua astia pohja kaataa saostuminen pinta nousta öljy astia kasvi#jäte jäädä astia pohja saostua aine kutsua sakka',
#  'selittää bingon säännöt': 'selittää binko sääntö selittää binko sääntö yleisö peli',
#  '3D-tulostusprosessi': '3D#tulostus#prosessi prosessi jäljentää 3D#esine 3D#tulostus#tekniikka',
#  'antaa työntekijöille toiminnan tehostamiskoulutusta': 'antaa työ#tekijä toiminta tehostaa#koulutus antaa työ#tekijä toiminta tehokkuus koskea koulutus antaa työ#tekijä resurssi valmistella koulutus työ#paja tehostaa varasto#työskentely',
#  'vähentää putkijohtohankkeiden ympäristövaikutuksia': 'vähentää putki#johto#hanke ympäristö#vaikutus pyrkiä lieventää putki#johto kuljettaa tavara ympäristö#vaikutus investoida aika resurssi putki#johto ympäristö#vaikutus ympäristön#suojelu#toimi hanke kustannus kasvu huomio ottaminen',
#  'nahkatuotteiden rakenneosat': 'nahka#tuote rakenne#osa nahka#materiaali nahka#tavara osa käsittely käyttää menettely menetelmä valmistettavuus ominaisuus',
#  'huolehtia omasta ulkonäöstä': 'huolehtia ulko#näkö antaa kuva varmistaa ulko#näkö valita asu imago ulko#asu huolehtia vaikutus antaminen',
#  'kehittää strategisia suunnitelmia fysioterapiapalveluille': 'kehittää suunnitelma fysioterapia#palvelu osallistuminen järjestelmä toiminta#linja menettely kehittäminen fysioterapia#palvelu tarjoaminen tietämys jakaminen oppia#mahdollisuus edistäminen',
#  'suunnitella rakennusten huoltotoimia': 'suunnitella rakennus huolto#toimi suunnitella rakennus#huolto aika#tauluttaa kiinteistö järjestelmä palvelu ylläpito#toimi rakennus asiakas paino#piste tarve',
#  'pakata tuotteita lahjapakettiin': 'pakata tuote lahja#paketti lahja#paka kauppa#tavara pakata tuote lahja#paketti asiakas pyyntö',
#  'korjauttaa varusteita': 'korjauttaa varuste huolehtia varuste korjaus olla',
# ...
#  'varastoida elintarvikkeiden raaka-aineita': 'varastoida elin#tarvike raaka#aine säilyttää elin#tarvike raaka#aine varastoida elin#tarvike varastoida raaka#aine varastoida elin#tarvike raaka#aine varastoida raaka#aine säilyttää raaka#aine säilyttää elin#tarvike pitää varasto raaka#aine elin#tarvike noudattaa varaston#hallinta menettely',
#  'analysoida elimistön nesteitä': 'analysoida elimistö neste testata näyte ihminen ruumi#innesti veri virtsa määrittää entsyymi hormoni aine#osa veri#tyyppi luovuttaa veri yhteen#sopiva vastaanottaja',
#  'hygienia terveydenhuollossa': 'hygienia terveyden#huolto menettely ylläpitää ympäristö hoito#laitos sairaala klinikka käsi pesu käyttää laite puhdistaminen desinfiointi infektio torjunta#menetelmä',
#  'Puppet (työkalut ohjelmiston kokoonpanon hallintaan)': 'työ#kalu ohjelmisto kokoonpano hallinta ohjelmisto#ohjelma tehdä konfigurointi määrittäminen valvonta tila#kirjan#pito tarkastus tehtävä',
#  'synnytys': 'synnytys synnytys#prosessi synnytys merkki vauva ulos#työntäminen liittyä vaihe prosessi lukea komplikaatio syntymä',
#  'johdinautojen mekaniikka': 'johdin#auto mekaniikka johdin#auto mekaniikka ymmärtäminen toiminta#häiriö ilmoittaa teknikka osa#puoli tietäminen sähkö#moottori varustaa johdin#auto diesel#moottori tuottaa lähtö vääntö#voima etu mäki nouseminen poltto#moottori sähkö#moottori saada voima keskus#laitos yli#kuormittaa aika vahingoittaa',
#  'järjestää sisäänpääsy nähtävyyksiin': 'järjestää sisäänpääsy nähtävyys hoitaa varaus etu#käteis#maksu vastata varaus etu#käteis#maksu jakaa tieto#esite huolehtia sisäänpääsy nähtävyys jaella tieto#esite järjestää sisäänpääsy aktiviteetti nähtävyys järjestää maksu ennakko#varaus jakaa',
#  'kehittää kaupungin markkinointikonsepteja': 'kehittää kaupunki markkinointi#konsepti kuvata alue kaupunki levitä idea keksiminen asukas sijoittaja turisti houkutteleminen kaupunki keskusta muuttaminen kävely#katu kulttuuri#tapahtuma järjestäminen',
#  'käsitellä lentopaikkaa koskevia mahdollisia vaaroja': 'käsitellä lento#paikka koskea vaara käsitellä lento#paikka koskea vaara esine roska eläin aiheuttaa häiriö',
#  'haketintyypit': 'haketin#tyyppi kone puu osa oksa runko tehdä hake haketin ominaisuus',
#  'lyönti': 'lyönti rahan#lyönti metalli#osa kolikko mitali merkki nappi valmistus puristaa osa meisti',
#  'harjoittaa hahmoterapiaa': 'harjoittaa hahmote#rapia käyttää hahmote#rapia tekniikka tuoli liioittelu#harjoitus yksilö ryhmä#ympäristö hyödyntää harjoitus kokeilu tarkoitus saada yksilö ymmärtää risti#riita kokemus mielen#terveys#ongelma näkö#kohta',
#  'tiedottaa koroista': 'tiedottaa korko ilmoittaa lainan#ottaja laina korko#prosentti kompensoida varallisuus lainata raha käyttö kustannus lainan#antaja',
#  'nuorten sosialisaatiokäyttäytyminen': 'nuori sosialisaatio#käyttäytyminen dynamiikka välitys aikuinen vuoro#vaikutus ilmaista mieltymys vasten#mielisyys suku#polvi viestintä koskea sääntö',
#  'suunnitella tuulipuiston keräysjärjestelmiä': 'suunnitella tuuli#puisto keräys#järjestelmä suunnitella tuuli#voima#puisto keräys#järjestelmä suunnitella järjestelmä yhdistää turbiini tuuli#puisto kerätä energia siirtää sähkö#asema mahdollistaa tuottaa sähkö#energia siirto varmistaa järjestelmä yhdistää turbiini sähköasta tapa',
#  'yritysanalyysi': 'yritys#analyysi liike#toiminta#analyysi tutkimus#ala selvittää liike#toiminta tarve ongelma ratkaisu lieventää ehkäistä liike#toiminta toiminta liike#toiminta#analyysi kuulua tieto#tekniikka#ratkaisu markkina#haaste politiikka kehittäminen kysymys',
#  'työskennellä yhteisöissä': 'työskennellä yhteisö perustaa hanke tavoite yhteisö kehittäminen kansalainen osallistuminen',
#  'nitoa arkkeja': 'arkki avata nippu asettaa kone syöttö#varsi ommella kiinnittää esi#lehti harso kirja nippu kuulua liima levittäminen kirja sidonta#reuna kirjan#sidonta',
#  'kuormata kappaletavararekkoja': 'kuormata kappale#tavara#rekko kappale#tavara#rekko lastaaminen reitti valinta liittyä tehtävä suorittaminen',
#  'tutkia uusia keittotapoja': 'tutkia keitto#tapa arvioida ruoka#valmistus#menetelmä osallistua tutkimus#toiminta tarkoitus kehittää parantaa elin#tarvike#teknologia prosessi',
#  'järjestää eläintieteellisiä näyttelyitä': 'järjestää näyttely näyttely järjestäminen eläin kokoelma esittely',
#  'mainostaa itseään': 'mainostaa markkinoida taito tietämys',
#  'hallita äänenlaatua': 'hallita äänen#laatu tehdä soinnin#tarkastus asettaa audio#laite äänen#tuotto esitys aika säädellä äänen#voimakkuus lähetys aika ohjata audio#laite',
#  'korkokuvioida': 'korko#kuvio malli kohottaminen korko#kuviointi prosessi syventää malli pakottaa materiaali pinta saada aika vaikutus materiaali ulko#näkö',
#  'hallita projektitietoja': 'hallita projekti#tieto asiaankuulua tieto antaminen hanke olla osa#puoli',
#  'lisääntymisterveys': 'lisääntymis#terveys lisääntyä#prosessi toiminto järjestelmä elin#vaihe olo#suhteet raskaus ehkäisy suku#puoli#tauti nainen suku#elin silpominen',
#  'huolehtia toimitusten asiakirjoista': 'huolehtia toimitus asia#kirja hoitaa toimitus paperi#työ huolehtia asia#kirja toimitus koskea tieto liittää toimittaa tavara varmistaa tunniste#tieto säännös tarkastaa merkintä tuote#määrä määrä#paikka malli#numero',
#  'johtaa ryhmiä ulkona': 'johtaa ryhmä järjestää dynaaminen ulko#aktiviteetti',
#  'luoda digitaalisia kuvia': 'luoda kuva luoda prosessoida kuva esittää esine kuvata prosessi käyttää animaatio mallintaa#ohjelma',
#  'tarkastaa valmiit sopimukset': 'tarkastaa sopimus tarkistaa sopimus sisältö tarkastaa sopimus oikeellisuus',
#  'tarkastaa kelloja': 'tarkastaa kello kello osa tarkastaminen viko heikkeneminen vaurio mittari tarkastus mittaus testaus#laite',
#  'eri kuljetustapojen markkinat': 'kuljetus#tapa markkinat liikenne#muoto markkina#mahdollisuus tunteminen',
#  'jalokivet': 'jalo#kivi mineraali luutua materiaali tyyppi hiota kiillottaa koru käyttää luokitella tyyppi ominaisuus arvo',
#  'harjoitella tanssimista säännöllisesti': 'harjoitella tanssiminen osallistua harjoitus kurssi pätevyys kyky kunto varmistaminen tunnistaa työ vaatimus harjoittelu suunnitella',
#  'muokata valokuvia': 'muokata valo#kuva muokata valo#kuva koko parannella retusoida käyttää väri kuvan#käsittely#ohjelmisto tekniikka',
#  'soittaa pianoa': 'soittaa piano soittaa piano harjoitus#pianiste',
#  'hoitaa lasten ongelmia': 'hoitaa lapsi ongelma lapsi ongelma ehkäisy havaitseminen hallinta edistäminen keskittyä kehitys#viive häiriö käytös#ongelma häiriö stressi aiheuttaa tilanne mielen#terveys#häiriö masennus ahdistuneisuus#häiriö',
#  'säätää kuulolaitteita': 'säätää kuulo#laite ohjelmoida kuulo#laite tieto#kone sovittaa jakaa kuulo#laite asentaa sisä#korvaistute kuulo parantaminen tarkoittaa laite',
#  'terveysarkistojen hallinta': 'terveys#arkisto hallinta Terveyden#huolto#järjestelmä sairaala klinikka kirjan#pito menettely merkitys tieto säilyttäminen käsittely käyttää tieto#järjestelmä tieto tarkkuus saavuttaa',
#  'työskennellä kuuman typen parissa': 'työskennellä typpi työskennellä typpi syöttää kuivain#sarja',
#  'ottaa käyttöön kuljetusstrategia': 'ottaa käyttö kuljetus#strategi ennakoida yritys kuljetus#strategia liittyä tarve tavoite toteuttaa strategia tieto pohja',
#  'antaa tietoja ennen hoitotoimenpiteitä': 'antaa tieto hoito#toimen#pide hoito#vaihto#ehto mahdollisuus selittäminen potilas tehdä harkita päätös',
#  'käyttää lasinkaiverrusvälineitä': 'käyttää lasin#kaiverrus#väline kaiverrus#työ#kalu käyttäminen käyttää teräs kivi kupari#pyörä lasi lasi#tavara tyyppi',
#  'noudattaa sosiaalisesti oikeudenmukaisia työskentelyperiaatteita': 'noudattaa työskentely#periaate johto organisaatio asettaa ihmis#oikeus oikeuden#mukaisuus koskea periaate arvo työskentely',
#  'valvoa lentoaseman ylläpitotoimia': 'valvoa lento#asema yllä#pito#toimi valvoa lento#asema henkilöstö toimi kunnossa#pito lento#kone tankkaus lento viestintä kiito#tie kunnossa#pito',
#  'rautateiden fyysiset ominaisuudet': 'rauta#tie ominaisuus rauta#tie osa rauta#tie#asema liikenne#väylä kallistuminen aleneminen nopeus#rajoitus tunteminen',
#  'säätää nesteytyslämpötilaa': 'säätää nesteytys#lämpö#tila säätää termostaatti saada vaha nesteyttäminen koskea spesifikaatio lämpö#tila',
#  'kehittää taiteellinen verkosto': 'kehittää verkosto levittää tieto esitys tapahtuma suhde#toiminta liittyä aloite apu luoda musiikki#ala yhteys#henkilö#verkosto levittää tieto esitys',
#  'korjata kuntoiluasiakkaiden tekniikkaa': 'korjata kuntoilu#asiakas tekniikka tarkkailla kuntoilu#asiakas ehdottaa korjaus mukautus vaatia varmistaminen tekniikka ominaisuus ryhti liike#rata liike hallinta ajoitus asento',
#  'käyttää syväkudoshieronnan tekniikoita': 'käyttää syvä#kudos#hieronta tekniikka soveltaa menetelmä paine tarkoitus vaikuttaa elimistö kudos#kerros',
#  'pysyä ajan tasalla psykoterapian kehitystrendeistä': 'pysyä aika psykoterapia kehitys#trendi seurata mielen#terveys#palvelu suuntaus koskea keskustelu psykoterapia liittyä ajattelu#tapa muutos teoria vuoro#vaikutus pysytellä aika terapia psykoterapia#palvelu kysyntä lisääntyminen seurata näyttö perustua tutkimus tuntea psykoterapia vaikuttavuus koskea mittari tutkimus tarvita',
#  'asentaa julkisivuverhous': 'asentaa julki#sivu#verhous julki#sivu peittää materiaali paanu liuske#kivi metalli valmistaminen leikata porata taivuttaa karsia kiinnitys#tekniikka käyttö materiaali',
#  'puhdistaa automaatit': 'puhdistaa automaatti puhdistaa myynti#automaatti myynti#automaatti puhtaus ylläpito puhdistus#väline käyttää',
#  'ennustaa kädestä': 'ennustaa käsi tulkita asiakas kämmenen kämmen ominaisuus tulkita ominaisuus järjestelmä kämmen rakenne joustavuus antaa lausunto henkilö persoonallisuus motivaatio elämä vaikkua tapahtuma',
#  'hyväksyä oma vastuullisuus': 'hyväksyä vastuullisuus ottaa vastuu ammatti#toiminta tunnistaa toimi#ala toimi#valta raja',
#  'käyttää tieteellisiä menetelmiä': 'käyttää menetelmä käyttää menetelmä tekniikka ilmiö tutkiminen hankkia tieto korjata yhdistää olla olla tieto',
#  'huolehtia aluksen konehuoneen huollosta': 'huolehtia alus kone#huone huolto huolehtia alus kone#huone kunnossa#pito huolehtia alus moottori kone#huone varustus tehdä tarkastus lähtö tutkimus matka aika',
#  'luoda tietomalleja': 'luoda tieto#malli luoda data#malli hallita data#malli hallita tieto#malli hallita data malli hallita tieto malli käyttää tekniikka menetelmä analysoida organisaatio liike#toiminta#prosessi tieto#vaatimus luoda tieto koskea malli malli malli rakenne muoto',
#  'käyttöjärjestelmän varmuuskopioinnin suositeltava käytäntö': 'käyttö#järjestelmä varmuus#kopiointi suositella käytäntö järjestelmä varmuus#kopiointi käytäntö tieto#järjestelmä varmuus#kopiointi käytänne järjestelmä varmuus#kopiointi keino järjestelmä varmuus#kopiointi toiminta#tapa menettely valmistautua organisaatio kanta teknologia#infrastruktuuri palauttaminen jatkaminen',
#  'käyttää sellunvalmistuksen ohjauslaitetta': 'käyttää sellu#valmistus ohjaus#laite asentaa käyttää ylläpitää laite tarkoittaa ohjata sellu#valmistus puu kierrätys#paperi sellulo#osa raaka#aine',
#  'dokumentoida haastatteluita': 'dokumentoida haastattelu kirjata kirjoittaa merkitä muisti vastaus kuulustelu yhteys kerätä tieto käsittely analysointi pika#kirjoitus väline käyttää',
#  'estää sälöytymistä puuntyöstössä': 'estää sälöytyminen puun#työstö käyttää tekniikka estää puumateriaali sälöytyminen saada pinta näyttää vaurioitunut alentaa tuote arvo',
#  'käyttää metallilevysaksia': 'käyttää metalli#levysas käyttää levysas käyttää metalli#levysas leikata metalli#levy',
#  'tutkia mahdollisia tuulipuistojen sijaintipaikkoja': 'tutkia tuuli#puisto sijainti#paikka tehdä tutkimus paikka käyttää tuuli#kartta arvioida tuuli#puisto rakentaminen soveltua sijainti tehdä seuranta#tutkimus paikka rakennus#suunnitelma laatiminen tuki',
#  'terveyspsykologian ammatillisen harjoittamisen edellytykset': 'terveys#psykologia harjoittaminen edellytys terveys#psykologia käytäntö edellytys tarkoitus soveltaminen psykologia harjoittaminen terveyden#huolto',
#  'putkityypit': 'putki#tyyppi putki#tyyppi putkisto#materiaali PVC PEX kupari etu käyttö#tapaus riski kustannus',
#  'käyttää kaavinvaunua': 'käyttää kaavin#vaunu käyttää kaavin#vaunu kaavin#vaunu kalusto kaapia maa maa pinta siirtää suppila',
#  'hoitaa turistiryhmiä': 'hoitaa turisti#ryhmä hoitaa matkailija#ryhmä toimi matka#opas opastaa matkailija opastaa turisti seurata opastaa matkailija varmistaa ryhmädynamiikka käsitellä esiintyä risti#riita ongelma',
#  'opettaa alan tekniikoita eteenpäin': 'opettaa ala tekniikka tieto osaaminen siirtäminen laite materiaali selittäminen esittely tuote valmistus koskea tekniikka koskea kysymys vastaaminen',
#  'antaa neuvontaa oikeudenkäyntistrategioista': 'antaa neuvonta oikeuden#käynti#strategia asian#ajaja tuomio#istuin virka#mies neuvominen tuomio#istuin#käsittely valmistelu auttaa argumentti valmistelu tutkia lauta#mies tuomari tausta antaa päätös koskea neuvo auttaa saavuttaa asiakas päätös asia',
#  'työskennellä vesiliikennetiimissä': 'työskennellä vesi#liikennetiin työskennellä vesi#liikenne#palvelu tarjota ryhmä henkilö toimia vastuu#alue tavoite saavuttaminen tavoite asiakas#vuoro#vaikutus meri#turvallisuus alus huolto',
#  'myydä käytettyä tavaraa': 'myydä käyttää tavara myydä käyttää tuote esitellä myydä kauppa olla tavara',
#  'valvoa junan liikkumista': 'valvoa juna liikkuminen valvoa kiihdyttäminen jarruttaminen liikkua juna toiminta kokonaisuus',
#  'laittomat aineet': 'aine kieltää aine kuljettaa alue henkilö saada kuljettaa luonne käsittely#tapa',
#  'suunnitella tavoitteita keskipitkästä pitkälle aikavälille': 'suunnitella tavoite keski#pitkä aika#väli laatia tavoite keski#pitkä aika#väli laatia tavoite keski#pitkä aika#väli suunnitella yhteys keski#pitkä aika#väli tavoite suunnitella tavoite keski#pitkä aika#väli asettaa aika#väli tavoite aika#väli tavoite aika#väli suunnittelu täsmäytys#prosessi',
#  'valmistella maa rakentamista varten': 'valmistella maa rakentaminen eritelmä täyttää materiaali valinta paikka valmistelu eritelmä',
#  'arvioida omia työskentelymenetelmiä': 'arvioida työskentely#menetelmä työskentely arviointi työskentely#menetelmä saavuttaa tulos valvonta tarkastelu tapa soveltua menetelmä tunteminen johtaja esi#mies ammattilainen potilas /asiakas saada palaute käyttäminen toiminta mukauttaminen',
#  'valvoa pysäköintialueiden turvallisuutta': 'valvoa pysäköinti#alue turvallisuus seurata pysäköinti#alue saapumis poistumis#reitti ilmoittaa vaara onnettomuus rikkomus',
#  'vastata karjanjalostukseen liittyvistä tehtävistä': 'vastata karjan#jalostus liittyä tehtävä huolehtia karjan#jalostus liittyä toimi hallita karjan#kasvatus soveltua ympäristö valita valmistella nauta#eläin sopia elin#ympäristö seurata karja kasvu terveys varmistaa ruokinta määrittää nauta teurastaa syödä kauppa tarkoitus',
#  'rakennusteollisuus': 'rakennus#teollisuus rakennus#ala tuote tuote#merkki toimittaja',
#  'käyttää lääketieteellisen kuvantamisen tekniikoita': 'käyttää kuvantaminen tekniikka käyttää kuvantaa#tekniikka röntgen#säde ultraään potilas kehon#osa tarkasteleminen käyttää tarkoitus teknologia laite',
#  'tanssityylin ja musiikkityylin välinen yhteys': 'tanssi#tyyli musiikki#tyyli yhteys harjoittaa tanssi#tyyli suhde musiikki rakenne muusikko',
#  'hoitaa neulekonetta': 'hoitaa neule#kone käyttää neule#kone pitää tehokkuus tuottavuus taso',
#  'koota polkupyöriä': 'koota polku#pyörä kasata polku#pyörä sovittaa polku#pyörä osa varmistaa osa kiinnittää polku#pyörä asentaa pyörä tarvike nopeus#mittari valo pullon#pidike',
#  'opastaa työntekijöitä': 'opastaa työ#tekijä ohjata työ#tekijä työ#tekijä suoritus#kyky yllä#pitäminen parantaminen valmentaa henkilö ryhmä optimoida menetelmä taito kyky käyttää tarkoitus mukauttaa valmennus#tyyli menetelmä palvelus ottaa työ#tekijä ohjaaminen liike#toiminta#järjestelmä opettaminen',
#  'kivikeramiikan valmistuksessa käytettävät materiaalit': 'kivike#ramiikka valmistus käyttää materiaali kivike#ramiikka tapaus tulenkestä savi valmistaa keramiikka tuotanto käyttää materiaali ominaisuus',
#  ...}

# %%
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(list(documents.values()))

# %%
# Here you only want to use vectorizer.transform and not fit_transform since the tfidf vectorizer has already been fitted with all the descriptions
def cosine_similarity(text1, text2):
    tmp = vectorizer.transform([text1, text2])
    return ((tmp * tmp.T).A)[0, 1]

# %%
def get_similarities(text):
    text_lemmatized, _ = lemmatize(text)
    text_preprocessed = ' '.join(text_lemmatized)
    
    similarities = {}
    
    for key, value in documents.items():
        similarities[key] = cosine_similarity(text_preprocessed, value)

    return similarities

# %%
d = get_similarities('hyviä vuorovaikutustaitoja')
d_sorted = dict(sorted(d.items(), key=lambda item: item[1], reverse=True))
d_sorted
# Out:
# {'osoittaa sosiaalisia taitoja': 0.6608136840197328,
#  'molekyylibiologia': 0.6316587700513385,
#  'ohjelmiston vuorovaikutuksen suunnittelu': 0.560586210675245,
#  'opettaa yrityksessä tarvittavia työskentelytaitoja': 0.5445002795457043,
#  'ihmisen ja tietokoneen välinen vuorovaikutus': 0.5309527189603742,
#  'aikatauluttaa vuorot': 0.4457319714703615,
#  'tukea sosiaalipalveluiden käyttäjiä taitojen hallinnassa': 0.43563269312051395,
#  'hallita kaivojen vuorovaikutusprosessit': 0.4341653421692856,
#  'olla huomaavainen': 0.4142654521289544,
#  'lääkkeiden vaikutuksen hallinta': 0.409578079760355,
#  'koordinoida vuoroja': 0.40503967335243735,
#  'suunnitella käyttöliittymää': 0.3983804807191749,
#  'käyttää kliinistä kiropraktista ammattitaitoa urheiluvammojen hoitamiseen': 0.3947580856896732,
#  'olla vuorovaikutuksessa kohdeyhteisön kanssa': 0.37789049390818774,
#  'työskennellä vuoroissa': 0.36406654984586645,
#  'järjestää harjoituksia motoristen taitojen kehittämiseksi': 0.3607894324947602,
#  'hallita toimintojen ympäristövaikutuksia': 0.3577027101807809,
#  'käyttää matemaattisia taitoja': 0.3571189130549677,
#  'parantaa vuorovaikutusta asiakkaiden kanssa': 0.35483368469659293,
#  'radiobiologia': 0.35345859492787324,
#  'arvioida käyttäjien vuorovaikutusta ICT-sovellusten kanssa': 0.3366460608174318,
#  'kaviteettioptomekaniikka': 0.3350442105454349,
#  'käyttää edistyneitä kliinisiä taitoja': 0.33457123770528424,
#  'tukea palveluiden käyttäjiä taitojen kehittämisessä': 0.3261078282376521,
#  'ekologia': 0.32082174365068383,
#  'opettaa taloudenhoitotaitoja': 0.31561238574864714,
#  'esiintyä julkisessa tilassa': 0.31453857341890235,
#  'suunnitella työntekijöiden vuoroja': 0.30221594030584525,
#  'ihmisen fysiologia': 0.300315068829746,
#  'luovuttaa ruoanvalmistustila seuraavalle vuorolle': 0.29931491375951425,
#  'hallinnoida ympäristövaikutuksia': 0.2967980450114281,
#  'hevosen anatomia': 0.29464992276381696,
#  'toimia turvallisesti eläinten kanssa': 0.29443264248193624,
#  'ekosysteemit': 0.2932502854880068,
#  'eläinbiologia': 0.29144097849219053,
#  'alusten sähköjärjestelmät': 0.28812877738202214,
#  'hoitaa aluksen vahtivuorot turvallisesti': 0.28191248822743076,
#  'valvoa henkilöstön töitä eri vuoroina': 0.28093681763915934,
#  'sähkömagnetismi': 0.28083614217154407,
#  'biologia': 0.2792585144885672,
#  'analysoida eri työpaikkojen ergonomiaa': 0.27842361443469443,
#  'luovuttaa palvelualue': 0.27805652868068526,
#  'hoitaa konevahtivuorot turvallisesti': 0.27598105116346083,
#  'hajautettu tietojenkäsittely': 0.2750842175901731,
#  'julkinen talous': 0.27494659910258973,
#  'arvioida omia taitoja yhteisötaideprojektien johtamisessa': 0.2716013389012788,
#  'tunnistaa puutteita taidoissa': 0.26877446013242845,
#  'välittää tietoja työvuorojen välillä': 0.26834924140226096,
#  'eläintenpidon sosiokulttuuriset kontekstit': 0.26653265420730626,
#  'autismi': 0.26593487920134007,
#  'sosiaalisen ympäristön vaikutus terveyteen': 0.26118129288271297,
#  'kemia': 0.26064696924919917,
#  'junan pyörän ja kiskon välinen kontakti': 0.2592241934493559,
#  'matkailun ympäristövaikutukset': 0.25766390402004297,
#  'työskennellä ammattimaisessa urheiluympäristössä': 0.2572866844470167,
#  'käyttää kliinisiä fysioterapiataitoja': 0.2557559101448328,
#  'opettaa sirkustemppuja': 0.25567417927910396,
#  'mainostaa itseään': 0.25457354460020215,
#  'osoittaa soittotaitoa': 0.25405245493304585,
#  'retoriikka': 0.2516435044266735,
#  'seurata yhteiskunnallisia vaikutuksia': 0.2508641192251338,
#  'koordinoida muotinvalmistuksen työvuoroja': 0.2499118443341359,
#  'hallita monikulttuurisia taitoja matkailu-, majoitus- ja ravitsemisalalla': 0.24984825398796076,
#  'arvioida sosiaalityöohjelmien vaikutuksia': 0.24948916782576339,
#  'arvioida esillepanon visuaalista vaikutusta': 0.24840819636313163,
#  'työskennellä kansainvälisissä ympäristöissä': 0.24622338187002168,
#  'kehittää ICT-laiteajuri': 0.2454626100266985,
#  'ilmoittaa lääkkeiden yhteisvaikutuksista farmaseutille': 0.24486537836575673,
#  'antaa systeemistä hoitoa': 0.24235267062021995,
#  'huolehtia lasten turvallisuudesta': 0.24129216992147529,
#  'koordinoida keernanvalmistuksen työvuoroja': 0.23961234930331402,
#  'edistää vuoropuhelua yhteiskunnassa': 0.2369505293476305,
#  'toimia vuorovaikutuksessa muiden näyttelijöiden kanssa': 0.23658153031333043,
#  'ravitsemustieteelliset lääkärintutkimukset': 0.23622423687433233,
#  'musiikkiterapeuttisten väliintulojen vaikutukset kehittymiseen': 0.1883140304867462,
#  'suunnitella nukkeja': 0.18828693678783245,
#  'harkita toimenpiteiden sosiaalisia vaikutuksia palvelun käyttäjiin': 0.18813130864039707,
#  'kemialliset tuotteet': 0.1875842384196138,
#  'ilmastonmuutoksen vaikutukset': 0.18756885904744933,
#  'mikrotaloustiede': 0.18620733856686358,
#  'kirjoittaa dialogeja': 0.18604891026137732,
#  'arvioida suunnitelman riskejä ja vaikutuksia': 0.1857927983086644,
#  'suunnitella vaatteita': 0.18533973716917207,
#  'käyttää kokemuskarttaa': 0.18365716107098803,
#  'suorittaa ICT-prosessien vaikutuksen arviointia liiketoimintaan': 0.18318945719351115,
#  'suorittaa ICT-käyttäjätutkimustoimia': 0.17976895015366723,
#  'tiedotusoppi': 0.17970790998939498,
#  'varmistaa lääketurvallisuus': 0.17867678363218892,
#  'opettaa asiakkaille viestintää': 0.1785427124192872,
#  'tarjota tietoa synnytyksen vaikutuksista seksuaalielämään': 0.17787142678256915,
#  'toimia vuorovaikutuksessa käyttäjien kanssa tarpeiden selvittämiseksi': 0.17735646653048834,
#  'tehdä erittely ominaisuuksista': 0.17692690295755528,
#  'avustaa fyysisten harjoitusten tekemisessä': 0.17680153214473276,
#  'hoitaa anestesian haittavaikutuksia': 0.1760222447555471,
#  'osallistuva havainnointi': 0.17580442665311657,
#  'vähentää putkijohtohankkeiden ympäristövaikutuksia': 0.17511886353726122,
#  'koirien käyttäytyminen': 0.1734730884735935,
#  'sääilmiöiden vaikutukset kaivostoimintaan': 0.17309462358888322,
#  'hunajan aineosat': 0.17305283474771105,
#  'pärjätä haastavissa olosuhteissa': 0.17218283525567613,
#  'luonnollisen kielen käsittely': 0.17216114150832346,
#  'osoittaa muiden kulttuurien tuntemusta': 0.17178504501112934,
#  'esittää improvisaatiota': 0.17172435818921472,
#  'kalatuotteiden laatu': 0.17161848710166328,
#  'arvioida pohjavedenoton ja -käytön ympäristövaikutuksia': 0.17106201167645654,
#  'taideterapian harjoittamistekniikat': 0.1701240261836147,
#  'hallinnoida yritysten koulutusohjelmia': 0.16947631052701256,
#  'tukea kalastustoiminnan koulutuskäytäntöjä': 0.16906549943627097,
#  'farmakokinetiikka': 0.16835394412218563,
#  'yhtiöoikeus': 0.16807716375880044,
#  'pitää kirjaa asiakasyhteyksistä': 0.1675339376236512,
#  'antaa lääkkeitä koskevia neuvoja': 0.16686676635532344,
#  'parantaa opiskelijoiden kokeista suoriutumistaitoja': 0.1661500300692194,
#  'arvioida työtunteja tarkasti': 0.16564155690585364,
#  'lennonjohtotoiminnot': 0.16438703617250155,
#  'mitata määritellyn vesiviljelytoiminnan vaikutuksia': 0.16332449241852381,
#  'politiikan vaikutukset urheilutarjontaan': 0.16194983794177836,
#  'aerodynamiikka': 0.16009178150282427,
#  'käyttää asiakkuuksien hallintaohjelmia': 0.15972608887318523,
#  'antaa lääkkeitä koskevia asiantuntijaneuvoja': 0.1595340757245586,
#  'työskennellä raideliikennetiimissä': 0.15886839985732878,
#  'viinirypäleiden kemiallinen koostumus': 0.15850810835567508,
#  'säätää tuotantoaikataulua': 0.1581860110509931,
#  'vesiekologia': 0.15705660131975546,
#  'tutkia lentoaseman ympäristövaikutuksia': 0.15565881303273818,
#  'käyttää muutoksenhallintataitoja': 0.15488932973763603,
#  'turvallisuuteen vaikuttavat inhimilliset tekijät': 0.15468699178168896,
#  'yritysoikeus': 0.15384143643106846,
#  'suunnitella luotsaus': 0.15323137290294309,
#  'valmistella baarialue': 0.15216827639338074,
#  'opettaa englantia vieraana kielenä': 0.15132149226422373,
#  'käyttää teknisen viestinnän taitoja': 0.14980093402568428,
#  'käyttää vieraita kieliä matkailualalla': 0.14846759715953,
#  'käyttää murretta': 0.1484272036038255,
#  'kognitiivinen käyttäytymisterapia': 0.14815797609276463,
#  'kasvatuksen ja pyytämisen vaikutukset vesiluonnonvaroihin': 0.14771308120056784,
#  'tehdä kokeita eläimillä': 0.14714717869490287,
#  'ottaa huomioon merenkulun rajoitteet': 0.1465867340464875,
#  'positioida brändi': 0.1459942034330613,
#  'olla vuorovaikutuksessa lentoaseman sidosryhmien kanssa': 0.14494139672980985,
#  'muuttoliike': 0.14464830509062757,
#  'nanoelektroniikka': 0.14399631637848842,
#  'huolehtia henkilökohtaisesta ammatillisesta kehityksestä urheilussa': 0.14377469854994782,
#  'kahvin paahtaminen': 0.1437324703399341,
#  'valmistella nuoria aikuisuuteen': 0.14347802870087828,
#  'ensiavussa käytettävät erikoisvälineet': 0.14341507056271616,
#  'varmistaa, etteivät rehun lisäaineet aiheuta haittavaikutuksia': 0.14312694023914002,
#  'pienentää jalkinevalmistuksen ympäristövaikutuksia': 0.1422065405520973,
#  'käyttää matemaattisia työkaluja ajoneuvojen hallintaan': 0.14163082478052993,
#  'analysoida asiakkaiden henkilökohtaisia kuntotietoja': 0.1415981604712261,
#  'tehdä tekstitys': 0.14150863379544126,
#  'päivittää kielitaitoa': 0.1409660189565827,
#  'suunnitella urheiluopetusohjelmaa': 0.14095235939225725,
#  'kehittää kuntoutusohjelmia': 0.14055630168652347,
#  'arvioida vesiviljelytoiminnan ympäristövaikutuksia': 0.1401538203750909,
#  'vastaavuus': 0.13887475794625054,
#  'työskennellä monikulttuurisessa ympäristössä terveydenhuollossa': 0.1386179305614442,
#  'tehdä merienergiaa koskevaa tutkimusta': 0.1385380476126424,
#  'ylläpitää ajantasaista ammatillista tietämystä': 0.13740202701413337,
#  'edustaa sosiaalipalveluiden käyttäjiä': 0.13720698523502656,
#  'harjoitella roolia': 0.1370542359428327,
#  'lannoitetuotteet': 0.13704647232425723,
#  'arvioida puunkorjauksen vaikutuksia luonnonvaraiseen kasvistoon ja eläimistöön': 0.13699348738463749,
#  'homeopatian hoitokeinot': 0.13692179006792973,
#  'havainnollistaa opettaessa': 0.13655163740360943,
#  'seurata esiintyjiä': 0.13632991308353873,
#  'ICT-ympäristöpolitiikat': 0.13593303125940798,
#  'mukautua taiteilijan taiteellisiin vaatimuksiin': 0.1355827592138219,
#  'arvioida uusien ratkaisujen toteuttamiskelpoisuutta': 0.13537277251578692,
#  'soveltaa kliinistä ammattitaitoa tapauksen mukaisesti': 0.13522557113044192,
#  'harjoittaa sirkuslajeja': 0.1349852052361756,
#  'osallistua kirjaston koululaisohjelmiin': 0.13489059591796787,
#  'osallistua terveydenhoitohenkilökunnan koulutukseen': 0.13450234040615378,
#  'seurata omaa suoritusta urheilutoimitsijana': 0.1334841762528224,
#  'ajoneuvojen sähköjärjestelmät': 0.13337872184145066,
#  'tarjota säiliöalusten toimintoja koskevaa asiantuntemusta': 0.13330989896732345,
#  'suorittaa teknisesti vaativia tehtäviä': 0.13250057755253092,
#  'viineihin liittyvät tieteet': 0.1324949883606897,
#  'laitteistomateriaalit': 0.1324733937303369,
#  'tunnistaa asiakassuhteiden stressipisteet': 0.13219847778070618,
#  'arvioida riskitekijöitä': 0.13180113562006066,
#  'tehdä lääkeaineen terapeuttisen tason seurantaa': 0.13121996712470227,
#  'antaa kiropraktista hoitoa lapsille': 0.13112365765121314,
#  'kuntoutus': 0.13025260917578804,
#  'psykofarmakologia': 0.13004586319438677,
#  'kankaiden ominaisuudet': 0.12978051423504036,
#  'lihavuus': 0.12877625159850636,
#  'tietokoneavusteiset laskenta- ja analyysiohjelmistot': 0.12854791170263183,
#  'konfliktin hallinta': 0.1281051628744691,
#  'osoittaa ammattimaista pilatesasennetta': 0.12766583117340177,
#  'osoittaa ammattimaista asennetta asiakkaita kohtaan': 0.1272524286879897,
#  'oppia käsikirjoitus ulkoa': 0.1268547537392523,
#  'toksikologia': 0.12626856340712858,
#  'kuvailla kohtauksia': 0.12607264373884838,
#  'arvioida ympäristön vaikutuksia nautaeläinten sorkkiin': 0.12605642791061933,
#  'tutkia kohdeyhteisöä': 0.124843674171169,
#  'täydentävän hoidon vaikutukset sädehoitoon': 0.12471526773713278,
#  'arvioida kliinisiä psykologisia keinoja': 0.1245255057468662,
#  'kouluttaa työntekijöitä': 0.12440562048104514,
#  'tunnistaa terapian vaikutukset potilaaseen': 0.12377725065525202,
#  'lisätä urheilumotivaatiota': 0.12302721757442633,
#  'suorittaa koulutussoveltuvuustestausta': 0.12298279299973902,
#  'vastata pelipöytien miehityksestä': 0.12292911877126128,
#  'seurata lääkkeiden vaikutuksia': 0.1224068937664754,
#  'hallita taloudellisia riskejä': 0.12129199760866737,
#  'mediatutkimus': 0.12069278115869907,
#  'ennustaa organisaatioriskejä': 0.12062410664636079,
#  'kehittää henkilökohtaisia taitoja': 0.1199522822809022,
#  'analysoida liiketoimintaprosesseja': 0.11990863179088174,
#  'analysoida ympäristöön liittyviä tietoja': 0.11969832240200853,
#  'sitoutua jatkuvaan ammatilliseen oppimiseen sosiaalityössä': 0.11901284975015927,
#  'pysyä ajan tasalla psykoterapian kehitystrendeistä': 0.1188338946193617,
#  'ylläpitää työskentelyn standardeja': 0.11875052632008894,
#  'psykosomatiikka': 0.11827367669960934,
#  'menetelmät verikokeiden ottamiseen lapsilta': 0.1182711046338425,
#  'arvioida aluksen tilaa': 0.11784995356762333,
#  'esittää käsikirjoitettua dialogia': 0.11755113121605691,
#  'numerologia': 0.11743588054402393,
#  'kasvien vaikutus sisäilmastoon ja terveydentilaan': 0.11704173025673369,
#  'suorittaa lentotaitotarkastuksia': 0.11692214877186874,
#  'laskea velkamäärä': 0.11678317986996495,
#  'opettaa kieliä': 0.1158064083991218,
#  'onkologinen hormonihoito': 0.11568043370011127,
#  'päivittää kastelujärjestelmiä koskevaa ammattitaitoa': 0.11553244946599661,
#  'hyödyntää eläinlääketieteen alan oppimismahdollisuuksia': 0.11523834652126753,
#  'profiloida ihmisiä': 0.11499649096480112,
#  'laskea etuuksien määrä': 0.11444620662005073,
#  'päättää rooleihin sopivista näyttelijöistä': 0.11365987677837952,
#  'arvioida säteilyn vaikutusta': 0.11346345495991039,
#  'tuholaistorjunta-aineiden vaikutukset ruoan raaka-aineisiin': 0.11338798274191944,
#  'edistää kestäviä johtamistapoja': 0.11248828128689566,
#  'filosofia': 0.11239309491534635,
#  'ratkaista rahapelaamisen ongelmia digitaalisesti': 0.11202169501326657,
#  'toimia tähystäjänä': 0.11200084783446682,
#  'ommella suojavaatteita': 0.11198628892106896,
#  'maanmittausoppi': 0.11184173732553385,
#  'tuholaistorjunnan biologia': 0.11131094196985526,
#  'antaa kliinistä neurologiaa hyödyntävää kiropraktista hoitoa': 0.11025461654574867,
#  'antaa asiakkaille tietoa ympäristönsuojelusta': 0.11007925794379178,
#  'yhteisötalouden yritys': 0.10920860073775054,
#  'psykologian hoitotoimenpiteet': 0.10840907677876538,
#  'fytoterapia': 0.10839116569820176,
#  'visuaaliset esitystekniikat': 0.108251703498184,
#  '3D-valaistus': 0.10821921660082293,
#  'kehittää valmennustyyli': 0.1073375281510062,
#  'järjestää työnhaun työpajoja': 0.1072848327969116,
#  'tutkia rooleja käsikirjoituksista': 0.10717296014566403,
#  'järjestää haastatteluja taiteellisen ryhmän jäsenten valitsemiseksi': 0.10702029369399625,
#  'opettaa selviytymistaitoja': 0.10700063945943288,
#  'rekrytoida linja-autonkuljettajia': 0.10692868167758632,
#  'säteilysuojaus': 0.10667318925292654,
#  'laatia riskikartoituksia': 0.10645162089245495,
#  'arvioida psykologisia terveydenhuollon toimenpiteitä': 0.10601121025837297,
#  'helpottaa työmarkkinoiden tavoitettavuutta': 0.10598476833500803,
#  'bobath-terapia': 0.10586340578882943,
#  'tarjota terveysuhkien hoitostrategioita': 0.10583308570297875,
#  'käyttää hyväkseen keskeisiä teknisiä taitoja huippu-urheilun mahdollistamiseksi': 0.10499551899944708,
#  'käsikirjoittamisen teoriat': 0.10486144051823913,
#  'ottaa vastaan palautetta taiteellisesta esityksestä': 0.10445857384851719,
#  'toimia rauhallisesti stressaavissa tilanteissa': 0.10415743196232967,
#  'analysoida ohjelmiston teknisiä tietoja': 0.1039769919171214,
#  'avustaa lasten perustaitojen kehittämisessä': 0.10388153289513083,
#  'avustaa lähetystyössä': 0.10387539073151152,
#  'erikoistuneet astrologiset ohjelmistot': 0.10383799896972352,
#  'käyttää konfliktinhallintataitoja': 0.10373292645624828,
#  'tehdä terveys-, turvallisuus- ja ympäristöarviointeja': 0.10291429031472232,
#  'säteilyn vaikutukset ihmiskehoon': 0.10262005928443911,
#  'ylläpitää portfoliota': 0.10232624821191363,
#  'optimoida ICT-ratkaisun valinta': 0.1022264459859101,
#  'pakata nahkoja': 0.10216938195611441,
#  'testata parannettuja ilmailutiedotuksen hallintajärjestelmiä': 0.10203744244194973,
#  'erityisopetuksen välineet': 0.10174897434172903,
#  'ymmärtää eläimen tilanne': 0.10170999397683855,
#  'antaa tietoja lääkityksestä': 0.10157086697293603,
#  'hedelmä- ja vihannestuotteet': 0.10152561530713743,
#  'ohjata aluksia satamissa': 0.10152439088782908,
#  'opettaa tanssia': 0.10141729542218957,
#  'selviytyä haastavista työolosuhteista': 0.10141660484561768,
#  'ympäristöpolitiikka': 0.10101188484946443,
#  'myydä matkamuistoja': 0.10056366680152115,
#  'bioetiikka': 0.10021758850669302,
#  'arvioida kuulo-ongelmien psykologisia vaikutuksia': 0.10020179845220664,
#  'kommentoida luonnoksia': 0.10014599719398919,
#  'tutkia budjetteja': 0.10004953073325168,
#  'arvioida puheongelmien psykologisia vaikutuksia': 0.09996678698039085,
#  'elokuvamusiikin tekniikat': 0.09982316529916214,
#  'seurata siivousalan organisaatiollisia toimintaohjeita': 0.09967425947282542,
#  'tarjota vesiviljelmillä tapahtuvaa koulutusta': 0.09965238895383477,
#  'tehdä riskianalyysi': 0.0994568204361122,
#  'reagoida odottamattomiin tilanteisiin luonnossa': 0.09937129083679817,
#  'valvoa lääkittyjä kaloja': 0.09929740791364612,
#  'ampumatarvikkeiden huolto': 0.0988134758411495,
#  'opettaa urheilulajia': 0.09872032564555354,
#  'virvoitus- ja alkoholijuomat': 0.09854503272596277,
#  'suunnitella öljynporauslautan työaikatauluja': 0.09783797377865978,
#  'hoitaa kassaa': 0.09717172388495239,
#  'tunnistaa terveydenhuollon asiakkaan henkilökohtaiset kyvyt': 0.09698133586109434,
#  'edistää yleisön osallistumista': 0.09659015320155669,
#  'raportoida räjähtämättömistä panoksista': 0.09644910713474196,
#  'käyttää jalkineiden pohjien esikokoonpanotekniikoita': 0.09625838983936218,
#  'lentoaseman ympäristömääräykset': 0.09602677451278979,
#  'johtaa ryhmää matkailu-, majoitus- tai ravitsemisalalla': 0.09566641911805193,
#  'asentaa vesisäiliö': 0.09554109685311403,
#  'vesivirrat': 0.0953812904867087,
#  'soveltaa steinerpedagogiikan opetusstrategioita': 0.09537677865632413,
#  'radioaktiivinen saastuminen': 0.09508094672801584,
#  'mikrotietokonepohjainen julkaisujärjestelmä': 0.09496695133680408,
#  'auttaa terveydenhuollon asiakkaita kehittämään sosiaalisia taitoja': 0.09467046276987597,
#  'tarjota tietoa fysioterapian vaikutuksista': 0.09459822737836837,
#  'hallinnoida väyläopinto-ohjelmia': 0.09436751564729047,
#  'antaa aromaterapiahoitoja': 0.09435061736431803,
#  'antaa seurusteluvalmennusta': 0.09419958519100048,
#  'valvoa ympäristötekijöitä': 0.09382574611886407,
#  'hallinnoida useita projekteja': 0.09359621810307128,
#  'antaa kliinisiä psykologisia arviointeja': 0.09342647891992574,
#  'ICT-kapasiteetin suunnittelustrategiat': 0.09341369171742678,
#  'käyttää hyväkseen keskeisiä taktisia taitoja huippu-urheilun mahdollistamiseksi': 0.09303953490280505,
#  'kiinnittää kattopäällysteitä': 0.09274093090079262,
#  'vaateompelu': 0.09253548549328615,
#  'tautioppi': 0.09235164650698499,
#  'eteeristen öljyjen tyypit': 0.0920898904921978,
#  'kehittää animaatioita': 0.0919314695389942,
#  'yksinkertaistaa viestintää merenkulun hallinnassa': 0.09157158720451027,
#  'torjunta-aineet': 0.09140376034823972,
#  'huolehtia henkilöresursseista': 0.09128076824034036,
#  'psykoakustiikka': 0.0906295248183782,
#  'antaa raskausneuvontaa': 0.09045867175662958,
#  'kehittää vahvoja urheilullisia asenteita': 0.09037479413133323,
#  'tarjota koiran ulkoilutuspalveluita': 0.09025797439400177,
#  'arvioida opiskelijoiden alkuvaiheen opintosuoriutumista': 0.0897332110235022,
#  'tarjota sijoituksiin liittyviä oikeudellisia neuvoja': 0.08960272291606575,
#  'tehdä peitetutkintaa': 0.08949321863665562,
#  'mäskäysprosessi': 0.08891099244731117,
#  'seurata hoidon vaikutusta potilaaseen': 0.08887487664158876,
#  'kala-, äyriäis- ja nilviäistuotteet': 0.08884056973103155,
#  'tehdä toimenpiteen aikaisia arviointeja': 0.08872089111310559,
#  'opastaa työntekijöitä': 0.0886278361927306,
#  'sosiologia': 0.08849768774555271,
#  'voima-anturijärjestelmä': 0.08819093074900222,
#  'analysoida logistisia muutoksia': 0.08774414479371047,
#  'käyttää hiustenleikkuutaitoja': 0.08768959411306357,
#  'siirtää potilaita ambulanssiin ja pois ambulanssista': 0.08751186312006722,
#  'soveltaa ihmisten käyttäytymistietoa': 0.0874466619968692,
#  'lentometeorologia': 0.08726238366598117,
#  'lääkevalvontalainsäädäntö': 0.0871480658142113,
#  'epidemiologia': 0.08664360731582273,
#  'merenkulkuala': 0.08582392706084598,
#  'edistää ympäristötietoisuutta': 0.08571599349114434,
#  'tuntemattoman tekstikatkelman kääntäminen': 0.08554677490151598,
#  'harrastaa urheilua': 0.08544425142702985,
#  'tarkastaa raitiovaunun laitteisto': 0.08475579356064529,
#  'opettaa viestintämenetelmiä': 0.08463485199405534,
#  'tehdä lainsäädännöstä ymmärrettävää sosiaalipalveluiden käyttäjille': 0.08444751278059656,
#  'määritellä kuvien sommittelu': 0.08420133179854997,
#  'työskennellä väkivallan aiheuttamien vaikutusten parissa': 0.08410954209337262,
#  'tarkastaa telineitä': 0.08365179780705059,
#  'antaa puheen parantamiseen liittyviä neuvoja': 0.08358111044734584,
#  'säätää vesiviljelytuotannon olosuhteita': 0.08329332859279882,
#  'olla vuorovaikutuksessa sidosryhmien kanssa': 0.08326401301337069,
#  'tutkia kalojen vaellusta': 0.08308318428306063,
#  'arvioida projektin resurssitarpeita': 0.08296142267072279,
#  'suorittaa palon alkusammutusta': 0.08284527737646645,
#  'välittää tietoja kaivostoiminnan ympäristövaikutuksista': 0.08265934399837085,
#  'antaa kaivostoiminnan ympäristövaikutuksiin liittyviä neuvoja': 0.0817843733039974,
#  'opettaa sosiaalityön periaatteita': 0.08158009517524041,
#  'käyttää tietokoneen ja puhelimen integrointia': 0.08047154811702106,
#  'huolehtia omasta ulkonäöstä': 0.08021794024717029,
#  'sokeri, suklaa ja sokerimakeiset': 0.07948599826076805,
#  'kannustaa terveydenhuollon asiakkaita omaseurantaan': 0.07926524993499107,
#  'kouluttaa merivoimien sotilaita': 0.07915934750900713,
#  'käsitellä sulautumisia ja yrityskauppoja': 0.07890823610189458,
#  'opettaa puhetaitoa': 0.07879465630498075,
#  'lasten fyysinen kehitys': 0.0784050072444728,
#  'nahkatuotteiden huolto': 0.07826749752617242,
#  'korkokuvioida': 0.07815216003670156,
#  'kerrontatekniikat': 0.07810093776789032,
#  'seurata henkilön ravitsemuksen tilaa': 0.07731623248134459,
#  'digitaaliset peligenret': 0.07710718803972436,
#  'toteuttaa rautatieliikenteen riskinhallintaa': 0.07688129602293169,
#  'kansainvälinen kauppa': 0.07680257049786464,
#  'kehittää koreografinen kieli': 0.07675113871410323,
#  'puun kosteuspitoisuus': 0.07640235087761492,
#  'minimoida ympäröivään alueeseen kohdistuvat ympäristövaikutukset': 0.07638633263700026,
#  'liikuntafysiologia': 0.0755896314581483,
#  'arvioida yhteisötaideprojektien käytännön toteutusta': 0.07536546205022611,
#  'luoda projektimääritykset': 0.07483212741426915,
#  'neurofarmakologia': 0.07469078468061272,
#  'tehdä verkkosivujen vianmääritystä': 0.07464500482554222,
#  'ortopedisen hoidon vaihtoehdot': 0.07395888481972929,
#  'edistää homeopatiaa': 0.07322394499248108,
#  'raideliikenteen häiriöiden hallinta': 0.0731924562528667,
#  'antaa eläintautien torjuntaa koskevia neuvoja': 0.07314196176448418,
#  'umpieritysjärjestelmän fysiologia': 0.07308825768171197,
#  'neuvoa maaperän ja vesien suojelussa': 0.07286707487978551,
#  'vaikuttaa lainsäätäjiin': 0.07274720978611768,
#  'antaa neuvoja ympäristöriskien hallintajärjestelmistä': 0.07267207746660712,
#  'liikutella ja lastata pieniä aluksia': 0.07257780280511812,
#  'varmistaa merikuljetusten turvallinen toteuttaminen': 0.07229587373853692,
#  'ravitsemustiede': 0.07217757779916328,
#  'kehittää veropolitiikkaa': 0.07173435733571044,
#  'ihmisen anatomian ja liikkumisen välisen suhteen tutkimus': 0.0704976460777658,
#  'osoittaa oman tanssityylin teknistä osaamista': 0.07047427317417825,
#  'kirjoittaa tutkimusehdotuksia': 0.07044045789208296,
#  'öljysiementen koostumus': 0.07035149542247715,
#  'laatia merenkulun tehokkuussuunnitelmia': 0.06939271887897512,
#  'kirjata taksien kulkuajat': 0.06857790811511075,
#  'meteorologia': 0.06825145581497084,
#  'puun leikkaustavat': 0.06744614375553445,
#  'hävittää valmiseläinrehujätettä': 0.06716248847479683,
#  'ympäristöä säästävä logistiikka': 0.06694799307158808,
#  'valmistella kahvialue': 0.0666363987712729,
#  'kouluttaa vastaanottohenkilöstöä': 0.06633109855305419,
#  'antaa eläimille rauhoittavia lääkkeitä': 0.0661392926758113,
#  'seurata poliittisia kiistoja': 0.06603587945493841,
#  'hioa hammaspaikkoja': 0.06561354672867993,
#  'ottaa huomioon aineiden ominaisuuksien vaikutus virtaukseen putkijohdoissa': 0.06550173707219997,
#  'neuvoa terveellisissä elämäntavoissa': 0.06540749380013709,
#  'poistot': 0.06503780239299314,
#  'kehittää jätehuoltoprosesseja': 0.06477679134056825,
#  'antaa lääkkeitä koskevia tietoja': 0.06467849597387014,
#  'määritellä historiallisia ilmastonmuutoksia': 0.06430228973260692,
#  'koordinoida lentoaseman ympäristöpolitiikkaa': 0.06338813449701441,
#  'viktimologia': 0.06319080862857736,
#  'maankäyttö lentoasemasuunnittelussa': 0.06231348269124562,
#  'kuulla todistajanlausuntoja': 0.062182450013317556,
#  'tiedottaa elintarvikkeiden pakkausmerkintöjen poikkitieteellisistä ongelmista': 0.06179509842660114,
#  'maitotaloustuotteet ja ruokaöljytuotteet': 0.06151626229694588,
#  'laatia viljelykasvien suojelusuunnitelmia': 0.061058980459035496,
#  'alusten ohjaamiseen vaikuttavat tuulet ja virtaukset': 0.06062802520701086,
#  'organisaation toimitilajohtaminen': 0.060195497160992865,
#  'johtaa urheilutapahtumia': 0.05990743161882198,
#  'toteuttaa nimeämisstrategioita': 0.05979393102443716,
#  'rikkakasvien torjunta-aineet': 0.059669804038272746,
#  'noudattaa villieläinvaaran hallintaohjelmia': 0.05954844829268396,
#  'tehdä putkelle perusta': 0.05933604256086607,
#  'korimateriaalit': 0.058629082987142304,
#  'sulautumat ja yritysostot': 0.05828781817363205,
#  'edistää ihmisoikeuksia': 0.058156471829091866,
#  'käyttää määrättyjä rikkakasvien torjunta-aineita': 0.05808478286251373,
#  'luistelu': 0.057900385464937205,
#  'yleiseen mielipiteeseen vaikuttaminen': 0.0578202442384149,
#  'arvioida mahdollisia loppukäyttäjien kanssa syntyviä ristiriitoja': 0.05729959925784617,
#  'suunnitella eläinten jalostusohjelmia': 0.05705842321149347,
#  'kehittää digitaalisia koulutusmateriaaleja': 0.05691164179362086,
#  'laatia horoskooppeja': 0.05683494885709463,
#  'ymmärtää toimitusketjun parantamisen vaikutus voittoihin': 0.05677712258117706,
#  'antaa verotuslainsäädäntöä koskevia tietoja': 0.05646823914208142,
#  'mallintaa pohjavettä': 0.05645631269946217,
#  'maa- ja metsätaloutta koskeva ympäristölainsäädäntö': 0.056308616065268206,
#  'markkinoille tulon strategiat': 0.05573329455452655,
#  'tehdä yhteistyötä sidosryhmien kanssa yhteisötaideprojektien yhteydessä': 0.0556682105749102,
#  'riippuvuus huumaavista aineista': 0.05555802932119534,
#  'helpottaa seksuaalirikoksiin liittyvää toipumisprosessia': 0.05540529036234537,
#  'toteuttaa tieteellistä päätöksentekoa terveydenhuollossa': 0.05457763835963433,
#  'käsitellä todistusaineistoa': 0.05274612718598393,
#  'suorittaa erikoisnäkötestejä': 0.049086830057560746,
#  'vanhusten hyväksikäyttö- tai pahoinpitelytapausten käsittelystrategiat': 0.04833227929352895,
#  'toimia kalastusprojektien johtajana': 0.045414013408651775,
#  'neuvoa verosuunnittelussa': 0.04481298002244172,
#  'hallita metsäpaloja': 0.044230491101097835,
#  'ihmisoikeuksia koskeva kansainvälinen oikeus': 0.042917983697611406,
#  'tietoliikennekonseptit': 0.042539369068458135,
#  'tehdä suunnitelmia eläinten epätoivottuun käyttäytymiseen liittyvien ongelmien ratkaisemiseksi': 0.04210412665305206,
#  'sisäinen riskinhallintamenetelmä': 0.03859771429035179,
#  'asentaa lämmitys-, ilmanvaihto-, ilmastointi- ja jäähdytyskanavia': 0.03680614500429887,
#  'seksuaalisten väkivaltatapausten käsittelystrategiat': 0.03644772639891726,
#  'tukea ICT-järjestelmän käyttäjiä': 0.03136013307814575,
#  'tarjota ICT-konsultointineuvoja': 0.030040933019785755,
#  'analysoida röntgenkuvia': 0.0,
#  'myydä kelloja': 0.0,
#  'valvoa myynninjälkeisiä tilastoja': 0.0,
#  'käyttää lakantuotantolaitteita': 0.0,
#  'hoitaa kuivaustunneleita': 0.0,
#  'tutkia ilmastointijärjestelmää': 0.0,
#  'huoltaa vedenkäsittelylaitteita': 0.0,
#  'purkaa rehun raaka-ainetta': 0.0,
#  'varastoida pyroteknisiä materiaaleja': 0.0,
#  'levittää ruiskutettavaa eristevaahtoa': 0.0,
#  'lukea raideliikenteen kytkentäsuunnitelmia': 0.0,
#  'asentaa hissikuilun tukielementit': 0.0,
#  'noudattaa työaikataulua': 0.0,
#  'valvoa hedelmientuotantoryhmiä': 0.0,
#  'valvoa ulkoliikuntavälineiden käyttöä': 0.0,
#  'seinä- ja lattiapäällysteteollisuus': 0.0,
#  'raakaöljy': 0.0,
#  'tarjota multimediasisältöä': 0.0,
#  'valmistaa juomissa käytettävät hedelmäainekset': 0.0,
#  'hoitaa sikarinleimauskonetta': 0.0,
#  'kohdentaa ohjelmisto järjestelmän arkkitehtuureihin': 0.0,
#  'hoitaa tekstiilien värjäyskoneita': 0.0,
#  'hallita liiketoimintatietoa': 0.0,
#  'antaa veropolitiikkaa koskevaa neuvontaa': 0.0,
#  'suorittaa työpaikkatarkastuksia': 0.0,
#  'valita ohjaustaulukomponentit': 0.0,
#  'antaa ohjeita oppimismenetelmistä': 0.0,
#  'makean veden ekosysteemien ymmärtäminen': 0.0,
#  'hotellitoimet': 0.0,
#  'simuloida kuljetusongelmia': 0.0,
#  'käyttää ennakoivaa ajotapaa': 0.0,
#  'harjoitella tanssiliikkeitä': 0.0,
#  'asentaa vesiviljelyhäkin kiinnitysjärjestelmiä': 0.0,
#  'harjoittaa mobiilimarkkinointia': 0.0,
#  'tehdä tieteellistä tutkimusta': 0.0,
#  'arvioida ulosmittauskelpoisia tavaroita': 0.0,
#  'tehdä hajusteita koskevaa tutkimusta': 0.0,
#  'leikata johtoja': 0.0,
#  'tarkastaa matkalippuja': 0.0,
#  'laatia kalastuksen aikatauluja': 0.0,
#  'käyttää polttouunia': 0.0,
#  'tupakanlehtien tyypit': 0.0,
#  'neuvotella sidosryhmien kanssa': 0.0,
#  'antaa selonteko oikeuden virkailijoille': 0.0,
#  'luoda riimirakenne': 0.0,
#  'eläinten neuroanatomia': 0.0,
#  'huolehtia kirjaston laitteista': 0.0,
#  'huoltaa jätteenpolttouunia': 0.0,
#  'pitää kirjaa huoltotoimenpiteistä': 0.0,
#  'hoitaa synnyttäviä äitejä': 0.0,
#  'noudattaa lainsäädäntöä sosiaalipalveluissa': 0.0,
#  'käyttää jyvienpuhdistuslaitetta': 0.0,
#  'viljan kuivausmenetelmät': 0.0,
#  'kehittää teknisten tekstiilien teknisiä tietoja': 0.0,
#  'hävittää kuolleita eläimiä': 0.0,
#  'arvioida vaatteen laatua': 0.0,
#  'työskennellä itsenäisesti maataloudessa': 0.0,
#  'suhdetoiminta': 0.0,
#  'huoltaa rautateiden merkinantolaitteita': 0.0,
#  'kehittää koulutusresursseja': 0.0,
#  'kestää ulosteita': 0.0,
#  'neuvotella hintoja antiikkiesineille': 0.0,
#  'valmistella raudoitustangot': 0.0,
#  'kehittää urheilun kilpailustrategioita': 0.0,
#  'tasapainottaa tietokantaresurssit': 0.0,
#  'rannekellotyypit': 0.0,
#  'valvoa hakkuuprojekteja': 0.0,
#  'tehdä ruumiinavaus': 0.0,
#  'arvioida eläinten elinympäristöä': 0.0,
#  'valmistella kalojen lääkintäsuunnitelmia': 0.0,
#  'valmistella taittoa': 0.0,
#  'tarjota yksityisiä kuljetuspalveluja': 0.0,
#  'mitata alusten vetoisuus': 0.0,
#  'tulkita taiteellisia tarkoituksia': 0.0,
#  'toteuttaa eläinten koulutusohjelmia': 0.0,
#  'koordinoida ostotoimintaa': 0.0,
#  'suunnitella maantiekaluston huolto': 0.0,
#  'tarjota tukea itsehoitoon': 0.0,
#  'käyttää käsiporakonetta': 0.0,
#  'valita muottityyppejä': 0.0,
#  'tarkastaa viemärijärjestelmiä': 0.0,
#  'työskennellä elintarvikejalostustiimissä': 0.0,
#  'valmistella juhlatiloja': 0.0,
#  'muuttaa strategia toimiksi ja tavoitteiksi': 0.0,
#  'suorittaa geologisia tutkimuksia': 0.0,
#  'hallinnolliset tehtävät terveydenhuollossa': 0.0,
#  'huonekaluteollisuus': 0.0,
#  'asentaa kumitiivisteitä': 0.0,
#  'tarkastaa oppilaitoksia': 0.0,
#  'laatia työohjelmia': 0.0,
#  'puhallettavat hioma-aineet': 0.0,
#  'asettaa lasi telineisiin': 0.0,
#  'valvoa maastoaluetta': 0.0,
#  'laatia strategioita sähkönjakelun vikatapahtumia varten': 0.0,
#  'käyttää aaltojuotoskonetta': 0.0,
#  'suunnitella soittimia': 0.0,
#  'tietokanta': 0.0,
#  'huolehtia peruukeista': 0.0,
#  'varmistaa potilaan oikea asento leikkausta varten': 0.0,
#  'käyttää ohjelmistosuunnittelun malleja': 0.0,
#  'määrätä lääkkeitä': 0.0,
#  'kehityspsykologia': 0.0,
#  'lukea lämmitysmittareita': 0.0,
#  'tiedon rakenne': 0.0,
#  'ohjelmoitavat logiikat': 0.0,
#  'muokata kipsiä': 0.0,
#  'suunnitella avaruussatelliittihankkeita': 0.0,
#  'testata filmien kehittämiseen käytettäviä kemikaaleja': 0.0,
#  'kartoittaa vikoja putkistoinfrastruktuurista': 0.0,
#  'hoitaa mattoja': 0.0,
#  'analysoida tietojärjestelmiä': 0.0,
#  'muokata kumituotteita': 0.0,
#  'työskennellä ammattikoulussa': 0.0,
#  'toimia potilaan hoitoon osallistuvan monialaisen tiimin vastuuhenkilönä': 0.0,
#  'siivota': 0.0,
#  'pelisäännöt': 0.0,
#  'painovärin poistoprosessit': 0.0,
#  'C++': 0.0,
#  'valita sopivia vaarojen hallintakeinoja': 0.0,
#  'huolehtia kliinisistä tiloista': 0.0,
#  'noudattaa hammaslääkärin ohjeita': 0.0,
#  'ottaa vastaan geenitestaukseen lähetteellä saapuvia potilaita': 0.0,
#  'tutkia kilpailunrajoituksia': 0.0,
#  'tiedottaa asiakkaille toiminnan muutoksista ja peruutuksista': 0.0,
#  'tasapainon fysiologia': 0.0,
#  'noudattaa tarkasti tasoristeyksessä toimimista koskevia ohjeita': 0.0,
#  'kehittää tuotesuunnittelua': 0.0,
#  'kannustaa urheilemaan kouluissa': 0.0,
#  'analysoida omaa esiintymistä': 0.0,
#  'liikerakennusten turvallisuus': 0.0,
#  'ottaa korkeimman tason vastuu sisämaan vesiliikenteessä': 0.0,
#  'analysoida hoidon laatua': 0.0,
#  'koordinoida lentoaikatauluja': 0.0,
#  'käyttää eristysputken käämintäkoneitta': 0.0,
#  'jakelukanavamarkkinointi': 0.0,
#  'valmistella välineet diagnostista kuvantamista varten': 0.0,
#  'oikeustapausten hallinta': 0.0,
#  'vastata koneen säätölaitteen asetuksista': 0.0,
#  'osallistua elintarviketuotantolaitoksen toiminnan suunnitteluun': 0.0,
#  'noudattaa kielioppi- ja oikeinkirjoitussääntöjä': 0.0,
#  'säätää jännitettä': 0.0,
#  'kouluttaa louhintakoneiden hoitajia': 0.0,
#  'ruoan tarjoilutoiminta': 0.0,
#  'testata terveydenhuollon laitteita': 0.0,
#  'hoitaa turvallisuus- ja valvontalaitteita': 0.0,
#  'kalastusalukset': 0.0,
#  'kerätä veroja': 0.0,
#  'osoittaa ammatillista vastuuta': 0.0,
#  'geotiede': 0.0,
#  'valvoa potilaan terveyden tilaa': 0.0,
#  'leikata tekstiilejä': 0.0,
#  'korjata huonekalujen osia': 0.0,
#  'tehdä lämpöenergiamittauksia': 0.0,
#  'käyttää sorkkienleikkaustyökaluja': 0.0,
#  'tehdä puunhakkuukoneiden säännöllisiä huoltoja': 0.0,
#  'suunnitella ruokalistoja': 0.0,
#  'ryöppäyskoneprosessi': 0.0,
#  'huoltaa maatalouskoneita': 0.0,
#  'analysoida soluviljelmiä': 0.0,
#  'käyttää rusnauslaitetta': 0.0,
#  'järjestää tietoa': 0.0,
#  'tallentaa puutavaran käsittelytietoja': 0.0,
#  'huolehtia kuvauslaitteista': 0.0,
#  'akustiikka': 0.0,
#  'kosmeettiset hammastoimenpiteet': 0.0,
#  'määritellä teoksen visuaalinen maailma': 0.0,
#  'huoltaa asennettuja laitteita': 0.0,
#  'huoltaa foliopainatuskonetta': 0.0,
#  'ottaa huonepalvelun tilauksia': 0.0,
#  'terästynnyreiden ja -astioiden valmistus': 0.0,
#  'kerätä tietoja GPS-laitteilla': 0.0,
#  'käyttää levityskonetta': 0.0,
#  'koordinoida lastin käsittelyä': 0.0,
#  'neuvoa alihankkijoita': 0.0,
#  'pujotella kangasvuoraus': 0.0,
#  'säädellä rouhitun tupakan kulkua': 0.0,
#  'esitellä tuotteen ominaisuuksia': 0.0,
#  'muokata koruja': 0.0,
#  'verrata maanmittauslaskelmia': 0.0,
#  'suorittaa turvallisuustoimenpiteitä pienaluksella': 0.0,
#  'käyttää käyttäjäkeskeisen suunnittelun menetelmiä': 0.0,
#  'valvoa museoesineiden siirtämistä': 0.0,
#  'kuumasaumaustyypit': 0.0,
#  'toimia kuiskaajana esityksissä': 0.0,
#  'käyttää tarkkuusmittausvälineitä': 0.0,
#  'analysoida kuvia': 0.0,
#  'liittää metalleja': 0.0,
#  'asentaa tihkukastelujärjestelmä': 0.0,
#  'käyttää näyttämön liikutusjärjestelmää': 0.0,
#  'korjata nosturikalustoa': 0.0,
#  'taidehistoria': 0.0,
#  'asettaa äänilevyetikettejä': 0.0,
#  'tilata optisia laitteita': 0.0,
#  'puhdistaa aluksia': 0.0,
#  'kehittää markkinoinnin työvälineitä': 0.0,
#  'antaa nitraattien aiheuttamaa pilaantumista koskevia neuvoja': 0.0,
#  'tutkia saastumista': 0.0,
#  'hankkia luvat julkisten tilojen käyttöä varten': 0.0,
#  'spesifikaatiot meijerituotteiden valmistuksessa': 0.0,
#  'vihanhallinta': 0.0,
#  'valvoa kasinohenkilökuntaa': 0.0,
#  'elektronisten laitteiden periaatteet': 0.0,
#  'käyttää ICT-lippujärjestelmää': 0.0,
#  'kirjoittaa ohjekirjoja': 0.0,
#  'urheiluetiikka': 0.0,
#  'vahata karvoja': 0.0,
#  'valmistaa alusta lasille': 0.0,
#  'varmistaa putkistoinfrastruktuurin säädöstenmukaisuus': 0.0,
#  'kertoa suuterveydestä ja sairauksien ehkäisystä': 0.0,
#  'mainostaa tuotteita mainoksissa': 0.0,
#  'hoitaa anodisointikonetta': 0.0,
#  'asentaa metallikattoja': 0.0,
#  'kehittää liikekumppanuuksia': 0.0,
#  'uskontotiede': 0.0,
#  'suorittaa lastaamis- ja purkamistoimintoja': 0.0,
#  'koristella kynsiä': 0.0,
#  'geofysiikka': 0.0,
#  'arvioida osakkeen arvo': 0.0,
#  'tunnistaa uusien mallien kohdemarkkinat': 0.0,
#  'kaupunkialueilla käytettävien ajoneuvojen mekaaniset vaatimukset': 0.0,
#  'valmistaa tilaukset': 0.0,
#  'tarkastaa virallisia asiakirjoja': 0.0,
#  'antaa tukea sopeutumisessa fyysiseen vammaan': 0.0,
#  'analysoida kokeellisia laboratoriotuloksia': 0.0,
#  'ostaa automateriaaleja': 0.0,
#  'tarkistaa kaiverruksen tarkkuus': 0.0,
#  'kehittää ratkaisuja haitalliseen käytökseen': 0.0,
#  'tehdä virkistystilojen käyttöaikataulu': 0.0,
#  'suunnitella sairaanhoitoa': 0.0,
#  'hydrografia': 0.0,
#  'valaa korumetalleja': 0.0,
#  'pitää varasto järjestyksessä': 0.0,
#  'puhua julkisesti': 0.0,
#  'kiinnittää aluksia laituriin': 0.0,
#  'oikomishoito': 0.0,
#  'käyttää pumppauslaitteita': 0.0,
#  'viljellyt helmet': 0.0,
#  'hankkia keskeisiä tietoja projekteista': 0.0,
#  'syöttää materiaaleja uuniin': 0.0,
#  'sekoittaa ainesosia lateksiin': 0.0,
#  'puhdistaa ilmastointijärjestelmiä': 0.0,
#  'täyttää öljylähdettä koskevia tietolomakkeita': 0.0,
#  'louhintatekniikat': 0.0,
#  'seurata henkilökunnan poissaoloja': 0.0,
#  'asentaa laskettu sisäkatto': 0.0,
#  'mausteiden valmistusprosessit': 0.0,
#  'valmistaa puolijohdekiteitä': 0.0,
#  'käyttää betoniharkkojen valukonetta': 0.0,
#  'käyttäytyä hillitysti': 0.0,
#  'estää petollista toimintaa': 0.0,
#  'käyttää merenkulun englantia': 0.0,
#  'valmistaa kolmiulotteisia jalkineprototyyppejä tietokoneavusteisesti': 0.0,
#  'putkikuljetusta koskevat määräykset': 0.0,
#  'hoitaa tiilipuristinta': 0.0,
#  'asentaa ikkuna': 0.0,
#  'käyttää irrotusveistä': 0.0,
#  'dokumentoida turvatoimenpiteet': 0.0,
#  'erottaa epävakaat elementit vedessä': 0.0,
#  'nähtävyystiedot': 0.0,
#  'tehdä aistinvaraista arviointia': 0.0,
#  'kirkastaa öljyä saostamalla': 0.0,
#  'selittää bingon säännöt': 0.0,
#  '3D-tulostusprosessi': 0.0,
#  'antaa työntekijöille toiminnan tehostamiskoulutusta': 0.0,
#  'nahkatuotteiden rakenneosat': 0.0,
#  'kehittää strategisia suunnitelmia fysioterapiapalveluille': 0.0,
#  'suunnitella rakennusten huoltotoimia': 0.0,
#  'pakata tuotteita lahjapakettiin': 0.0,
#  'korjauttaa varusteita': 0.0,
#  'sovellettu eläintiede': 0.0,
#  'prosessiperusteinen hallinta': 0.0,
#  'silkkipainokoneet': 0.0,
#  'ehkäistä terveys- ja turvallisuusongelmia': 0.0,
#  'antaa geneettisten sairauksien diagnostisiin sikiötutkimuksiin liittyviä neuvoja': 0.0,
#  'edustaa uskonnollista instituutiota': 0.0,
#  'käyttää kalastusvälineiden valmistuskonetta': 0.0,
#  'määritellä ihotyyppi': 0.0,
#  'työskennellä sirkusryhmän kanssa': 0.0,
#  'huolehtia karbonointitasoista': 0.0,
#  'rajoittaa lastia vahinkojen ehkäisemiseksi': 0.0,
#  'valvoa munantuotantoa': 0.0,
#  'tehdä mosaiikkia': 0.0,
#  'valvoa kiertokäyntejä': 0.0,
#  'tehdä kastikkeita ja keittoja': 0.0,
#  'hoitaa tyhjiöpursotinta': 0.0,
#  'terveydenhuolto': 0.0,
#  'tunnistaa lahjakkaan oppilaan merkkejä': 0.0,
#  'ammattisanasto': 0.0,
#  'varmistaa vieraiden yksityisyys': 0.0,
#  'käyttää restaurointitekniikoita': 0.0,
#  'hoitaa tuotetilauksia asiakkaiden puolesta': 0.0,
#  'pitää tuotantokirjaa': 0.0,
#  'huolehtia vesiviljelmien vedenlaadusta': 0.0,
#  'tasoittaa lasin pintaa': 0.0,
#  'neuvoa asiakkaita uusien laitteiden käytössä': 0.0,
#  'rekisteröidä virallisia asiakirjoja': 0.0,
#  'asentaa lattianpäällysteitä': 0.0,
#  'tarkastaa raaka-aineiden laatu': 0.0,
#  'vaatetus- ja jalkinetuotteet': 0.0,
#  'elintarvikehygieniaa koskevat määräykset': 0.0,
#  'huolehtia kuiskaajan pääkirjasta': 0.0,
#  'hoitaa ikeniä': 0.0,
#  'varmistaa tuotteiden vaatimustemukaisuus': 0.0,
#  'haastattelututkimustekniikat': 0.0,
#  'ohjata lentoaseman alihankkijoita': 0.0,
#  'antaa aikuisopetusta': 0.0,
#  'tarkastaa käytettyjen tavaroiden myyntipotentiaali': 0.0,
#  'arvioida ympäristösuunnitelmia talouden näkökulmasta': 0.0,
#  'huoltaa teknisiä välineitä': 0.0,
#  'käsitellä rikkoutuneita lasilevyjä': 0.0,
#  'käyttää hoitotyössä kokonaisvaltaista lähestymistapaa': 0.0,
#  'muokata lasia': 0.0,
#  'seurata tuotantoaikataulua': 0.0,
#  'säätää videolähetyksen asetuksia': 0.0,
#  'huolehtia lentoaseman valvontainfrastruktuurista': 0.0,
#  'proteiini': 0.0,
#  'kuljettaa vierailijoita': 0.0,
#  'ohjata nosturinkuljettajia': 0.0,
#  'huolehtia henkilökohtaisista raha-asioista': 0.0,
#  'tehdä fysikaalisia stressitestejä malleille': 0.0,
#  'pyrkiä säilyttämään veden koostumus': 0.0,
#  'antaa neuvoja eläinten omistajille': 0.0,
#  'käyttää vannesahaa': 0.0,
#  'tehdä rikosteknisiä tutkimuksia': 0.0,
#  'kotieläintalous': 0.0,
#  'lukea sähkömittareita': 0.0,
#  'ylläpitää arkistoa lääkemääräyksistä ja lääkkeistä': 0.0,
#  'projektiolaitteet': 0.0,
#  'suorittaa avaamis- ja sulkemismenettelyt': 0.0,
#  'suunnitella terveys- ja turvallisuustoimenpiteitä': 0.0,
#  'ajaa moottoriajoneuvojen prototyyppejä': 0.0,
#  'käsitellä lihanjalostuslaitteita jäähdytyshuoneissa': 0.0,
#  'peruselintoimintojen häiriöt': 0.0,
#  'noudattaa ympäristöystävällisiä käytäntöjä elintarvikkeiden jalostuksessa': 0.0,
#  'mitata aikaa tarkasti': 0.0,
#  'korjata maanalaisia voimakaapeleita': 0.0,
#  'suorittaa potilaalle proteesitutkimus': 0.0,
#  'tarjota tieto- ja viestintäteknistä tukea': 0.0,
#  'säätää savenpolton lämpötilaa': 0.0,
#  'antaa terveysneuvontaa': 0.0,
#  'johtaa tapahtuman rakenteiden asennusta': 0.0,
#  'hoitaa viilauskonetta': 0.0,
#  'hiivakäymisen periaatteet': 0.0,
#  'suorittaa pastörointiprosesseja': 0.0,
#  'antaa asiakkaille hedelmien ja vihannesten käsittelyä koskevia neuvoja': 0.0,
#  'testata, että hammasapuvälineet ovat määräysten mukaisia': 0.0,
#  'ampumatarvikkeisiin liittyvät oikeudelliset vaatimukset': 0.0,
#  'johtaa laadunvalvontaa': 0.0,
#  'klassiset kielet': 0.0,
#  'analysoida vedonlyöntidataa': 0.0,
#  'käyttää biologista suodatusta': 0.0,
#  'kalojen ja äyriäisten käsittely': 0.0,
#  'työskennellä maalla toimivassa ryhmässä': 0.0,
#  'soveltaa montessoripedagogiikan opetusstrategioita': 0.0,
#  'suorittaa tekninen äänentarkistus': 0.0,
#  'urheiluvälineiden käyttö': 0.0,
#  'opettaa lukustrategioita': 0.0,
#  'vaarallisten aineiden kuljetus': 0.0,
#  'käyttää eläintautien epidemiologiaan liittyviä tietoja': 0.0,
#  'myydä kankaita': 0.0,
#  'paikallismaantiede': 0.0,
#  'puhdistaa öljynjalostusyksiköitä': 0.0,
#  'myöntää virallisia asiakirjoja': 0.0,
#  'opettaa matematiikkaa': 0.0,
#  'tarkastaa kasinosali': 0.0,
#  'puhaltaa pintoja': 0.0,
#  'avustaa lentäjää pakkolaskutilanteessa': 0.0,
#  'kvanttimekaniikka': 0.0,
#  'käyttää puuhiokekartonkipuristinta': 0.0,
#  'suorittaa virallistettuja tulkkauksia': 0.0,
#  'paahdetun maltaan värit': 0.0,
#  'huolehtia lisäaineiden käytöstä elintarvikkeiden valmistuksessa': 0.0,
#  'reiki': 0.0,
#  'käyttää laivan laitteita': 0.0,
#  'eläinravitsemus': 0.0,
#  'käyttää olio-ohjelmointia': 0.0,
#  'levittää suihkurusketusta': 0.0,
#  'merentutkimus': 0.0,
#  'sähkölaitteiden komponentit': 0.0,
#  'sietää voimakkaita hajuja': 0.0,
#  'lääkkeiden valmistuksen laatujärjestelmät': 0.0,
#  'oikeussanasto': 0.0,
#  'käyttää siistauskemikaaleja': 0.0,
#  'huoltaa puuhiokekartonkikoneita': 0.0,
#  'analysoida kaukoputkella otettuja kuvia': 0.0,
#  'tehdä kemiallisia kokeita': 0.0,
#  'lisätä tietoisuutta paikallisyhteisöä koskevista tärkeistä ongelmista': 0.0,
#  'osallistua urheiluharjoituksiin': 0.0,
#  'valmistaa räätälöityjä tuotteita': 0.0,
#  'tiedottaa työsuojelutoimenpiteistä': 0.0,
#  'tunnistaa talousrikoksia': 0.0,
#  'semantiikka': 0.0,
#  'korjata satoa': 0.0,
#  'markkinaosapuolet': 0.0,
#  'tunnistaa puun käyristyminen': 0.0,
#  'rahdinkäsittelyn kansalliset määräykset': 0.0,
#  'käsitellä kaivosjätteitä': 0.0,
#  'pitää kirjaa museon kokoelmista': 0.0,
#  'varmistaa elintarviketuotantolaitoksen koneiden täydellinen toiminta': 0.0,
#  'asentaa tuuletuslaitteita': 0.0,
#  'tekohartsit': 0.0,
#  'kehittää erikoistarjouksia': 0.0,
#  'aluksen turvavarusteet': 0.0,
#  'määritellä tulipaloriskejä': 0.0,
#  'huolehtia verkkoviestinnästä': 0.0,
#  'hallita erilaisia hedelmien ja vihannesten kuivatusprosesseja': 0.0,
#  'analysoida öljynporaustoimintaa koskevia tietoja': 0.0,
#  'tehdä terveyteen liittyvää tutkimusta': 0.0,
#  'noudattaa kansallisten ja kansainvälisten turvallisuusohjelmien standardeja': 0.0,
#  'terveyskasvatus': 0.0,
#  'tuuliturbiinityypit': 0.0,
#  'vaarallisten aineiden kansainvälinen maantiekuljetus': 0.0,
#  'puusepäntuotteiden valmistus': 0.0,
#  'arvioida sisustussuunnitelman budjetti': 0.0,
#  'elintarvikkeisiin ja juomiin liittyvät fyysiset, kemialliset ja biologiset riskit': 0.0,
#  'valmistella rakennuslupahakemuksia': 0.0,
#  'auttaa asiakkaita tekemään päätöksiä terapian aikana': 0.0,
#  'huolehtia raideliikenteen turvallisuudesta korjaustöiden aikana': 0.0,
#  'laatia terveysasiakirjoja': 0.0,
#  'soveltaa ennen opetusta annettavan tukiopetuksen menetelmiä': 0.0,
#  'käsitellä filmiä': 0.0,
#  'laatia lentoaseman pelastussuunnitelmat': 0.0,
#  'laskea viiniä': 0.0,
#  'ylläpitää raportteja kassatapahtumista': 0.0,
#  'toteuttaa politiikkaa terveydenhuollon käytännöissä': 0.0,
#  'tekniset piirustukset': 0.0,
#  'pitää kirjaa rahdista': 0.0,
#  'toimia hevostapahtumien johtajana': 0.0,
#  'huolehtia fleksopainoprosesseista': 0.0,
#  'valmistaa veistoksen prototyyppi': 0.0,
#  'asentaa kaapeli-TV-palveluja': 0.0,
#  'tarkastaa toimitettu betoni': 0.0,
#  'polttimen lämpötila metallinkäsittelyssä': 0.0,
#  'tehdä sumutuslaitteiden turvatarkistuksia': 0.0,
#  'esittää vapaa-ajan toimintaa': 0.0,
#  'sirkussanasto': 0.0,
#  'käyttää metallintyöstötyökaluja': 0.0,
#  'käyttää käsimerkkejä kuljetustoimenpiteissä': 0.0,
#  'järjestää ajoneuvojen teknisiä käyttötietoja koskevia asiakirjoja': 0.0,
#  'hätätilanteiden hoidossa käytettävät psykologian menetelmät': 0.0,
#  'näytellä liikkeenkaappausvarusteissa': 0.0,
#  'valita vesiviljelylaitteita': 0.0,
#  'noudattaa lentopaikan toimintakäsikirjan määräyksiä': 0.0,
#  'kylvettää koiria': 0.0,
#  'tehdä potilaan aktiivisuusanalyyseja': 0.0,
#  'valmistella huonekaluja maalaamista varten': 0.0,
#  'antaa öljyntuotantoa koskevaa teknistä tukea': 0.0,
#  'kirjoittaa nopeasti koneella': 0.0,
#  'asentaa lähetyslaitteet': 0.0,
#  'hallinnoida arvopaperikauppaa': 0.0,
#  'jakaa kulkulupia': 0.0,
#  'antaa potilaille mahdollisuus tutkia taideteoksia': 0.0,
#  'kliininen farmakologia ja lääkehoito': 0.0,
#  'tutkia määrien välisiä suhteita': 0.0,
#  'valvoa viljeltyjen kalalajien kasvunopeutta': 0.0,
#  'tulkita raitiovaunujen liikennemerkkejä': 0.0,
#  'antaa tietoja historiallisesta kontekstista': 0.0,
#  'käyttää paperipuristinta': 0.0,
#  'kirjoittaa sähkölaitteilla': 0.0,
#  'valvoa metsän kuntoa': 0.0,
#  'maailmanlaajuisen satelliittinavigointijärjestelmän suorituskykyparametrit': 0.0,
#  'käyttää elektronisuihkuhitsauskonetta': 0.0,
#  'käyttää astianpesukonetta': 0.0,
#  'ajoneuvotyypit': 0.0,
#  'vesipolitiikka': 0.0,
#  'tarkastaa materiaalien yhteensopivuus': 0.0,
#  'huolehtia ajoneuvojen varaosien saatavuudesta': 0.0,
#  'suorittaa tutkimushaastatteluja': 0.0,
#  'kaivosturvallisuuteen liittyvä lainsäädäntö': 0.0,
#  'ohjata musiikkiryhmiä': 0.0,
#  'vastata kliinisestä kiropraktisesta tutkimuksesta': 0.0,
#  'tuottaa tekstiilinäytteitä': 0.0,
#  'pitää kokeita': 0.0,
#  'läheisen kuoleman käsittelyn vaiheet': 0.0,
#  'wc-istuintyypit': 0.0,
#  'antaa kotitehtäviä': 0.0,
#  'laskea jalkineiden ja nahkatuotteiden valmistuskapasiteetti': 0.0,
#  'valvoa käymisprosessia': 0.0,
#  'annostella materiaaleja betoninsekoittimeen': 0.0,
#  'muovata suklaata': 0.0,
#  'huolehtia lasin paksuudesta': 0.0,
#  'käyttää porausvaunua': 0.0,
#  'ohjata hissivaunun asennusta': 0.0,
#  'taivuttaa kimpiä': 0.0,
#  'kirjata asiakkaan henkilötiedot': 0.0,
#  ...}

# %% [markdown]
# ## Stemming

# %%
import re
import nltk

stemmer = nltk.stem.snowball.SnowballStemmer('finnish')
stopwords = nltk.corpus.stopwords.words('finnish')

def stem_tokens(tokens):
    return [stemmer.stem(item) for item in tokens]

def tokenize(text):
    return re.split(' |,|\!|\(|\)|\/|-|:|\r\n', data)


def has_numbers(string):
    return any(char.isdigit() for char in string)


def has_at_sign(string):
    return '@' in string


def clean_tokens(tokens):
    tokens = [token for token in tokens if token and not any([has_numbers(token), has_at_sign(token)])]
    
    return tokens


def remove_stopwords(tokens):
    return [token for token in tokens if token not in stopwords]


def tokenizer(text):
    tokens = re.split(' |,|\!|\(|\)|\/|-|:|\r\n', text.lower())
    tokens = [token for token in tokens if token and not any([has_numbers(token), has_at_sign(token)])]
    tokens = remove_stopwords(tokens)
    tokens = [token.replace('.', '') for token in tokens]
    tokens = stem_tokens(tokens)
    
    return tokens

# %%
def get_stemmed_documents(data):
    documents = {}
    for i in data.index:
        document_words = []
        
        preferred_label = data['preferredLabel'][i]
        document_words.extend(tokenizer(preferred_label))

        description = data['description'][i]
        document_words.extend(tokenizer(description))
        
        document = ' '.join(document_words)
        documents[preferred_label] = document
        
    return documents

stemmed_documents = get_stemmed_documents(data)

# %%
stemmed_vectorizer = TfidfVectorizer()
stemmed_tfidf = stemmed_vectorizer.fit_transform(list(stemmed_documents.values()))

# %%
def stemmed_cosine_similarity(text1, text2):
    tmp = stemmed_vectorizer.transform([text1, text2])
    return ((tmp * tmp.T).A)[0, 1]

def get_stemmed_similarities(text):
    text_tokens = tokenizer(text)
    text_stemmed = ' '.join(text_tokens)
    
    similarities = {}
    
    for key, value in stemmed_documents.items():
        similarities[key] = stemmed_cosine_similarity(text_stemmed, value)
    
    return similarities

# %%
d = get_stemmed_similarities('hyviä vuorovaikutustaitoja')
d_sorted = dict(sorted(d.items(), key=lambda item: item[1], reverse=True))
d_sorted
# Out:
# {'jakaa hyviä käytäntöjä tytäryhtiöihin': 0.40257129562284893,
#  'toimia hyvien tapojen mukaisesti pelaajien kanssa': 0.3978977424934986,
#  'testata sähkönsiirron käytäntöjä': 0.3571446219340207,
#  'edistää hyviä tapoja viestintähäiriöiden ehkäisemiseksi': 0.342163021971418,
#  'valmistaa lähetykset hyvissä ajoin': 0.31356493005875136,
#  'ostaa osia': 0.2780904871313674,
#  'ylläpitää tietokannan turvallisuutta': 0.2659599076128245,
#  'tehdä myyntianalyysi': 0.26555130741278515,
#  'kirjoittaa tuotantoraportteja': 0.2627778312914531,
#  'tyhjiötislausprosessit': 0.2546292758114418,
#  'joukko-oppi': 0.2530449602924419,
#  'käyttää myyntiennusteohjelmistoja': 0.2513880699316718,
#  'ylläpitää ihmissuhteita työpaikalla': 0.2465451896850979,
#  'valvoa vieraiden pesulapalvelua': 0.24551351990442863,
#  'suhtautua potilaisiin hyvin': 0.24138000486814837,
#  'noudattaa hyvää valmistustapaa': 0.24126332646379683,
#  'kehittää projektisuunnitelma': 0.24088578516168052,
#  'toimia ensihoitotilanteessa': 0.23080085207175505,
#  'päivittää kielitaitoa': 0.22880147162229575,
#  'kehittää verkkomyynnin liiketoimintasuunnitelma': 0.22853778504038674,
#  'olla hyvin tietoinen turvallisuusnäkökohdista': 0.22567112008153825,
#  'ylläpitää suhteita valtion virastoihin': 0.224386135842789,
#  'suorittaa damaskointia': 0.22416711434235362,
#  'tehdä laatuvaatimusten yksityiskohtaista arviointia': 0.2235464192082266,
#  'pitää kirjaa ruokalaboratorion varastotilanteesta': 0.22284461900151456,
#  'tarkastaa merenkulkutoiminta': 0.22167521199067416,
#  'toimittaa tapausta koskevia tietoja': 0.21842428589609797,
#  'huolehtia laumasta': 0.21799127291031364,
#  'hienomekaaninen suunnittelu': 0.21582097824734672,
#  'säätää projektorilaitteita': 0.21448364908098955,
#  'testata tuotannon panosmateriaaleja': 0.21424496546943173,
#  'hoitaa hallintojärjestelmiä': 0.214104965846736,
#  'huolehtia hylätyistä tuotteista': 0.20901592692104592,
#  'valvoa sosiaalityön opiskelijoita': 0.20769642385516854,
#  'hoitaa sosiaalisia kriisitilanteita': 0.20697403106564127,
#  'tehdä elintarvikkeiden turvallisuustarkastuksia': 0.20609609469926293,
#  'käyttää säännöllisiä ilmauksia': 0.20605010417161804,
#  'käyttää etukuormaajaa': 0.19962152061744134,
#  'järjestää julkisia suuterveysohjelmia': 0.199001692613733,
#  'valvoa kiropraktikko-opiskelijoita': 0.1973403876387482,
#  'viestiä hotellien, bussiyhtiöiden ja ravintoloiden kanssa': 0.1962454018369993,
#  'korjata leukanivelen toimintahäiriöitä': 0.19616123561365442,
#  'valvoa kuntouttamista': 0.19408895287526925,
#  'pitää yhteyttä huolitsijoihin': 0.19401996159084473,
#  'pitää yllä suhteita paikallisiin toimijoihin': 0.19336757493917586,
#  'noudattaa hyviä kliinisiä tutkimustapoja': 0.19234689374298283,
#  'koordinoida autojen korjaus- ja huoltopalveluita': 0.18944771357622445,
#  'tarjota psykoterapeuttinen ympäristö': 0.18879497659649863,
#  'harjoittaa extremelajeja': 0.18591534690068032,
#  'huoltaa proteesi- ja ortoosiapuvälineitä': 0.18580758945172007,
#  'sekoittaa tapettiliisteriä': 0.18544991546915027,
#  'pitää yllä suhteita kuuluisuuksiin': 0.1846905517053646,
#  'tukea kirjailijoita': 0.17579507640860617,
#  'varastoida kaloja säilytysyksiköihin': 0.17443102516748715,
#  'tukea lahjakkaita opiskelijoita': 0.17175156310549303,
#  'suorittaa ohjelmiston palautuksen testausta': 0.16947001711013093,
#  'kerätä alkioita': 0.16936775508109192,
#  'pitää kirjaa myynnistä': 0.16915122311790717,
#  'edistää eläinten hyvinvointia': 0.16875200910810267,
#  'tarkastaa lähetyksiä': 0.167664467370663,
#  'seurata taidemarkkinoita': 0.1649647676846277,
#  'näkölentosäännöt': 0.16466988166612015,
#  'olla yhteydessä taiteilijoiden agentteihin': 0.16440664029063623,
#  'valmistella työkappaleet etsaamista varten': 0.16175081018831053,
#  'tutkia vastasyntynyttä': 0.1606052612749161,
#  'yhdistää ihmisiä': 0.16033696678094558,
#  'levittää liimapäällystettä seinään': 0.15684383748525868,
#  'valmistella hedelmät ja vihannekset esikäsittelyä varten': 0.15273160718926443,
#  'neuvoa terveellisissä elämäntavoissa': 0.14813931002857497,
#  'valmistella työkappaleet kaivertamista varten': 0.1445527611285679,
#  'hitsata korkeapaineisissa olosuhteissa': 0.13966887380923448,
#  'antaa tietoja kiinteistöistä': 0.13560911987816346,
#  'sopeuttaa puumateriaaleja huoneilmaan': 0.13158143149724533,
#  'asentaa maahan metallista ponttiseinää': 0.127711618869948,
#  'kirkastaa öljyjä keittomenetelmillä': 0.12049435349002449,
#  'valmistella pinta rappaamista varten': 0.11802680197712863,
#  'tehdä sorvin huippukelkan asetuksia': 0.11748592648099812,
#  'valita taiteelliset materiaalit taideteoksen luomiseen': 0.11125292007249367,
#  'käyttää tupakan ilmakuivausmenetelmää': 0.10548039853031235,
#  'käyttää Microsoft Office -ohjelmistoa': 0.10493969352968413,
#  'harjatyypit': 0.10124876696948472,
#  'antaa päällystölle sotilasoperaatioita koskevaa neuvontaa': 0.09988418284190656,
#  'analysoida röntgenkuvia': 0.0,
#  'myydä kelloja': 0.0,
#  'valvoa myynninjälkeisiä tilastoja': 0.0,
#  'käyttää lakantuotantolaitteita': 0.0,
#  'hoitaa kuivaustunneleita': 0.0,
#  'tutkia ilmastointijärjestelmää': 0.0,
#  'huoltaa vedenkäsittelylaitteita': 0.0,
#  'purkaa rehun raaka-ainetta': 0.0,
#  'varastoida pyroteknisiä materiaaleja': 0.0,
#  'levittää ruiskutettavaa eristevaahtoa': 0.0,
#  'psykologian hoitotoimenpiteet': 0.0,
#  'lukea raideliikenteen kytkentäsuunnitelmia': 0.0,
#  'asentaa hissikuilun tukielementit': 0.0,
#  'noudattaa työaikataulua': 0.0,
#  'valvoa hedelmientuotantoryhmiä': 0.0,
#  'valvoa ulkoliikuntavälineiden käyttöä': 0.0,
#  'seinä- ja lattiapäällysteteollisuus': 0.0,
#  'raakaöljy': 0.0,
#  'tarjota multimediasisältöä': 0.0,
#  'valmistaa juomissa käytettävät hedelmäainekset': 0.0,
#  'hoitaa sikarinleimauskonetta': 0.0,
#  'kohdentaa ohjelmisto järjestelmän arkkitehtuureihin': 0.0,
#  'hoitaa tekstiilien värjäyskoneita': 0.0,
#  'hallita liiketoimintatietoa': 0.0,
#  'antaa veropolitiikkaa koskevaa neuvontaa': 0.0,
#  'suorittaa työpaikkatarkastuksia': 0.0,
#  'valita ohjaustaulukomponentit': 0.0,
#  'antaa ohjeita oppimismenetelmistä': 0.0,
#  'makean veden ekosysteemien ymmärtäminen': 0.0,
#  'hotellitoimet': 0.0,
#  'simuloida kuljetusongelmia': 0.0,
#  'tukea sosiaalipalveluiden käyttäjiä määrätyissä viestintätarpeissa': 0.0,
#  'käyttää ennakoivaa ajotapaa': 0.0,
#  'harjoitella tanssiliikkeitä': 0.0,
#  'asentaa vesiviljelyhäkin kiinnitysjärjestelmiä': 0.0,
#  'harjoittaa mobiilimarkkinointia': 0.0,
#  'tehdä tieteellistä tutkimusta': 0.0,
#  'arvioida ulosmittauskelpoisia tavaroita': 0.0,
#  'tehdä hajusteita koskevaa tutkimusta': 0.0,
#  'leikata johtoja': 0.0,
#  'tarkastaa matkalippuja': 0.0,
#  'laatia kalastuksen aikatauluja': 0.0,
#  'käyttää polttouunia': 0.0,
#  'tupakanlehtien tyypit': 0.0,
#  'neuvotella sidosryhmien kanssa': 0.0,
#  'antaa selonteko oikeuden virkailijoille': 0.0,
#  'luoda riimirakenne': 0.0,
#  'eläinten neuroanatomia': 0.0,
#  'huolehtia kirjaston laitteista': 0.0,
#  'huoltaa jätteenpolttouunia': 0.0,
#  'pitää kirjaa huoltotoimenpiteistä': 0.0,
#  'hoitaa synnyttäviä äitejä': 0.0,
#  'noudattaa lainsäädäntöä sosiaalipalveluissa': 0.0,
#  'käyttää jyvienpuhdistuslaitetta': 0.0,
#  'viljan kuivausmenetelmät': 0.0,
#  'kehittää teknisten tekstiilien teknisiä tietoja': 0.0,
#  'hävittää kuolleita eläimiä': 0.0,
#  'arvioida vaatteen laatua': 0.0,
#  'työskennellä itsenäisesti maataloudessa': 0.0,
#  'suhdetoiminta': 0.0,
#  'huoltaa rautateiden merkinantolaitteita': 0.0,
#  'kehittää koulutusresursseja': 0.0,
#  'kestää ulosteita': 0.0,
#  'neuvotella hintoja antiikkiesineille': 0.0,
#  'valmistella raudoitustangot': 0.0,
#  'kehittää urheilun kilpailustrategioita': 0.0,
#  'tasapainottaa tietokantaresurssit': 0.0,
#  'arvioida suunnitelman riskejä ja vaikutuksia': 0.0,
#  'rannekellotyypit': 0.0,
#  'valvoa hakkuuprojekteja': 0.0,
#  'tehdä ruumiinavaus': 0.0,
#  'arvioida eläinten elinympäristöä': 0.0,
#  'valmistella kalojen lääkintäsuunnitelmia': 0.0,
#  'valmistella taittoa': 0.0,
#  'tarjota yksityisiä kuljetuspalveluja': 0.0,
#  'mitata alusten vetoisuus': 0.0,
#  'tulkita taiteellisia tarkoituksia': 0.0,
#  'toteuttaa eläinten koulutusohjelmia': 0.0,
#  'koordinoida ostotoimintaa': 0.0,
#  'suunnitella maantiekaluston huolto': 0.0,
#  'tarjota tukea itsehoitoon': 0.0,
#  'käyttää käsiporakonetta': 0.0,
#  'valita muottityyppejä': 0.0,
#  'tarkastaa viemärijärjestelmiä': 0.0,
#  'työskennellä elintarvikejalostustiimissä': 0.0,
#  'valmistella juhlatiloja': 0.0,
#  'muuttaa strategia toimiksi ja tavoitteiksi': 0.0,
#  'suorittaa geologisia tutkimuksia': 0.0,
#  'hallinnolliset tehtävät terveydenhuollossa': 0.0,
#  'huonekaluteollisuus': 0.0,
#  'asentaa kumitiivisteitä': 0.0,
#  'tarkastaa oppilaitoksia': 0.0,
#  'laatia työohjelmia': 0.0,
#  'retoriikka': 0.0,
#  'puhallettavat hioma-aineet': 0.0,
#  'asettaa lasi telineisiin': 0.0,
#  'valvoa maastoaluetta': 0.0,
#  'laatia strategioita sähkönjakelun vikatapahtumia varten': 0.0,
#  'käyttää aaltojuotoskonetta': 0.0,
#  'suunnitella soittimia': 0.0,
#  'tietokanta': 0.0,
#  'huolehtia peruukeista': 0.0,
#  'varmistaa potilaan oikea asento leikkausta varten': 0.0,
#  'käyttää ohjelmistosuunnittelun malleja': 0.0,
#  'määrätä lääkkeitä': 0.0,
#  'kehityspsykologia': 0.0,
#  'lukea lämmitysmittareita': 0.0,
#  'tiedon rakenne': 0.0,
#  'ohjelmoitavat logiikat': 0.0,
#  'muokata kipsiä': 0.0,
#  'suunnitella avaruussatelliittihankkeita': 0.0,
#  'testata filmien kehittämiseen käytettäviä kemikaaleja': 0.0,
#  'kartoittaa vikoja putkistoinfrastruktuurista': 0.0,
#  'hoitaa mattoja': 0.0,
#  'analysoida tietojärjestelmiä': 0.0,
#  'muokata kumituotteita': 0.0,
#  'työskennellä ammattikoulussa': 0.0,
#  'toimia potilaan hoitoon osallistuvan monialaisen tiimin vastuuhenkilönä': 0.0,
#  'siivota': 0.0,
#  'pelisäännöt': 0.0,
#  'painovärin poistoprosessit': 0.0,
#  'C++': 0.0,
#  'valita sopivia vaarojen hallintakeinoja': 0.0,
#  'huolehtia kliinisistä tiloista': 0.0,
#  'noudattaa hammaslääkärin ohjeita': 0.0,
#  'ottaa vastaan geenitestaukseen lähetteellä saapuvia potilaita': 0.0,
#  'valmistella baarialue': 0.0,
#  'tutkia kilpailunrajoituksia': 0.0,
#  'tiedottaa asiakkaille toiminnan muutoksista ja peruutuksista': 0.0,
#  'tasapainon fysiologia': 0.0,
#  'noudattaa tarkasti tasoristeyksessä toimimista koskevia ohjeita': 0.0,
#  'kehittää tuotesuunnittelua': 0.0,
#  'kannustaa urheilemaan kouluissa': 0.0,
#  'analysoida omaa esiintymistä': 0.0,
#  'liikerakennusten turvallisuus': 0.0,
#  'ottaa korkeimman tason vastuu sisämaan vesiliikenteessä': 0.0,
#  'analysoida hoidon laatua': 0.0,
#  'koordinoida lentoaikatauluja': 0.0,
#  'käyttää eristysputken käämintäkoneitta': 0.0,
#  'jakelukanavamarkkinointi': 0.0,
#  'valmistella välineet diagnostista kuvantamista varten': 0.0,
#  'oikeustapausten hallinta': 0.0,
#  'vastata koneen säätölaitteen asetuksista': 0.0,
#  'osallistua elintarviketuotantolaitoksen toiminnan suunnitteluun': 0.0,
#  'noudattaa kielioppi- ja oikeinkirjoitussääntöjä': 0.0,
#  'säätää jännitettä': 0.0,
#  'kouluttaa louhintakoneiden hoitajia': 0.0,
#  'ruoan tarjoilutoiminta': 0.0,
#  'testata terveydenhuollon laitteita': 0.0,
#  'hoitaa turvallisuus- ja valvontalaitteita': 0.0,
#  'kalastusalukset': 0.0,
#  'kerätä veroja': 0.0,
#  'osoittaa ammatillista vastuuta': 0.0,
#  'geotiede': 0.0,
#  'valvoa potilaan terveyden tilaa': 0.0,
#  'leikata tekstiilejä': 0.0,
#  'korjata huonekalujen osia': 0.0,
#  'tehdä lämpöenergiamittauksia': 0.0,
#  'käyttää sorkkienleikkaustyökaluja': 0.0,
#  'tehdä puunhakkuukoneiden säännöllisiä huoltoja': 0.0,
#  'suunnitella ruokalistoja': 0.0,
#  'ryöppäyskoneprosessi': 0.0,
#  'huoltaa maatalouskoneita': 0.0,
#  'analysoida soluviljelmiä': 0.0,
#  'käyttää rusnauslaitetta': 0.0,
#  'järjestää tietoa': 0.0,
#  'tallentaa puutavaran käsittelytietoja': 0.0,
#  'huolehtia kuvauslaitteista': 0.0,
#  'akustiikka': 0.0,
#  'kosmeettiset hammastoimenpiteet': 0.0,
#  'määritellä teoksen visuaalinen maailma': 0.0,
#  'huoltaa asennettuja laitteita': 0.0,
#  'huoltaa foliopainatuskonetta': 0.0,
#  'ottaa huonepalvelun tilauksia': 0.0,
#  'terästynnyreiden ja -astioiden valmistus': 0.0,
#  'kerätä tietoja GPS-laitteilla': 0.0,
#  'käyttää levityskonetta': 0.0,
#  'koordinoida lastin käsittelyä': 0.0,
#  'neuvoa alihankkijoita': 0.0,
#  'pujotella kangasvuoraus': 0.0,
#  'säädellä rouhitun tupakan kulkua': 0.0,
#  'esitellä tuotteen ominaisuuksia': 0.0,
#  'sosiaalisen ympäristön vaikutus terveyteen': 0.0,
#  'muokata koruja': 0.0,
#  'verrata maanmittauslaskelmia': 0.0,
#  'suorittaa turvallisuustoimenpiteitä pienaluksella': 0.0,
#  'käyttää käyttäjäkeskeisen suunnittelun menetelmiä': 0.0,
#  'valvoa museoesineiden siirtämistä': 0.0,
#  'kuumasaumaustyypit': 0.0,
#  'ottaa huomioon merenkulun rajoitteet': 0.0,
#  'toimia kuiskaajana esityksissä': 0.0,
#  'käyttää tarkkuusmittausvälineitä': 0.0,
#  'analysoida kuvia': 0.0,
#  'liittää metalleja': 0.0,
#  'asentaa tihkukastelujärjestelmä': 0.0,
#  'käyttää näyttämön liikutusjärjestelmää': 0.0,
#  'korjata nosturikalustoa': 0.0,
#  'taidehistoria': 0.0,
#  'asettaa äänilevyetikettejä': 0.0,
#  'tilata optisia laitteita': 0.0,
#  'puhdistaa aluksia': 0.0,
#  'kehittää markkinoinnin työvälineitä': 0.0,
#  'antaa nitraattien aiheuttamaa pilaantumista koskevia neuvoja': 0.0,
#  'tutkia saastumista': 0.0,
#  'hankkia luvat julkisten tilojen käyttöä varten': 0.0,
#  'spesifikaatiot meijerituotteiden valmistuksessa': 0.0,
#  'vihanhallinta': 0.0,
#  'valvoa kasinohenkilökuntaa': 0.0,
#  'elektronisten laitteiden periaatteet': 0.0,
#  'käyttää ICT-lippujärjestelmää': 0.0,
#  'psykosomatiikka': 0.0,
#  'kirjoittaa ohjekirjoja': 0.0,
#  'urheiluetiikka': 0.0,
#  'tutkia kielenomaksumista': 0.0,
#  'vahata karvoja': 0.0,
#  'valmistaa alusta lasille': 0.0,
#  'varmistaa putkistoinfrastruktuurin säädöstenmukaisuus': 0.0,
#  'kertoa suuterveydestä ja sairauksien ehkäisystä': 0.0,
#  'mainostaa tuotteita mainoksissa': 0.0,
#  'hoitaa anodisointikonetta': 0.0,
#  'asentaa metallikattoja': 0.0,
#  'kehittää liikekumppanuuksia': 0.0,
#  'uskontotiede': 0.0,
#  'suorittaa lastaamis- ja purkamistoimintoja': 0.0,
#  'koristella kynsiä': 0.0,
#  'geofysiikka': 0.0,
#  'arvioida osakkeen arvo': 0.0,
#  'tunnistaa uusien mallien kohdemarkkinat': 0.0,
#  'kaupunkialueilla käytettävien ajoneuvojen mekaaniset vaatimukset': 0.0,
#  'valmistaa tilaukset': 0.0,
#  'tarkastaa virallisia asiakirjoja': 0.0,
#  'antaa tukea sopeutumisessa fyysiseen vammaan': 0.0,
#  'analysoida kokeellisia laboratoriotuloksia': 0.0,
#  'ostaa automateriaaleja': 0.0,
#  'tarkistaa kaiverruksen tarkkuus': 0.0,
#  'kehittää ratkaisuja haitalliseen käytökseen': 0.0,
#  'tehdä virkistystilojen käyttöaikataulu': 0.0,
#  'suunnitella sairaanhoitoa': 0.0,
#  'hydrografia': 0.0,
#  'valaa korumetalleja': 0.0,
#  'pitää varasto järjestyksessä': 0.0,
#  'puhua julkisesti': 0.0,
#  'kiinnittää aluksia laituriin': 0.0,
#  'oikomishoito': 0.0,
#  'järjestää työnhaun työpajoja': 0.0,
#  'käyttää pumppauslaitteita': 0.0,
#  'viljellyt helmet': 0.0,
#  'hankkia keskeisiä tietoja projekteista': 0.0,
#  'syöttää materiaaleja uuniin': 0.0,
#  'sekoittaa ainesosia lateksiin': 0.0,
#  'puhdistaa ilmastointijärjestelmiä': 0.0,
#  'täyttää öljylähdettä koskevia tietolomakkeita': 0.0,
#  'louhintatekniikat': 0.0,
#  'seurata henkilökunnan poissaoloja': 0.0,
#  'asentaa laskettu sisäkatto': 0.0,
#  'mausteiden valmistusprosessit': 0.0,
#  'valmistaa puolijohdekiteitä': 0.0,
#  'käyttää betoniharkkojen valukonetta': 0.0,
#  'käyttäytyä hillitysti': 0.0,
#  'estää petollista toimintaa': 0.0,
#  'käyttää merenkulun englantia': 0.0,
#  'valmistaa kolmiulotteisia jalkineprototyyppejä tietokoneavusteisesti': 0.0,
#  'putkikuljetusta koskevat määräykset': 0.0,
#  'hoitaa tiilipuristinta': 0.0,
#  'asentaa ikkuna': 0.0,
#  'käyttää irrotusveistä': 0.0,
#  'dokumentoida turvatoimenpiteet': 0.0,
#  'erottaa epävakaat elementit vedessä': 0.0,
#  'nähtävyystiedot': 0.0,
#  'tehdä aistinvaraista arviointia': 0.0,
#  'kirkastaa öljyä saostamalla': 0.0,
#  'selittää bingon säännöt': 0.0,
#  '3D-tulostusprosessi': 0.0,
#  'antaa työntekijöille toiminnan tehostamiskoulutusta': 0.0,
#  'vähentää putkijohtohankkeiden ympäristövaikutuksia': 0.0,
#  'nahkatuotteiden rakenneosat': 0.0,
#  'huolehtia omasta ulkonäöstä': 0.0,
#  'kehittää strategisia suunnitelmia fysioterapiapalveluille': 0.0,
#  'suunnitella rakennusten huoltotoimia': 0.0,
#  'pakata tuotteita lahjapakettiin': 0.0,
#  'korjauttaa varusteita': 0.0,
#  'sovellettu eläintiede': 0.0,
#  'prosessiperusteinen hallinta': 0.0,
#  'silkkipainokoneet': 0.0,
#  'ehkäistä terveys- ja turvallisuusongelmia': 0.0,
#  'antaa geneettisten sairauksien diagnostisiin sikiötutkimuksiin liittyviä neuvoja': 0.0,
#  'edustaa uskonnollista instituutiota': 0.0,
#  'säteilysuojaus': 0.0,
#  'käyttää kalastusvälineiden valmistuskonetta': 0.0,
#  'määritellä ihotyyppi': 0.0,
#  'työskennellä sirkusryhmän kanssa': 0.0,
#  'huolehtia karbonointitasoista': 0.0,
#  'rajoittaa lastia vahinkojen ehkäisemiseksi': 0.0,
#  'valvoa munantuotantoa': 0.0,
#  'tehdä mosaiikkia': 0.0,
#  'valvoa kiertokäyntejä': 0.0,
#  'tehdä kastikkeita ja keittoja': 0.0,
#  'hoitaa tyhjiöpursotinta': 0.0,
#  'terveydenhuolto': 0.0,
#  'tunnistaa lahjakkaan oppilaan merkkejä': 0.0,
#  'ammattisanasto': 0.0,
#  'varmistaa vieraiden yksityisyys': 0.0,
#  'käyttää restaurointitekniikoita': 0.0,
#  'hoitaa tuotetilauksia asiakkaiden puolesta': 0.0,
#  'pitää tuotantokirjaa': 0.0,
#  'huolehtia vesiviljelmien vedenlaadusta': 0.0,
#  'tasoittaa lasin pintaa': 0.0,
#  'neuvoa asiakkaita uusien laitteiden käytössä': 0.0,
#  'rekisteröidä virallisia asiakirjoja': 0.0,
#  'asentaa lattianpäällysteitä': 0.0,
#  'tarkastaa raaka-aineiden laatu': 0.0,
#  'vaatetus- ja jalkinetuotteet': 0.0,
#  'elintarvikehygieniaa koskevat määräykset': 0.0,
#  'huolehtia kuiskaajan pääkirjasta': 0.0,
#  'hoitaa ikeniä': 0.0,
#  'varmistaa tuotteiden vaatimustemukaisuus': 0.0,
#  'haastattelututkimustekniikat': 0.0,
#  'ohjata lentoaseman alihankkijoita': 0.0,
#  'antaa aikuisopetusta': 0.0,
#  'tarkastaa käytettyjen tavaroiden myyntipotentiaali': 0.0,
#  'arvioida ympäristösuunnitelmia talouden näkökulmasta': 0.0,
#  'huoltaa teknisiä välineitä': 0.0,
#  'käsitellä rikkoutuneita lasilevyjä': 0.0,
#  'käyttää hoitotyössä kokonaisvaltaista lähestymistapaa': 0.0,
#  'muokata lasia': 0.0,
#  'seurata tuotantoaikataulua': 0.0,
#  'säätää videolähetyksen asetuksia': 0.0,
#  'huolehtia lentoaseman valvontainfrastruktuurista': 0.0,
#  'proteiini': 0.0,
#  'kuljettaa vierailijoita': 0.0,
#  'ohjata nosturinkuljettajia': 0.0,
#  'huolehtia henkilökohtaisista raha-asioista': 0.0,
#  'tehdä fysikaalisia stressitestejä malleille': 0.0,
#  'pyrkiä säilyttämään veden koostumus': 0.0,
#  'antaa neuvoja eläinten omistajille': 0.0,
#  'käyttää vannesahaa': 0.0,
#  'tehdä rikosteknisiä tutkimuksia': 0.0,
#  'kotieläintalous': 0.0,
#  'lukea sähkömittareita': 0.0,
#  'ylläpitää arkistoa lääkemääräyksistä ja lääkkeistä': 0.0,
#  'projektiolaitteet': 0.0,
#  'suorittaa avaamis- ja sulkemismenettelyt': 0.0,
#  'suunnitella terveys- ja turvallisuustoimenpiteitä': 0.0,
#  'ajaa moottoriajoneuvojen prototyyppejä': 0.0,
#  'käsitellä lihanjalostuslaitteita jäähdytyshuoneissa': 0.0,
#  'peruselintoimintojen häiriöt': 0.0,
#  'noudattaa ympäristöystävällisiä käytäntöjä elintarvikkeiden jalostuksessa': 0.0,
#  'mitata aikaa tarkasti': 0.0,
#  'korjata maanalaisia voimakaapeleita': 0.0,
#  'suorittaa potilaalle proteesitutkimus': 0.0,
#  'tarjota tieto- ja viestintäteknistä tukea': 0.0,
#  'säätää savenpolton lämpötilaa': 0.0,
#  'antaa terveysneuvontaa': 0.0,
#  'johtaa tapahtuman rakenteiden asennusta': 0.0,
#  'hoitaa viilauskonetta': 0.0,
#  'hiivakäymisen periaatteet': 0.0,
#  'suorittaa pastörointiprosesseja': 0.0,
#  'antaa asiakkaille hedelmien ja vihannesten käsittelyä koskevia neuvoja': 0.0,
#  'testata, että hammasapuvälineet ovat määräysten mukaisia': 0.0,
#  'ampumatarvikkeisiin liittyvät oikeudelliset vaatimukset': 0.0,
#  'johtaa laadunvalvontaa': 0.0,
#  'klassiset kielet': 0.0,
#  'koordinoida vuoroja': 0.0,
#  'analysoida vedonlyöntidataa': 0.0,
#  'käyttää biologista suodatusta': 0.0,
#  'kalojen ja äyriäisten käsittely': 0.0,
#  'työskennellä maalla toimivassa ryhmässä': 0.0,
#  'soveltaa montessoripedagogiikan opetusstrategioita': 0.0,
#  'suorittaa tekninen äänentarkistus': 0.0,
#  'urheiluvälineiden käyttö': 0.0,
#  'opettaa lukustrategioita': 0.0,
#  'vaarallisten aineiden kuljetus': 0.0,
#  'käyttää eläintautien epidemiologiaan liittyviä tietoja': 0.0,
#  'myydä kankaita': 0.0,
#  'paikallismaantiede': 0.0,
#  'puhdistaa öljynjalostusyksiköitä': 0.0,
#  'myöntää virallisia asiakirjoja': 0.0,
#  'opettaa matematiikkaa': 0.0,
#  'tarkastaa kasinosali': 0.0,
#  'puhaltaa pintoja': 0.0,
#  'avustaa lentäjää pakkolaskutilanteessa': 0.0,
#  'kvanttimekaniikka': 0.0,
#  'käyttää puuhiokekartonkipuristinta': 0.0,
#  'suorittaa virallistettuja tulkkauksia': 0.0,
#  'paahdetun maltaan värit': 0.0,
#  'huolehtia lisäaineiden käytöstä elintarvikkeiden valmistuksessa': 0.0,
#  'reiki': 0.0,
#  'käyttää laivan laitteita': 0.0,
#  'eläinravitsemus': 0.0,
#  'käyttää olio-ohjelmointia': 0.0,
#  'levittää suihkurusketusta': 0.0,
#  'merentutkimus': 0.0,
#  'sähkölaitteiden komponentit': 0.0,
#  'sietää voimakkaita hajuja': 0.0,
#  'lääkkeiden valmistuksen laatujärjestelmät': 0.0,
#  'oikeussanasto': 0.0,
#  'käyttää siistauskemikaaleja': 0.0,
#  'huoltaa puuhiokekartonkikoneita': 0.0,
#  'analysoida kaukoputkella otettuja kuvia': 0.0,
#  'tehdä kemiallisia kokeita': 0.0,
#  'luoda projektimääritykset': 0.0,
#  'lisätä tietoisuutta paikallisyhteisöä koskevista tärkeistä ongelmista': 0.0,
#  'osallistua urheiluharjoituksiin': 0.0,
#  'valmistaa räätälöityjä tuotteita': 0.0,
#  'tiedottaa työsuojelutoimenpiteistä': 0.0,
#  'tunnistaa talousrikoksia': 0.0,
#  'semantiikka': 0.0,
#  'korjata satoa': 0.0,
#  'markkinaosapuolet': 0.0,
#  'tunnistaa puun käyristyminen': 0.0,
#  'rahdinkäsittelyn kansalliset määräykset': 0.0,
#  'käsitellä kaivosjätteitä': 0.0,
#  'pitää kirjaa museon kokoelmista': 0.0,
#  'varmistaa elintarviketuotantolaitoksen koneiden täydellinen toiminta': 0.0,
#  'asentaa tuuletuslaitteita': 0.0,
#  'tekohartsit': 0.0,
#  'kehittää erikoistarjouksia': 0.0,
#  'antaa kliinistä neurologiaa hyödyntävää kiropraktista hoitoa': 0.0,
#  'aluksen turvavarusteet': 0.0,
#  'määritellä tulipaloriskejä': 0.0,
#  'huolehtia verkkoviestinnästä': 0.0,
#  'hallita erilaisia hedelmien ja vihannesten kuivatusprosesseja': 0.0,
#  'analysoida öljynporaustoimintaa koskevia tietoja': 0.0,
#  'tehdä terveyteen liittyvää tutkimusta': 0.0,
#  'noudattaa kansallisten ja kansainvälisten turvallisuusohjelmien standardeja': 0.0,
#  'terveyskasvatus': 0.0,
#  'tuuliturbiinityypit': 0.0,
#  'vaarallisten aineiden kansainvälinen maantiekuljetus': 0.0,
#  'puusepäntuotteiden valmistus': 0.0,
#  'arvioida sisustussuunnitelman budjetti': 0.0,
#  'elintarvikkeisiin ja juomiin liittyvät fyysiset, kemialliset ja biologiset riskit': 0.0,
#  'valmistella rakennuslupahakemuksia': 0.0,
#  'auttaa asiakkaita tekemään päätöksiä terapian aikana': 0.0,
#  'huolehtia raideliikenteen turvallisuudesta korjaustöiden aikana': 0.0,
#  'laatia terveysasiakirjoja': 0.0,
#  'soveltaa ennen opetusta annettavan tukiopetuksen menetelmiä': 0.0,
#  'käsitellä filmiä': 0.0,
#  'laatia lentoaseman pelastussuunnitelmat': 0.0,
#  'laskea viiniä': 0.0,
#  'ylläpitää raportteja kassatapahtumista': 0.0,
#  'toteuttaa politiikkaa terveydenhuollon käytännöissä': 0.0,
#  'tekniset piirustukset': 0.0,
#  'pitää kirjaa rahdista': 0.0,
#  'toimia hevostapahtumien johtajana': 0.0,
#  'huolehtia fleksopainoprosesseista': 0.0,
#  'valmistaa veistoksen prototyyppi': 0.0,
#  'asentaa kaapeli-TV-palveluja': 0.0,
#  'tarkastaa toimitettu betoni': 0.0,
#  'polttimen lämpötila metallinkäsittelyssä': 0.0,
#  'tehdä sumutuslaitteiden turvatarkistuksia': 0.0,
#  'esittää vapaa-ajan toimintaa': 0.0,
#  'sirkussanasto': 0.0,
#  'käyttää metallintyöstötyökaluja': 0.0,
#  'käyttää käsimerkkejä kuljetustoimenpiteissä': 0.0,
#  'järjestää ajoneuvojen teknisiä käyttötietoja koskevia asiakirjoja': 0.0,
#  'hätätilanteiden hoidossa käytettävät psykologian menetelmät': 0.0,
#  'näytellä liikkeenkaappausvarusteissa': 0.0,
#  'valita vesiviljelylaitteita': 0.0,
#  'noudattaa lentopaikan toimintakäsikirjan määräyksiä': 0.0,
#  'kylvettää koiria': 0.0,
#  'tehdä potilaan aktiivisuusanalyyseja': 0.0,
#  'valmistella huonekaluja maalaamista varten': 0.0,
#  'antaa öljyntuotantoa koskevaa teknistä tukea': 0.0,
#  'kirjoittaa nopeasti koneella': 0.0,
#  'asentaa lähetyslaitteet': 0.0,
#  'hallinnoida arvopaperikauppaa': 0.0,
#  'jakaa kulkulupia': 0.0,
#  'antaa potilaille mahdollisuus tutkia taideteoksia': 0.0,
#  'kliininen farmakologia ja lääkehoito': 0.0,
#  'tutkia määrien välisiä suhteita': 0.0,
#  'valvoa viljeltyjen kalalajien kasvunopeutta': 0.0,
#  'tulkita raitiovaunujen liikennemerkkejä': 0.0,
#  'antaa tietoja historiallisesta kontekstista': 0.0,
#  'käyttää paperipuristinta': 0.0,
#  'kirjoittaa sähkölaitteilla': 0.0,
#  'valvoa metsän kuntoa': 0.0,
#  'maailmanlaajuisen satelliittinavigointijärjestelmän suorituskykyparametrit': 0.0,
#  'käyttää elektronisuihkuhitsauskonetta': 0.0,
#  'käyttää astianpesukonetta': 0.0,
#  'ajoneuvotyypit': 0.0,
#  'vesipolitiikka': 0.0,
#  'tarkastaa materiaalien yhteensopivuus': 0.0,
#  'huolehtia ajoneuvojen varaosien saatavuudesta': 0.0,
#  'suorittaa tutkimushaastatteluja': 0.0,
#  'kaivosturvallisuuteen liittyvä lainsäädäntö': 0.0,
#  'ohjata musiikkiryhmiä': 0.0,
#  'vastata kliinisestä kiropraktisesta tutkimuksesta': 0.0,
#  'tuottaa tekstiilinäytteitä': 0.0,
#  'pitää kokeita': 0.0,
#  'läheisen kuoleman käsittelyn vaiheet': 0.0,
#  'osoittaa sosiaalisia taitoja': 0.0,
#  'helpottaa seksuaalirikoksiin liittyvää toipumisprosessia': 0.0,
#  'wc-istuintyypit': 0.0,
#  'antaa kotitehtäviä': 0.0,
#  'laskea jalkineiden ja nahkatuotteiden valmistuskapasiteetti': 0.0,
#  'valvoa käymisprosessia': 0.0,
#  'annostella materiaaleja betoninsekoittimeen': 0.0,
#  'muovata suklaata': 0.0,
#  'huolehtia lasin paksuudesta': 0.0,
#  'käyttää porausvaunua': 0.0,
#  'ohjata hissivaunun asennusta': 0.0,
#  'taivuttaa kimpiä': 0.0,
#  'kirjata asiakkaan henkilötiedot': 0.0,
#  'luonnonmukaiset rakennusmateriaalit': 0.0,
#  'kalojen anatomia': 0.0,
#  'käyttää pultituskonetta': 0.0,
#  'urheiluvarusteiden valmistus': 0.0,
#  'käyttää lukkosepän työkaluja': 0.0,
#  'toimintaterapian teoriat': 0.0,
#  'jäljittää ihmisiä': 0.0,
#  'proteesien ja ortoosien materiaalit': 0.0,
#  'tarkastaa lihaelintarvikejalostuksen raaka-aineet': 0.0,
#  'kauko-ohjata tuotantolinjaa': 0.0,
#  'työskennellä video- ja elokuvatuotantoryhmän kanssa': 0.0,
#  'käyttää vedynpoistolaitteita': 0.0,
#  'vastata koiranjalostukseen liittyvistä tehtävistä': 0.0,
#  'tyhjentää yhteisöjäteastioita': 0.0,
#  'hoitaa kelauskoneita': 0.0,
#  'toteuttaa puhtaanapitotoimenpiteitä': 0.0,
#  'korjata kodinkoneita': 0.0,
#  'laatia konossementteja': 0.0,
#  'myydä palveluita': 0.0,
#  'osoittaa perehtyneisyyttä pakkausstandardeihin': 0.0,
#  'Kalifornia-pohjausmenetelmällä valmistettujen kenkien kokoamisprosessit ja -tekniikat': 0.0,
#  'koota tavaroita': 0.0,
#  'kaakaopapujen paahtamisessa tapahtuvat kemialliset reaktiot': 0.0,
#  'antaa kliinistä psykologista tukea kriisitilanteissa': 0.0,
#  'terveydenhuollon henkilökunnan johtaminen': 0.0,
#  'arvioida nautaeläinten sorkkien hoitovaatimuksia': 0.0,
#  'ylläpitää leirintätiloja': 0.0,
#  'varmistaa koreografian säilyttäminen': 0.0,
#  'huolehtia jalkineiden laatujärjestelmistä': 0.0,
#  'ratkaista kuljetusten operatiivisia ongelmia': 0.0,
#  'pysyä ajan tasalla hiusmuodista': 0.0,
#  'lastata rahtia': 0.0,
#  'huolehtia oppitunnin materiaaleista': 0.0,
#  'verolainsäädäntö': 0.0,
#  'seurata puhelinpalvelukeskusten keskeisiä suorituskykyindikaattoreita': 0.0,
#  'moderoida keskustelufoorumia': 0.0,
#  'annostella ainesosia elintarviketuotannossa': 0.0,
#  'todennäköisyysteoria': 0.0,
#  'antaa merenkulkua koskevaa neuvontaa': 0.0,
#  'psykopatologia': 0.0,
#  'asettaa tuotannon keskeisiä suorituskykyindikaattoreita': 0.0,
#  'edistää kestävän energian käyttöä': 0.0,
#  'edistää positiivista käsitystä hoitotyöstä': 0.0,
#  'asentaa tuulensuojamuovia': 0.0,
#  'lentokoneiden opastamiseen liittyvät vaaratekijät': 0.0,
#  'suunnitella automaatiokomponentteja': 0.0,
#  'antaa lakien säätämistä koskevaa neuvontaa': 0.0,
#  'arvioida asiakkaan päihderiippuvuuksia': 0.0,
#  'myydä ohjelmistotuotteita': 0.0,
#  'käsitellä asiakastiedot sisältäviä tilauslomakkeita': 0.0,
#  'torjua rikkakasveja': 0.0,
#  'järjestää harjoitukset': 0.0,
#  'varmistaa ympäristölainsäädännön noudattaminen': 0.0,
#  'tulkita asiakkaan sanatonta viestintää': 0.0,
#  'eurooppalainen junakulunvalvontajärjestelmä': 0.0,
#  'avustaa verinäytteiden ottamisessa': 0.0,
#  'hakea kirjastolle rahoitusta': 0.0,
#  'kirjoittaa juonikuvauksia': 0.0,
#  'laskea provisioiden määrä': 0.0,
#  'antaa tukea talouslaskelmien teossa': 0.0,
#  'hallita valuuttariskin vähennystekniikoita': 0.0,
#  'tiedotusoppi': 0.0,
#  'lisätä tietokoneen osia': 0.0,
#  'valvoa opetusohjelmaan kuulumattomia tapahtumia': 0.0,
#  'hallinnoida lentotietojen välitysohjelmaa': 0.0,
#  'liikkeenjohdon periaatteet': 0.0,
#  'tarkastaa henkilökunta': 0.0,
#  'raportoida tiimin päällikölle': 0.0,
#  'käyttää jalkineiden päällysten esikokoonpanotekniikoita': 0.0,
#  'avustaa eläinten diagnostisissa kuvantamistoimenpiteissä': 0.0,
#  'restauroida soittimia': 0.0,
#  'lentokelpoisuusmääräysten sisältö': 0.0,
#  'psykologiset toimenpiteet': 0.0,
#  'puhdistaa pintoja': 0.0,
#  'asentaa vesisäiliö': 0.0,
#  'käyttää juotostekniikoita': 0.0,
#  'aikatauluttaa lentoaseman sähköjärjestelmien huolto': 0.0,
#  'sukellustukialusten järjestelmät': 0.0,
#  'sähkökoneet': 0.0,
#  'myyntistrategia': 0.0,
#  'neuro-oftalmologia': 0.0,
#  'leikata paperin reunoja': 0.0,
#  'annostella lääkeaineita kaloille': 0.0,
#  'Schoology': 0.0,
#  'arvioida kuljetukseen liittyviä riskejä': 0.0,
#  'hankkia pitopalveluita': 0.0,
#  'mukautua erilaisiin rooleihin': 0.0,
#  'antaa erityisruokavalioiden toteuttamiseen liittyviä neuvoja': 0.0,
#  'kaivosalan politiikkatoimet': 0.0,
#  'tarjota taidevalmennusharjoituksia': 0.0,
#  'puhetulkkaus': 0.0,
#  'käyttää lämmönseurantaa': 0.0,
#  'kerrontatekniikat': 0.0,
#  'valmistajan ohjeet audiovisuaalisille laitteille': 0.0,
#  'tehdä strategisia liiketoimintapäätöksiä': 0.0,
#  'suunnitella koneiden säännöllisen huollon aikatauluja': 0.0,
#  'kehittää ohjelmistoa musiikkiterapiaistuntoihin': 0.0,
#  'moottoriajoneuvon osapiirustukset': 0.0,
#  'märkärummutus': 0.0,
#  'valmistella ruoassa käytettävät kasvikset': 0.0,
#  'tehdä muutoksia vaatteisiin': 0.0,
#  'suodattaa viiniä': 0.0,
#  'korjata laminoituja rakenteita': 0.0,
#  'käsitellä kerättyä hunajaa': 0.0,
#  'kiipeilyköyden kiinnitystekniikat': 0.0,
#  'suunnitella tapahtumamarkkinointia markkinointikampanjoihin': 0.0,
#  'ajoneuvojen sähköjärjestelmät': 0.0,
#  'maantieteelliset alueet': 0.0,
#  'tarjota räätälöityjä rakennusmateriaaleja': 0.0,
#  'tekstiilimateriaalit': 0.0,
#  'tutkia aiheita': 0.0,
#  'lasin päällysteet': 0.0,
#  'kodinsisustustekniikat': 0.0,
#  'nykyaikaiset sähköiset opastinjärjestelmät': 0.0,
#  'hälytysjärjestelmät': 0.0,
#  'huolehtia fyysisistä resursseista': 0.0,
#  'valvoa jätteenkäsittelylaitteita': 0.0,
#  'suunnitella jalkineiden ja nahkatuotteiden toimitusketjulogistiikkaa': 0.0,
#  'käyttää kaarihitsauksen tekniikoita': 0.0,
#  'ottaa yhteyttä asiakkaisiin': 0.0,
#  'ehkäistä satohäiriöitä': 0.0,
#  'esittää eläinten omistajille kysymyksiä eläinten terveydentilasta': 0.0,
#  'arvioida kellojen arvoa': 0.0,
#  'tehdä tutkimusta edistyneestä sairaanhoidosta': 0.0,
#  'tarkkailla laitteita': 0.0,
#  'kierretyypit': 0.0,
#  'ratkaista ongelmia': 0.0,
#  'käyttää raitiovaunujärjestelmän seurantalaitteistoa': 0.0,
#  'avustaa eläinten synnytyksissä': 0.0,
#  'säätää lämpötilaa': 0.0,
#  'keskustella terveydenhuollon käyttäjän terveyshistoriasta': 0.0,
#  'työskennellä solistien kanssa': 0.0,
#  'istuttaa mikrosiruja eläimiin': 0.0,
#  'panimoprosessit': 0.0,
#  'avustaa lentoon liittyvissä tarkastustoimissa': 0.0,
#  'hoitaa front-toimintoja': 0.0,
#  'analysoida tietoja ilmailualan julkaisuja varten': 0.0,
#  'hyvät tuotantotavat': 0.0,
#  'opettaa opettamisen periaatteita': 0.0,
#  'osallistua omalla panoksella lääketieteen opettamiseen': 0.0,
#  'turvamääräykset': 0.0,
#  'viestiä vierailla kielillä terveydenhuollon ammattilaisten kanssa': 0.0,
#  'tuoda hyödykkeitä': 0.0,
#  'tupakkatuotteet': 0.0,
#  'elintarvikkeiden ainesosat': 0.0,
#  'luonnostella kampaus-, puvustus- tai maskeerausaikataulu': 0.0,
#  'varmistaa taistelukohtausten jatkuvuus': 0.0,
#  'suunnitella': 0.0,
#  'valvoa jätevedenkäsittelyä': 0.0,
#  'antaa neuvoja lämmitysjärjestelmien energiatehokkuudesta': 0.0,
#  'metallisten kokoonpanotuotteiden valmistus': 0.0,
#  'CryEngine': 0.0,
#  'farmaseuttinen biologia': 0.0,
#  'vertailla kiinteistöjen hintoja': 0.0,
#  'hoitaa vedenalaista elinympäristöä': 0.0,
#  'keskustella oppilaitoksen hallintohenkilöstön kanssa': 0.0,
#  'energia': 0.0,
#  'ajatella luovasti koruista': 0.0,
#  'analysoida puhelinpalvelukeskuksen toimintaa': 0.0,
#  'sitoutua jatkuvaan ammatilliseen oppimiseen kalastustyössä': 0.0,
#  'sopeutua teknisten kehityssuunnitelmien muutoksiin': 0.0,
#  'valvoa päivittäisiä töitä': 0.0,
#  'tehdä korjauksia avoautojen kattopeitteeseen': 0.0,
#  'pitää musiikkiterapiaistuntoja': 0.0,
#  'kaiverrettavat kivityypit': 0.0,
#  'myydä sähkötyökaluja': 0.0,
#  'pitää merkinnät luettavina': 0.0,
#  'antaa opiskelijaohjausta': 0.0,
#  'soveltaa ilmatilan joustavan käytön käsitettä': 0.0,
#  'siirtää tiiliä': 0.0,
#  'neuvoa asiakkaita vientirajoituksista': 0.0,
#  'sähköturvallisuusmääräykset': 0.0,
#  'käyttää tribometriä': 0.0,
#  'hallita ICT-muutospyyntöprosesseja': 0.0,
#  'varmistaa junien liikennöinti aikataulun mukaisesti': 0.0,
#  'sädettää': 0.0,
#  'käyttää puutarhanhoitolaitteita': 0.0,
#  'APL': 0.0,
#  'tarkastaa vedenpaine': 0.0,
#  'asentaa pingotettu sisäkatto': 0.0,
#  'analysoida skannaamalla hankittuja kehontietoja': 0.0,
#  'energia-alan politiikkatoimet': 0.0,
#  'suorittaa etsintä- ja pelastustehtäviä': 0.0,
#  'tietokoneavusteinen vaatteiden suunnittelu': 0.0,
#  'hävittää lääketieteellistä jätettä': 0.0,
#  'määritellä kuormien painopisteitä': 0.0,
#  'tutkia vaatemalleja': 0.0,
#  'kouluttaa eläimiä': 0.0,
#  'radiologiset menettelytavat': 0.0,
#  'auttaa lapsia kotitehtävissä': 0.0,
#  'käsitellä geenitestauksen eettisiä kysymyksiä': 0.0,
#  'musiikkiterapian prosessit': 0.0,
#  'suunnitella vesiluonnonvarojen ruokintaohjelmia': 0.0,
#  'muokata vaatteita': 0.0,
#  'huolehtia reseptien noudattamisesta': 0.0,
#  'kehittää vierailijoiden sitouttamisstrategioita': 0.0,
#  'ylläpitää ajoneuvon asiakirjoja': 0.0,
#  'väkevöidä tislattuja alkoholijuomia': 0.0,
#  'eläinten käyttäytyminen': 0.0,
#  'vastata sianjalostukseen liittyvistä tehtävistä': 0.0,
#  'ripustaa eläimiä': 0.0,
#  'johtaa poliisitutkintaa': 0.0,
#  'mukautua käytettävän median vaatimuksiin': 0.0,
#  'viedä tapaus korkeammalle tasolle': 0.0,
#  'hoitaa turvatoimia pidätyskeskuksessa': 0.0,
#  'valvoa myyntitilan turvallisuutta': 0.0,
#  'levittää kromaattia sisältävää reaktiopinnoitetta metallityökappaleeseen': 0.0,
#  'antaa kiinteistön arvoon liittyviä neuvoja': 0.0,
#  'valmistella tuotantoprototyyppejä': 0.0,
#  'noudattaa valmistajien ohjeita lentoaseman laitteistoja käytettäessä': 0.0,
#  'mukauttaa johtamistyylejä terveydenhuollossa': 0.0,
#  'käyttää kiiloja': 0.0,
#  'periä WC-tilojen käyttömaksuja': 0.0,
#  'kehittää mekatroniikkalaitteiden testausmenetelmiä': 0.0,
#  'ottaa käyttöön turvallisuudenhallintajärjestelmiä': 0.0,
#  'vastasyntyneiden hoito': 0.0,
#  'tutkia verotusmenettelyjä': 0.0,
#  'muokata vaatesuunnitelmia': 0.0,
#  'pinota puutavaraa': 0.0,
#  'kehittää tiedotusharjoittelusuunnitelmia': 0.0,
#  'antaa porausohjeita': 0.0,
#  'kiertää metallia': 0.0,
#  'ydinpolttoaineen jälleenkäsittely': 0.0,
#  'avustaa markkinointisuunnitelmien kehittämisen käytännön toimissa': 0.0,
#  'vanhusten hyväksikäyttö- tai pahoinpitelytapausten käsittelystrategiat': 0.0,
#  'imuroida pintoja': 0.0,
#  'pitää kirjaa käytetyistä hoidoista ja lääkkeistä vesiviljelyssä': 0.0,
#  'simuloida mekatroniikan suunnittelukonsepteja': 0.0,
#  'lentoaseman ympäristömääräykset': 0.0,
#  'pitää kirjaa esiintymisasuista': 0.0,
#  'esiintyä yleisölle': 0.0,
#  'noudattaa liikennesääntöjä sisävesiväylillä': 0.0,
#  'valvoa hyllyjen täyttämistä': 0.0,
#  'aseiden ja ampumatarvikkeiden valmistus': 0.0,
#  'liittää liiketoimintateknologia käyttäjäkokemuksiin': 0.0,
#  'määritellä visuaaliset konseptit': 0.0,
#  'valvoa toimitusten reititystä': 0.0,
#  'kehittää kauppapolitiikkaa': 0.0,
#  'testata valokuvausvälineitä': 0.0,
#  'turkistuotteiden valmistus': 0.0,
#  'koota ohjelmisto': 0.0,
#  'käyttää vedenpuhdistuslaitteistoa': 0.0,
#  'käyttää valaistuslaitteita': 0.0,
#  'kuvata omia taiteellisia pyrkimyksiä suhteessa taiteen suuntauksiin': 0.0,
#  'käsin tekeminen': 0.0,
#  'huoltaa laboratoriolaitteita': 0.0,
#  'jaettujen hakemistojen tietopalvelut': 0.0,
#  'tarkastaa materiaaliresurssit': 0.0,
#  'noudattaa teknisiä vaatimuksia': 0.0,
#  'hoitaa juomien kaasutinvälineitä': 0.0,
#  'käyttää kaasuturbiineja': 0.0,
#  'asettaa varoituksia sukelluskohteen ympärille': 0.0,
#  'sekoittaa elintarvikkeita': 0.0,
#  'optomekaaniset laitteet': 0.0,
#  'arvioida alusten vakautta': 0.0,
#  'hoitaa valkaisuhollanteria': 0.0,
#  'kasinopelien säännöt': 0.0,
#  'tarjota hoitopalveluita kouluajan ulkopuolella': 0.0,
#  'pitää kirjaa korujen painosta': 0.0,
#  'käyttää sähköistä potilastietojärjestelmää sairaanhoidossa': 0.0,
#  'suunnitella lasimaalauksia': 0.0,
#  'tehdä kadun hätäpuhdistuksia': 0.0,
#  'suklaan historia': 0.0,
#  'kahvin jauhatusasteet': 0.0,
#  'käyttää tekstinkäsittelyohjelmistoja': 0.0,
#  'tarjota ruokaa ja juomia': 0.0,
#  'korjata ICT-laitteita': 0.0,
#  'koostaa rautateiden merkinantoraportteja': 0.0,
#  'huolehtia aluksen messinkiosista': 0.0,
#  'turvata esityksen taiteellinen laatu': 0.0,
#  'kastelujärjestelmät': 0.0,
#  'nimetä leimoja': 0.0,
#  'valmistaa salaatinkastikkeita': 0.0,
#  'graffitin poistotekniikat': 0.0,
#  'huoltaa jarrujärjestelmiä': 0.0,
#  'laatia osaston aikataulu henkilöstölle': 0.0,
#  'leikata eristemateriaalia oikean kokoiseksi': 0.0,
#  'pystyttää porauslauttoja': 0.0,
#  'lähettää ohjelmaa käyttämällä IP-protokollaa': 0.0,
#  'käyttäytymistiede': 0.0,
#  'testata maakaluston suorituskykyä': 0.0,
#  'tunnistaa jalokiviä': 0.0,
#  'jalkineiden päällisten valmistelu': 0.0,
#  'alusten sähköjärjestelmät': 0.0,
#  'kaasukondensaatin talteenottoprosessit': 0.0,
#  'käyttää toto-taulua': 0.0,
#  'kertoa ihmisille luonnosta': 0.0,
#  'liikehoito': 0.0,
#  'hioa jalokiviä hiekkapaperilla': 0.0,
#  'käyttää ohjausjärjestelmiä': 0.0,
#  'islam': 0.0,
#  'luokitella kahvipapuja': 0.0,
#  'hoitaa määriteltyjä potilasryhmiä': 0.0,
#  'tehdä kvalitatiivista tutkimusta': 0.0,
#  'varmistaa laivojen turvatoimet': 0.0,
#  'kaukokartoitustekniikat': 0.0,
#  'puhdistaa vesiviljelykantojen yksiköitä': 0.0,
#  'hallinnoida henkilöstötoimintoja': 0.0,
#  'ohjauskeskuksen osat': 0.0,
#  'auttaa taiteellisen työn dokumentoinnissa kaikissa vaiheissa': 0.0,
#  'asiakastietous': 0.0,
#  'analysoida kirjastonkäyttäjien kyselyjä': 0.0,
#  'yhteisökuntoutus': 0.0,
#  'kehittää elintarviketurvallisuusohjelmia': 0.0,
#  'työskennellä sosiaalipalveluiden käyttäjäryhmän kanssa': 0.0,
#  'mobiililaitteiden ohjelmistokehykset': 0.0,
#  'käyttää jäljitettävyysjärjestelmiä': 0.0,
#  'tukea sosiaalipalveluiden käyttäjiä kotona asumisessa': 0.0,
#  'kirjallisuushistoria': 0.0,
#  'käyttää valvontaprosessiin tilastollisia menetelmiä': 0.0,
#  'tehdä strategista tutkimusta': 0.0,
#  'kehittää taiteellinen viitekehys': 0.0,
#  'laatia palkkalaskelmia': 0.0,
#  'asentaa projektiolaitteet': 0.0,
#  'huolehtia markkinointimateriaalien tuottamisesta': 0.0,
#  'kastopäällystysprosessi': 0.0,
#  'käyttää teurastamovälineitä': 0.0,
#  'viineihin liittyvät tieteet': 0.0,
#  'laatia työmääräyksiä optiseen laboratorioon': 0.0,
#  'työskennellä poraustiimeissä': 0.0,
#  'huoltaa pituusleikkuria': 0.0,
#  'kommunikoida esityksen aikana': 0.0,
#  'varmistaa pidätettyjen hyvinvointi': 0.0,
#  'opastaa sisustamisessa': 0.0,
#  'optomekaaniset komponentit': 0.0,
#  'valmistaa kitaran osia': 0.0,
#  'valmistella harjoituksia': 0.0,
#  'tulkita perinnöllisyyslääketieteellisten laboratoriokokeiden tuloksia': 0.0,
#  'määritellä maisemasuunnitelman osatekijöitä': 0.0,
#  'työjunat': 0.0,
#  'toimittaa öljynporauslaitteita': 0.0,
#  'varmistaa kaivoskirjanpidon ylläpito': 0.0,
#  'laboratoriotekniikat': 0.0,
#  'laatia raportteja säännöllisistä säähavainnoista': 0.0,
#  'sovittaa kuvia kehyksiin': 0.0,
#  'hoitaa lihanpakkauskonetta': 0.0,
#  'virvoitus- ja alkoholijuomat': 0.0,
#  'selittää taloudellisia yksityiskohtia asiakkaille': 0.0,
#  'ICT-palautustekniikat': 0.0,
#  'edistää terveyttä': 0.0,
#  'sisätaudit': 0.0,
#  'tehdä yhteistyötä raitiovaunujen huolto-osaston kanssa': 0.0,
#  'avustaa nesteiden annossa eläimille': 0.0,
#  'kattojen tarkastamiseen käytetyt pienoiskopterit': 0.0,
#  'hoitaa kiilahihnojen leimauskonetta': 0.0,
#  'avustaa ruumiin sulkemisessa ruumiinavauksen jälkeen': 0.0,
#  'tehdä maanhuoltotöitä': 0.0,
#  'varmistaa sähkövoimajärjestelmien turvallisuus': 0.0,
#  'hallita kaivojen vuorovaikutusprosessit': 0.0,
#  'käyttää metsänhoitolaitteita': 0.0,
#  'ohjata imupuomeja': 0.0,
#  'tarkastaa otosten jatkuvuus': 0.0,
#  'vastuullinen rahapelaaminen': 0.0,
#  'huoltaa vetureita': 0.0,
#  'suunnitella työntekijöiden vuoroja': 0.0,
#  'asettaa betonilaattoja': 0.0,
#  'työskennellä turvallisesti kuumien materiaalien kanssa': 0.0,
#  'määritellä lankanumero': 0.0,
#  'transponoida musiikkia': 0.0,
#  'heprea': 0.0,
#  'varmistaa koneistuksessa tarvittava ilmanvaihto': 0.0,
#  'kaataa sekoitusta kumipusseihin': 0.0,
#  'huolehtia kasvien terveydestä': 0.0,
#  'käyttää uutta teknologiaa elintarvikkeiden tuotannossa': 0.0,
#  'satelliittien laukaisu kiertoradalle': 0.0,
#  'tunnistaa terrorismiuhkia': 0.0,
#  'tukea kalastustoiminnan koulutuskäytäntöjä': 0.0,
#  'matkustajaliikennettä koskevat määräykset': 0.0,
#  'valvoa raskaiden koneiden käyttöä': 0.0,
#  'hallinnoida rahtimaksujen suoritustapoja': 0.0,
#  'käyttää sisältötyyppejä': 0.0,
#  'luoda korkeat standardit kokoelmien ylläpidolle': 0.0,
#  'näyttöön perustuva radiografinen hoito': 0.0,
#  'elintarvikelainsäädäntö': 0.0,
#  'koota tilastotietoja vakuutustarkoituksiin': 0.0,
#  'puhdistaa optisia komponentteja': 0.0,
#  'tallentaa tiedot hammasproteeseista': 0.0,
#  'analysoida henkilöstökapasiteettia': 0.0,
#  'pitää kirjaa kierrätyksestä': 0.0,
#  'koordinoida nuohoojien toimintaa': 0.0,
#  'tukea paikallista taloutta': 0.0,
#  'ohjelmistokomponenttikirjastot': 0.0,
#  'tunnistaa sähköisiä signaaleja': 0.0,
#  'id Tech': 0.0,
#  'valvoa leiritoimintoja': 0.0,
#  'käsitellä asiakkaiden tilauksia': 0.0,
#  'valmistella kivi hiomista varten': 0.0,
#  'käyttää pikakirjoituskoneita': 0.0,
#  'grafiitti': 0.0,
#  'asentaa elektroniset tiedonvaihtovälineet': 0.0,
#  'johtaa tutkimus- ja kehityshankkeita': 0.0,
#  'laatia lakeja': 0.0,
#  'esittää laituriin kiinnittymistä koskeva suunnitelma': 0.0,
#  'silmätaudit': 0.0,
#  'käyttää laatukuva- tai akateemisen maalauksen tekniikoita': 0.0,
#  'arvioida lääkkeisiin liittyviä tieteellisiä tutkimustuloksia': 0.0,
#  'tallentaa biolääketieteellisten testien tuloksia': 0.0,
#  'lastenvaatteiden valmistus': 0.0,
#  'elintarviketekniikka': 0.0,
#  'huolehtia vastaanottoalueesta': 0.0,
#  'opettaa yliopistokurssia': 0.0,
#  'pinnoittaa sähkölaitteita': 0.0,
#  'kielityypit': 0.0,
#  'tarkkailla tukkeja': 0.0,
#  'tutkia rikospaikkoja': 0.0,
#  'leipomotuotteiden ainesosat': 0.0,
#  'hallinnoida räjähteitä lainsäädännön mukaisesti': 0.0,
#  'edistää oman esimerkin avulla työterveys- ja -turvallisuusmääräysten noudattamista': 0.0,
#  'johtaa tiimiä metsänhoitopalveluissa': 0.0,
#  'varastoida elintarvikkeiden raaka-aineita': 0.0,
#  'analysoida elimistön nesteitä': 0.0,
#  'hygienia terveydenhuollossa': 0.0,
#  'Puppet (työkalut ohjelmiston kokoonpanon hallintaan)': 0.0,
#  'synnytys': 0.0,
#  'johdinautojen mekaniikka': 0.0,
#  ...}

# %% [markdown]
# ## TS-SS (triange's area similarity and sector's area similarity combination)
#
# Experiment with a different similarity metric.
#
# https://github.com/taki0112/Vector_Similarity
#
# Note the current implementation runs a long time.

# %%
import math
from IPython.display import display, clear_output

def vector_size(vec):
    return math.sqrt(sum(math.pow(v, 2) for v in vec))

def inner_product(vec1, vec2):
    return sum(v1 * v2 for v1, v2 in zip(vec1, vec2))

def cosine(vec1, vec2):
    return inner_product(vec1, vec2) / (vector_size(vec1) * vector_size(vec2))

def theta(vec1, vec2):
    return math.acos(cosine(vec1, vec2)) + math.radians(10)

def triangle(vec1, vec2):
    angle_rad = math.radians(theta(vec1, vec2))
    return (vector_size(vec1) * vector_size(vec2) * math.sin(angle_rad)) / 1

def magnitude_difference(vec1, vec2):
    return abs(vector_size(vec1) - vector_size(vec2))

def euclidean(vec1, vec2):
    return math.sqrt(sum(math.pow((v1 - v2), 2) for v1, v2 in zip(vec1, vec2)))

def sector(vec1, vec2):
    ed = euclidean(vec1, vec2)
    md = magnitude_difference(vec1, vec2)
    angle = theta(vec1, vec2)
    return math.pi * math.pow((ed + md), 2) * angle / 360

def TS_SS(vec1, vec2):
    return triangle(vec1, vec2) * sector(vec1, vec2)

def TS_SS_similarity(text1, text2):
    sparse = stemmed_vectorizer.transform([text1, text2])
    
    vec1 = sparse[0].todense().A[0]
    vec2 = sparse[1].todense().A[0]
    
    return TS_SS(vec1, vec2)

def get_TS_SS_similarities(text):
    text_tokens = tokenizer(text)
    text_stemmed = ' '.join(text_tokens)
    
    similarities = {}
    
    i = 1
    for key, value in stemmed_documents.items():
        clear_output(wait=True)
        print(f"{i}/{len(stemmed_documents)}")
        similarities[key] = TS_SS_similarity(text_stemmed, value)
        i += 1

    return similarities

text = 'jakaa postia'

d = get_TS_SS_similarities(text)
d_sorted = dict(sorted(d.items(), key=lambda item: item[1], reverse=True))
d_sorted
# Out:
# 12566/12566
# {'selviytyä merellä tilanteessa, jossa laiva joudutaan jättämään': 0.0009277742258158227,
#  'suunnitella tapahtumamarkkinointia markkinointikampanjoihin': 0.0009277742258158226,
#  'työskennellä psykologisten käytösmallien parissa': 0.0009277742258158226,
#  'rahtiteollisuus': 0.0009277742258158226,
#  'noudattaa työaikataulua': 0.0009277742258158219,
#  'antaa selonteko oikeuden virkailijoille': 0.0009277742258158219,
#  'kehittää teknisten tekstiilien teknisiä tietoja': 0.0009277742258158219,
#  'kestää ulosteita': 0.0009277742258158219,
#  'mitata alusten vetoisuus': 0.0009277742258158219,
#  'huolehtia kuvauslaitteista': 0.0009277742258158219,
#  'toimia kuiskaajana esityksissä': 0.0009277742258158219,
#  'antaa nitraattien aiheuttamaa pilaantumista koskevia neuvoja': 0.0009277742258158219,
#  'asentaa laskettu sisäkatto': 0.0009277742258158219,
#  'mausteiden valmistusprosessit': 0.0009277742258158219,
#  'markkinaosapuolet': 0.0009277742258158219,
#  'aluksen turvavarusteet': 0.0009277742258158219,
#  'osoittaa sosiaalisia taitoja': 0.0009277742258158219,
#  'varmistaa ympäristölainsäädännön noudattaminen': 0.0009277742258158219,
#  'tehdä muutoksia vaatteisiin': 0.0009277742258158219,
#  'suodattaa viiniä': 0.0009277742258158219,
#  'panimoprosessit': 0.0009277742258158219,
#  'CryEngine': 0.0009277742258158219,
#  'tutkia vaatemalleja': 0.0009277742258158219,
#  'kehittää vierailijoiden sitouttamisstrategioita': 0.0009277742258158219,
#  'tarjota hoitopalveluita kouluajan ulkopuolella': 0.0009277742258158219,
#  'koostaa rautateiden merkinantoraportteja': 0.0009277742258158219,
#  'ylläpitää asiakasrekisterejä': 0.0009277742258158219,
#  'CSS': 0.0009277742258158219,
#  'käyttää fysioterapiaa eläinten hoidossa': 0.0009277742258158219,
#  'kehittää ennustavia malleja': 0.0009277742258158219,
#  'suorittaa lentoaseman valaistuksen huoltotoimenpiteitä': 0.0009277742258158219,
#  'käyttää testauslaitteita': 0.0009277742258158219,
#  'valvoa viinintuotantoprosessia': 0.0009277742258158219,
#  'tarjoilla viinejä': 0.0009277742258158219,
#  'laatia työsuunnitelmia ongelmien ratkaisemiseksi': 0.0009277742258158219,
#  'välimuistipalvelimet': 0.0009277742258158219,
