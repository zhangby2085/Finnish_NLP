# %%
import pandas as pd
import json
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %config Completer.use_jedi = False
pd.options.display.max_columns = 40
pd.options.display.max_rows = 50

# %%
df = pd.read_json('lemmatized_esco_data.json')
df.head()
# Out:
#                             preferredLabel  \
# 0                  analysoida r枚ntgenkuvia
# 1                            myyd盲 kelloja
# 10           psykologian hoitotoimenpiteet
# 100                             tietokanta
# 1000  m盲盲ritell盲 lakis盲盲teiset vaatimukset
#
#                     preferredLabelLemmatized  preferredLabelPOS  \
# 0                 [analysoida, r枚ntgen#kuva]       [VERB, NOUN]
# 1                             [myyd盲, kello]       [VERB, NOUN]
# 10           [psykologia, hoito#toimen#pide]       [NOUN, NOUN]
# 100                            [tieto#kanta]             [NOUN]
# 1000  [m盲盲ritell盲, laki#s盲盲teinen, vaatimus]  [VERB, ADJ, NOUN]
#
#                                        alternativeLabel  \
# 0                                                    []
# 1                                                    []
# 10                                                   []
# 100   [tietokantojen luokitukset, tietokannat, tieto...
# 1000  [m盲盲ritt盲盲 juridisia vaatimuksia, m盲盲ritt盲盲 la...
#
#                              alternativeLabelLemmatized  \
# 0                                                    []
# 1                                                    []
# 10                                                   []
# 100   [[tieto#kanta, luokitus], [tieto#kanta], [tiet...
# 1000  [[m盲盲ritt盲盲, juridinen, vaatimus], [m盲盲ritt盲盲,...
#
#                                     alternativeLabelPOS  \
# 0                                                    []
# 1                                                    []
# 10                                                   []
# 100   [[NOUN, NOUN], [NOUN], [NOUN], [NOUN, NOUN], [...
# 1000  [[VERB, ADJ, NOUN], [VERB, NOUN, CCONJ, NOUN, ...
#
#                                             description  \
# 0     Analysoida r枚ntgenkuvia potilaiden ongelmien s...
# 1     Myyd盲 kelloja, rannekelloja tai niihin liittyv...
# 10    Kaikenik盲isille henkil枚ille ja ryhmille suunna...
# 100   Tietokantojen luokittelu, johon kuuluu niiden ...
# 1000  Tutkimuksen tekeminen sovellettavista ja norma...
#
#                                   descriptionLemmatized  \
# 0     [analysoida,  r枚ntgen#kuva,  potilas,  ongelma...
# 1     [myyd盲,  kello,  , ,  ranne#kello,  tai,  se, ...
# 10    [kaiken#ik盲inen,  henkil枚,  ja,  ryhm盲,  suunn...
# 100   [tieto#kanta,  luokittelu,  , ,  joka,  kuulua...
# 1000  [tutkimus,  tekeminen,  soveltaa,  ja,  normat...
#
#                                          descriptionPOS
# 0     [VERB,  NOUN,  NOUN,  NOUN,  NOUN,  CCONJ,  NO...
# 1     [VERB,  NOUN,  PUNCT,  NOUN,  CCONJ,  PRON,  V...
# 10    [ADJ,  NOUN,  CCONJ,  NOUN,  VERB,  NOUN,  NOU...
# 100   [NOUN,  NOUN,  PUNCT,  PRON,  VERB,  PRON,  NO...
# 1000  [NOUN,  NOUN,  VERB,  CCONJ,  ADJ,  NOUN,  CCO...

# %%
data = df[['preferredLabel', 'preferredLabelLemmatized', 'preferredLabelPOS', 'alternativeLabel', 'alternativeLabelLemmatized', 'alternativeLabelPOS', 'description', 'descriptionLemmatized', 'descriptionPOS']]
data.head()
# Out:
#                             preferredLabel  \
# 0                  analysoida r枚ntgenkuvia
# 1                            myyd盲 kelloja
# 10           psykologian hoitotoimenpiteet
# 100                             tietokanta
# 1000  m盲盲ritell盲 lakis盲盲teiset vaatimukset
#
#                     preferredLabelLemmatized  preferredLabelPOS  \
# 0                 [analysoida, r枚ntgen#kuva]       [VERB, NOUN]
# 1                             [myyd盲, kello]       [VERB, NOUN]
# 10           [psykologia, hoito#toimen#pide]       [NOUN, NOUN]
# 100                            [tieto#kanta]             [NOUN]
# 1000  [m盲盲ritell盲, laki#s盲盲teinen, vaatimus]  [VERB, ADJ, NOUN]
#
#                                        alternativeLabel  \
# 0                                                    []
# 1                                                    []
# 10                                                   []
# 100   [tietokantojen luokitukset, tietokannat, tieto...
# 1000  [m盲盲ritt盲盲 juridisia vaatimuksia, m盲盲ritt盲盲 la...
#
#                              alternativeLabelLemmatized  \
# 0                                                    []
# 1                                                    []
# 10                                                   []
# 100   [[tieto#kanta, luokitus], [tieto#kanta], [tiet...
# 1000  [[m盲盲ritt盲盲, juridinen, vaatimus], [m盲盲ritt盲盲,...
#
#                                     alternativeLabelPOS  \
# 0                                                    []
# 1                                                    []
# 10                                                   []
# 100   [[NOUN, NOUN], [NOUN], [NOUN], [NOUN, NOUN], [...
# 1000  [[VERB, ADJ, NOUN], [VERB, NOUN, CCONJ, NOUN, ...
#
#                                             description  \
# 0     Analysoida r枚ntgenkuvia potilaiden ongelmien s...
# 1     Myyd盲 kelloja, rannekelloja tai niihin liittyv...
# 10    Kaikenik盲isille henkil枚ille ja ryhmille suunna...
# 100   Tietokantojen luokittelu, johon kuuluu niiden ...
# 1000  Tutkimuksen tekeminen sovellettavista ja norma...
#
#                                   descriptionLemmatized  \
# 0     [analysoida,  r枚ntgen#kuva,  potilas,  ongelma...
# 1     [myyd盲,  kello,  , ,  ranne#kello,  tai,  se, ...
# 10    [kaiken#ik盲inen,  henkil枚,  ja,  ryhm盲,  suunn...
# 100   [tieto#kanta,  luokittelu,  , ,  joka,  kuulua...
# 1000  [tutkimus,  tekeminen,  soveltaa,  ja,  normat...
#
#                                          descriptionPOS
# 0     [VERB,  NOUN,  NOUN,  NOUN,  NOUN,  CCONJ,  NO...
# 1     [VERB,  NOUN,  PUNCT,  NOUN,  CCONJ,  PRON,  V...
# 10    [ADJ,  NOUN,  CCONJ,  NOUN,  VERB,  NOUN,  NOU...
# 100   [NOUN,  NOUN,  PUNCT,  PRON,  VERB,  PRON,  NO...
# 1000  [NOUN,  NOUN,  VERB,  CCONJ,  ADJ,  NOUN,  CCO...

# %%
def get_documents(data):
    documents = []
    for i in data.index:
        document_words = []
        
        preferred_label = data['preferredLabel'][i]
        preferred_label_lemmatized = data['preferredLabelLemmatized'][i]
        preferred_label_POS = data['preferredLabelPOS'][i]
        for j in range(len(preferred_label_lemmatized)):
            if preferred_label_POS[j].strip() in ['VERB', 'NOUN']:
                document_words.append(preferred_label_lemmatized[j].strip())
                
        alternative_label = data['alternativeLabel'][i]
        alternative_label_lemmatized = data['alternativeLabelLemmatized'][i]
        alternative_label_POS = data['alternativeLabelPOS'][i]
        for j in range(len(alternative_label_lemmatized)):
            for k in range(len(alternative_label_lemmatized[j])):
                if alternative_label_POS[j][k].strip() in ['VERB', 'NOUN']:
                    document_words.append(alternative_label_lemmatized[j][k].strip())
                
        description_lemmatized = [item for item in data['descriptionLemmatized'][i] if item != ' ']
        description_POS = data['descriptionPOS'][i]
        for j in range(len(description_lemmatized)):
            if description_POS[j].strip() in ['VERB', 'NOUN']:
                document_words.append(description_lemmatized[j].strip())
        
        documents.append(document_words)
        
    return documents

documents = get_documents(data)

# %%
documents
# Out:
# [['analysoida',
#   'r枚ntgen#kuva',
#   'analysoida',
#   'r枚ntgen#kuva',
#   'potilas',
#   'ongelma',
#   'selvitt盲minen',
#   'tulos',
#   'tulkitseminen'],
#  ['myyd盲',
#   'kello',
#   'myyd盲',
#   'kello',
#   'ranne#kello',
#   'liitty盲',
#   'tarvike',
#   'asiakas',
#   'mieltymys'],
#  ['psykologia',
#   'hoito#toimen#pide',
#   'henkil枚',
#   'ryhm盲',
#   'suunnata',
#   'psykologia',
#   'hoito#toimen#pide',
#   'pyrki盲',
#   'parantaa',
#   'hoito#taito',
#   'v盲litt盲盲',
#   'kulttuuri',
#   'suku#puoli#n盲k枚#kulma'],
#  ['tieto#kanta',
#   'tieto#kanta',
#   'luokitus',
#   'tieto#kanta',
#   'tieto#kanta#tyyppi',
#   'tieto#kanta',
#   'tyyppi',
#   'tieto#kanta',
#   'ominaisuus',
#   'tieto#kanta',
#   'luokittelu',
#   'kuulua',
#   'k盲ytt枚#tarkoitus',
#   'ominaisuus',
#   'terminologia',
#   'malli',
#   'k盲ytt枚',
#   'XML#tieto#kanta',
#   'tieto#kanta',
#   'teksti#tieto#kanta'],
#  ['m盲盲ritell盲',
#   'vaatimus',
#   'm盲盲ritt盲盲',
#   'vaatimus',
#   'm盲盲ritt盲盲',
#   'laki',
#   'standardi',
#   'asettaa',
#   'vaatimus',
#   'm盲盲ritt盲盲',
#   'vaatimus',
#   'm盲盲ritt盲盲',
#   'laki',
#   'standardi',
#   'vaatimus',
#   'selvitt盲盲',
#   'vaatimus',
#   'tutkimus',
#   'tekeminen',
#   'soveltaa',
#   'menettely',
#   'standardi',
#   'organisaatio',
#   'k盲yt盲nt枚',
#   'tuote',
#   'p盲te盲',
#   'vaatimus',
#   'selvitt盲minen',
#   'analysointi'],
#  ['rengas#tyyppi',
#   'kumi#p盲盲llyste',
#   'ilma',
#   't盲ytt盲盲',
#   'rengas',
#   'k盲ytt盲盲',
#   'ajo#neuvo',
#   's盲盲#ola',
#   'talvi',
#   'kes盲#rengas',
#   'suoritus#kyky',
#   'rengas',
#   'rekka',
#   'traktori#rengas'],
#  ['m盲盲ritell盲',
#   'kuvaus#paikka',
#   'maalaus#menetelm盲',
#   'kuvaus#paikka',
#   'maalaus#menetelm盲',
#   'materiaali',
#   'm盲盲rittely'],
#  ['levitt盲盲',
#   'laasti',
#   'pinta',
#   'laasti',
#   'levitt盲minen',
#   'pinta',
#   'kipsi#levitin',
#   'k盲ytt盲盲',
#   'pinto',
#   'valmisteleminen',
#   'laasti#kerros',
#   'viimeistely',
#   'muuraus#lasta',
#   'tasoitus#lasta',
#   'pinta',
#   'viimeistely',
#   'varmistaminen',
#   'p盲盲llyste',
#   'tarttua',
#   'pinta',
#   'loppu#tulos',
#   'tarkastus',
#   'korjaus'],
#  ['markkinoida',
#   'maa#talous#tuote',
#   'markkinoida',
#   'maa#tila',
#   'tuote',
#   'varmistaa',
#   'tuote',
#   'markkinoida',
#   'esitell盲',
#   'tuote',
#   'asiakas',
#   'k盲ytt盲盲',
#   'markkinointi#menetelm盲'],
#  ['hautomo',
#   'suunnittelu',
#   'kala',
#   'nilvi盲inen',
#   '盲yri盲inen',
#   'tarvita',
#   'nimet盲',
#   'laji',
#   'hautomo',
#   'suunnittelu',
#   'sijoittelu',
#   'ilma#vaihto',
#   'osa#tekij盲'],
#  ['tarkastaa',
#   'lasi#levy',
#   'tarkastaa',
#   'valmistelu',
#   'lasi#levy',
#   'viko',
#   'kupla',
#   'kivi'],
#  ['antaa',
#   'talous#kehitys',
#   'koskea',
#   'neuvonta',
#   'antaa',
#   'organisaatio',
#   'laitos',
#   'neuvo',
#   'tekij盲',
#   'toimi',
#   'edist盲盲',
#   'vakaus',
#   'kasvu',
#   'varmistaa'],
#  ['hoitaa',
#   'pullon#pesu#kone',
#   'pullo#pesu#kone',
#   'hoitaminen',
#   'varmistaminen',
#   'pullo',
#   'liikkua',
#   'kone',
#   'sy枚tt枚',
#   'huolto',
#   'tehd盲',
#   'vaatimus'],
#  ['hahmottaa',
#   'asia#yhteys',
#   'ymm盲rt盲盲',
#   'konteksti',
#   'muodostaa',
#   'tilanne',
#   'asia#yhteys',
#   'apu',
#   'kuva',
#   'sanoa',
#   'ymm盲rt盲盲',
#   'asia',
#   'liitty盲',
#   'ihminen',
#   'olo#suhteet',
#   'mieli#ala',
#   'ymp盲rist枚',
#   't盲sment盲盲',
#   'tulkkaus',
#   'tulkki',
#   'tuntea',
#   'puhuja',
#   'n盲k枚#kanta'],
#  ['k盲ytt盲盲', 'ty枚st枚#kone', 'ohjelmoida', 'k盲ytt盲盲', 'ohjata', 'ty枚st枚#kone'],
#  ['valvoa',
#   'puisto',
#   's盲盲nt枚',
#   'panna',
#   'mets盲n#hoito',
#   'koskea',
#   'ymp盲rist枚#laki',
#   's盲盲nt枚',
#   'mets盲#vartija',
#   'panna',
#   's盲盲nn枚s',
#   'soveltaa',
#   'mets盲',
#   'k盲ytt枚',
#   'el盲in',
#   'kasvi',
#   'suojelu',
#   'tehd盲',
#   'leirint盲#alue',
#   'turvallisuus#tarkastus',
#   'tutkia',
#   'valitus'],
#  ['tarkkailla',
#   'keitti枚#tarvike',
#   'valvoa',
#   'varasto#m盲盲r盲',
#   'yll盲pit盲盲',
#   'varasto',
#   'materiaali',
#   'laite#inventaari',
#   'valvoa',
#   'varasto',
#   'm盲盲r盲',
#   'yll盲pit盲盲',
#   'inventaario',
#   'varasto',
#   'materiaali',
#   'laite#tilanne',
#   'tarkkailla',
#   'keitti枚#tarvike',
#   'valvoa',
#   'keitti枚',
#   'k盲ytt盲盲',
#   'tarvike',
#   'varasto#taso',
#   'raportoida',
#   'henkil枚'],
#  ['antaa',
#   'el盲in',
#   'rauhoittaa',
#   'l盲盲ke',
#   'rauhoittaa',
#   'el盲in',
#   'valita',
#   'antaa',
#   'el盲in',
#   'rauhoittaa',
#   'l盲盲ke',
#   'tarkoitus',
#   'seurata',
#   'vaikutus'],
#  ['k盲ytt盲盲',
#   'sairaus',
#   'ehk盲isy#toimen#pide',
#   'ehk盲ist盲',
#   'sairaus',
#   'kehitt盲盲',
#   'm盲盲ritell盲',
#   'toteuttaa',
#   'arvioida',
#   'toimi',
#   'ehk盲ist盲',
#   'sairaus',
#   'infektio',
#   'pyrki盲',
#   'parantaa',
#   'kansalainen',
#   'terveys',
#   'el盲m盲n#laatu'],
#  ['valita',
#   'ruiskutus#paine',
#   'valita',
#   'ruiskutus#paine',
#   'ottaa',
#   'huomio',
#   'ruiskuttaa',
#   'maali',
#   'pohjustus#aine',
#   'tyyppi',
#   'ruiskuttaa',
#   'materiaali',
#   'ruiskutus#ymp盲rist枚',
#   'tekij盲'],
#  ['karja',
#   'ruokinta',
#   'hy枚ty#el盲in',
#   'ruokinta',
#   'koti#el盲in',
#   'ruokinta',
#   'koti#el盲in',
#   'ruokinta',
#   'tarkoittaa',
#   'elin#tarvike'],
#  ['varmistaa',
#   'liike#toiminto',
#   'lain#mukaisuus',
#   'noudattaa',
#   'yritys',
#   'toiminta',
#   'liitty盲',
#   'lain#s盲盲d盲nt枚'],
#  ['riski#hallinta#menetelm盲',
#   'riski#hallinta#menetelm盲',
#   'riski#hallinta#politiikka',
#   'riski#hallinta',
#   'menetelm盲',
#   'riski#hallinta',
#   'menetelm盲',
#   'riski#hallinta#k盲yt盲nt枚',
#   'riski#hallinta#menetelm盲',
#   'tunnistaa',
#   'arvioida',
#   'priorisoida',
#   'tieto#tekniikka#ymp盲rist枚',
#   'esiinty盲',
#   'riski',
#   'menetelm盲',
#   'minimoida',
#   'seurata',
#   'valvoa',
#   'liike#toiminta',
#   'tavoite',
#   'saavuttaminen',
#   'vaikuttaa',
#   'tapahtuma',
#   'mahdollisuus',
#   'vaikutus'],
#  ['seurata', 'raskaus', 'tehd盲', 'raskaus', 'seuranta', 'kuulua', 'tutkimus'],
#  ['ohjaus#keskus',
#   'ohjaus#keskus',
#   'ohjaus#keskus',
#   'k盲ytt盲盲',
#   'vipu',
#   'laite',
#   'ohjaus#keskus#paneeli',
#   'integroida',
#   'j盲rjestelm盲'],
#  ['toto#veikkaus', 'vedon#ly枚nti#j盲rjestelm盲', 'veto', 'ly枚d盲', 'potti'],
#  ['varmistaa',
#   'vierailija',
#   'terveys',
#   'turvallisuus',
#   'toteuttaa',
#   'varo#toimi',
#   'varmistaa',
#   'yleis枚',
#   'toiminta',
#   'osallistua',
#   'henkil枚',
#   'turvallisuus',
#   'valmistella',
#   'h盲t盲#tilanne#toimi',
#   'hallinnoida',
#   'ensi#apu',
#   'johtaa',
#   'h盲t盲#eva#kuointi'],
#  ['s盲盲t盲盲',
#   'paperi#pussi#kone',
#   'paperi#s盲kki',
#   'kontrolli#tulos',
#   'valmius',
#   'tehd盲',
#   'muutos',
#   'varmistaa',
#   'sivu#tiiviste',
#   'portti',
#   'reik盲',
#   'huulikoko',
#   'tuote',
#   'yritys',
#   'vaatimus'],
#  ['kehitt盲盲',
#   'ohjelmisto#testi',
#   'laatia',
#   'ohjelmisto#testi',
#   'laatia',
#   'ohjelmisto',
#   'testi',
#   'suunnitella',
#   'ohjelmisto#testi',
#   'kehitt盲盲',
#   'ohjelmisto',
#   'testi',
#   'suunnitella',
#   'ohjelmisto',
#   'testi',
#   'luoda',
#   'ohjelmisto',
#   'testi',
#   'luoda',
#   'ohjelmisto#testi',
#   'laatia',
#   'erikois#kieli',
#   'ty枚#kalu',
#   'apu',
#   'ohjelmisto#testi#sarja',
#   'suorittaa',
#   'testi#ty枚#kalu',
#   's盲盲st盲盲',
#   'resurssi',
#   'parantaa',
#   'testaus',
#   'tehokkuus',
#   'vaikuttavuus'],
#  ['valmistella',
#   'laite',
#   'navigointi#operaatio',
#   'valmistella',
#   'yll盲pit盲盲',
#   'p盲盲',
#   'lis盲#laite',
#   'tukea',
#   'navigointi#operaatio',
#   'laatia',
#   'valvoa',
#   'tarkistus#lista',
#   'noudattaa',
#   't盲yt盲nt枚枚npano#menettely'],
#  ['rauta#tie',
#   'puite#lain#s盲盲d盲nt枚',
#   'rauta#tie',
#   'koskea',
#   'vaatimus',
#   'vahvistaa',
#   'rauta#tie',
#   'puite#lain#s盲盲d盲nt枚',
#   'tunteminen',
#   'soveltaminen',
#   'raja',
#   'ylitt盲盲',
#   'tavara#liikenne',
#   'kautta#kuljetus',
#   'soveltaa',
#   'lain#s盲盲d盲nt枚',
#   'tunteminen'],
#  ['kulttuuri#projekti',
#   'kulttuuri#projekti',
#   'liitty盲',
#   'vara#keruu#toimi',
#   'tarkoitus',
#   'organisointi',
#   'hallinto'],
#  ['virologi',
#   'virus#tutkimus',
#   'viru#soppi',
#   'virus',
#   'aiheuttaa',
#   'tauti',
#   'rakenne',
#   'ominaisuus',
#   'kehitys',
#   'vuoro#vaikutus'],
#  ['tehd盲',
#   'betoni#valu',
#   'betonoida',
#   'vesi',
#   'valmistella',
#   'valu#kuoppa',
#   'ohjata',
#   'k盲ytt盲盲',
#   'valu#putki',
#   'betoni',
#   'valuttaminen',
#   'paikka',
#   'vesi',
#   'varmistaa',
#   'betoni#virta',
#   'vesi',
#   'p盲盲st盲',
#   'virrata',
#   'valu#putki'],
#  ['k盲ytt盲盲',
#   'pehmo#paperi#raina',
#   'kerrostus#kone',
#   'kone',
#   'k盲ytt盲minen',
#   'erottaa',
#   'liuska',
#   'rulta',
#   'sitoa',
#   'liuska'],
#  ['hoitaa',
#   'purkitus#kone',
#   'purkitus#kone',
#   'hoitaminen',
#   'k盲ytt枚#voima',
#   's盲hk枚',
#   'akku',
#   'purkittaa',
#   'elin#tarvike'],
#  ['tehd盲',
#   'toimen#pide',
#   'toimen#pide',
#   'suorittaminen',
#   'valita',
#   'alue',
#   'potilas',
#   'suoni',
#   'pisto#kohta',
#   'valmistella',
#   'pisto#kohi',
#   'selitt盲盲',
#   'toimen#pide',
#   'potilas',
#   'ottaa',
#   'veri',
#   'ker盲t盲',
#   'astia'],
#  ['poistaa', 'kasvusto', 'kasvusto', 'poistaminen', 'vesi#viljely#laitos'],
#  ['kehitt盲盲',
#   'exploit#koodi',
#   'luoda',
#   'testata',
#   'haavoittuvuus',
#   'hy枚dynt盲盲',
#   'menetelm盲',
#   'valvoa',
#   'ymp盲rist枚',
#   'j盲rjestelm盲#virhe',
#   'haavoittuvuus',
#   'havaitseminen',
#   'tarkastaminen'],
#  ['bingo#terminologi',
#   'bingos#anasto',
#   'binko',
#   'k盲ytt盲盲',
#   'termi',
#   'riimitt盲盲',
#   'nimitys',
#   'k盲ytt盲盲',
#   'bingo#numero',
#   'ilmoittaa'],
#  ['ty枚skennell盲',
#   'n盲ytt盲m枚#ase',
#   'noudattaa',
#   'varo#toimi',
#   'n盲ytt盲m枚#ase',
#   'valmistelu',
#   'kuljetus',
#   'varastointi',
#   'k盲ytt枚',
#   'opastus',
#   'k盲ytt枚',
#   'aika',
#   'ter盲#ase',
#   'ampuma#ase'],
#  ['myyd盲',
#   'lattia',
#   'tekstiili#p盲盲llyste',
#   'sein盲#verhoilu',
#   'myyd盲',
#   'lattia',
#   'sein盲',
#   'p盲盲llyste',
#   'myyd盲',
#   'matta',
#   'verho',
#   'lino#leumi#n盲yte',
#   'koko#lattia#matta',
#   'houkutella',
#   'tapa',
#   'asiakas',
#   'saada',
#   'ostaa'],
#  ['laatia',
#   'suositus#j盲rjestelm盲',
#   'laatia',
#   'suositus#moottori',
#   'laatia',
#   'suositus#j盲rjestelm盲',
#   'laatia',
#   'suositus#alus',
#   'laatia',
#   'suositus#j盲rjestelm盲',
#   'laatia',
#   'suosittelu#moottori',
#   'laatia',
#   'suositus#j盲rjestelm盲',
#   'perustua',
#   'tieto#joukko',
#   'luoda',
#   'ohjelmointi#kieli',
#   'v盲line',
#   'tieto',
#   'ala#luokka',
#   'suodatus#j盲rjestelm盲',
#   'pyrki盲',
#   'ennakoida',
#   'k盲ytt盲j盲',
#   'antaa',
#   'luokitus',
#   'mieltymys'],
#  ['盲盲ni',
#   'hallita',
#   'ilmaisu#tyyli',
#   'puhua',
#   'ymm盲rt盲盲',
#   'sanoa',
#   'lausua',
#   'virhe',
#   'v盲ltt盲minen',
#   'varmistaminen',
#   'ett盲#ei',
#   'vahinko',
#   'sanoa'],
#  ['muodostaa',
#   'ICT#turvallisuus#suunnitelma',
#   'toimen#pide',
#   'velvollisuus',
#   'm盲盲ritt盲minen',
#   'varmistaa',
#   'tieto',
#   'luottamuksellisuus',
#   'eheys',
#   'saatavuus',
#   'toiminta#linja',
#   't盲yt盲nt枚枚npano',
#   'est盲盲',
#   'tieto#turva#loukkaus',
#   'havaita',
#   'p盲盲sy',
#   'j盲rjestelm盲',
#   'resurssi',
#   'reagoida',
#   'tieto#turva#sovellus',
#   'ty枚#tekij盲',
#   'koulutus'],
#  ['laskostaa',
#   'kangas',
#   'k盲ytt盲盲',
#   'kangas',
#   'vaate',
#   'laskostus#menetelm盲',
#   'menettely',
#   'noudattaa',
#   'k盲ytt盲盲',
#   'tarkoitus',
#   'suunnitella',
#   'erityis#laite'],
#  ['suunnitella',
#   'luotsaus',
#   'laatia',
#   'alus',
#   'reitti#suunnitelma',
#   'ottaa',
#   'huomio',
#   'vuoro#vesi#vaihtelu',
#   's盲盲#olo#suhde'],
#  ['maalata',
#   'koriste#maalaus',
#   'tehd盲',
#   'koriste#maalaus',
#   'k盲ytt盲盲',
#   'maalaus#pistooli',
#   'pensseli',
#   'spraymaali'],
#  ['tiedottaa',
#   'vuokra#sopimus',
#   'antaa',
#   'vuokran#antaja',
#   'vuokralainen',
#   'tieto',
#   'vuokran#antaja',
#   'vuokralainen',
#   'velvollisuus',
#   'oikeus',
#   'vuokran#antaja',
#   'velvollisuus',
#   'huolehtia',
#   'kiinteist枚',
#   'yll盲pito',
#   'oikeus',
#   'h盲盲t盲盲',
#   'vuokralainen',
#   'sopimus',
#   'rikkoa',
#   'vuokralainen',
#   'velvollisuus',
#   'maksaa',
#   'vuokra',
#   'v盲ltt盲盲',
#   'laimin#ly枚nti'],
#  ['k盲ytt盲盲',
#   '盲盲nen#mittaus#v盲line',
#   'k盲ytt盲盲',
#   'v盲line',
#   'anturi',
#   '盲盲nitas#omittari',
#   'mitata',
#   'melu#taso',
#   'ymp盲rist枚',
#   'melu#saaste',
#   'ehk盲iseminen'],
#  ['asentaa',
#   'n盲ytt盲m枚',
#   'laite',
#   'n盲ytt盲m枚#laite',
#   'asentaminen',
#   'laitteisto',
#   'testaaminen',
#   'varmistaminen',
#   'toiminta#kunto'],
#  ['koota',
#   'huone#kalu',
#   'kasata',
#   'koottaa',
#   'huone#kalu',
#   'koota',
#   'osa',
#   'toimittaa',
#   'huone#kalu',
#   'muoto'],
#  ['hoitaa',
#   'poltto#aine#myynti',
#   'raha#liikenne',
#   'hoitaa',
#   'huolto#asema',
#   'raha#liikenne',
#   'ilmoittaa',
#   'poltto#aine#myynti#tapahtuminen',
#   'tarvi#keosto',
#   'k盲ytt盲盲',
#   'tieto#koneistaa',
#   'kassa#j盲rjestelm盲',
#   'k盲sitell盲',
#   'luotto#kortti#tapahtuma',
#   'k盲teis#ostos',
#   'laatia',
#   'tase',
#   'k盲ytt盲盲',
#   'kassa#laatikko',
#   'tehd盲',
#   'k盲teis#talletus'],
#  ['suunnittelu',
#   'tekniikka',
#   'alkaa',
#   'koskea',
#   'instrumentti',
#   'sovellus',
#   'teleskooppa',
#   'mikroskooppa',
#   'linssi',
#   'laser',
#   'kuitu#optiikka#viestint盲',
#   'kuvannus#j盲rjestelm盲',
#   'kehitt盲minen'],
#  ['k盲ytt盲盲',
#   'murskain',
#   'k盲ytt盲盲',
#   'kone',
#   'murskata',
#   'kivi',
#   'malmi',
#   'hiili#paakku',
#   'materiaali',
#   'k盲ytt盲盲',
#   'leuka#murskain',
#   'murskata',
#   'kivi',
#   'synnytt盲盲',
#   't盲rin盲',
#   'leuka',
#   'kartio#murskain',
#   'heiluttaa',
#   'spiraali#elementti'],
#  ['kiinnitt盲盲',
#   'komponentti',
#   'kehys',
#   'asentaa',
#   'komponentti',
#   'kehys',
#   'komponentti',
#   'linssi',
#   'osa',
#   'kehys',
#   'kiinnitt盲minen',
#   's盲盲t盲minen',
#   'linssi',
#   'asettaa',
#   'kiinni#tysrengas',
#   'kiinnitys#aine',
#   'levitt盲盲',
#   'linssi',
#   'ulko#reuna'],
#  ['valvoa',
#   'apteekki#henkil枚#kunta',
#   'valvoa',
#   'l盲盲ke#teknikko',
#   'farmasia',
#   'ala',
#   'opiskelija',
#   'harjoittelija',
#   'ty枚#tekij盲',
#   'ty枚'],
#  ['analysoida',
#   'j盲senyys',
#   'm盲盲ritt盲盲',
#   'j盲senyys',
#   'liitty盲',
#   'suuntaus',
#   'alue',
#   'kasvattaa',
#   'j盲sen',
#   'm盲盲r盲'],
#  ['antaa',
#   'l盲hete',
#   'silm盲#tutkimus',
#   'siirt盲盲',
#   'potilas',
#   'hoito',
#   'silm盲#l盲盲ke#tiede',
#   'erikois#ala',
#   'l盲盲ke#tiede',
#   'ala',
#   'k盲sitell盲',
#   'silm盲',
#   'anatomia',
#   'fysiologia',
#   'sairaus'],
#  ['yll盲pit盲盲',
#   'asiakas#rekisteri',
#   'p盲ivitt盲盲',
#   'asiakas#rekisteri',
#   'ker盲t盲',
#   'tieto',
#   'k盲vij盲',
#   'sy枚tt盲盲',
#   'tieto',
#   'j盲rjestelm盲',
#   'yll盲pit盲盲',
#   'asiakas#profiili',
#   'sy枚tt盲盲',
#   'tieto',
#   'j盲rjestelm盲',
#   'yll盲pit盲盲',
#   'asia#as',
#   'histori#aprofiili',
#   'yll盲pit盲盲',
#   'matkustaja',
#   'nimi#rekisteri',
#   'yll盲pit盲盲',
#   'asiakas#rekisteri',
#   't盲ydent盲盲',
#   'asiakas#tietue',
#   's盲ilytt盲盲',
#   'asiakas#tieto',
#   'yll盲pit盲盲',
#   'tallentaa',
#   'j盲sennell盲',
#   'asiakas#tieto',
#   'tieto#suoja',
#   'yksityisyys',
#   'koskea',
#   's盲盲nn枚s'],
#  ['latoma#kone',
#   'ladonta',
#   'lato#makone',
#   'kuulua',
#   'lino#tyyppi',
#   'mono#tyyppi',
#   'valo#tyyppi#kone',
#   'k盲ytt盲盲',
#   'kirjain',
#   'merkki',
#   'kokoaminen',
#   'm盲盲r盲t盲',
#   'piirros',
#   'viiva'],
#  ['valvoa',
#   'vieras',
#   'pesula#palvelu',
#   'valvoa',
#   'asiakas',
#   'pesula#palvelu',
#   'huolehtia',
#   'pesula#palvelu',
#   'toiminta',
#   'varmistaa',
#   'pesula#palvelu',
#   'toimia',
#   'varmistaminen',
#   'vieras',
#   'pyykki',
#   'ker盲t盲',
#   'puhdistaa',
#   'palauttaa'],
#  ['muotoilla',
#   'koriste#kuvio',
#   'muokata',
#   'muotoilla',
#   'koriste#kuvio',
#   'materiaali',
#   'metalli',
#   'puu',
#   'k盲si#ty枚#kalu',
#   'laite'],
#  ['valvoa',
#   'liuku#hihna',
#   'valvoa',
#   'kuljetus#hihna',
#   'seurata',
#   'ty枚#kappale',
#   'virtaus',
#   'liuku#hihna',
#   'k盲sittely',
#   'aika',
#   'varmistaa',
#   'tuottavuus'],
#  ['el盲in',
#   'neuro#fysiologia',
#   'el盲in#l盲盲ke#tiede',
#   'erityis#ala',
#   'tutkia',
#   'el盲in',
#   'hermosto',
#   'toiminta',
#   'lukea',
#   'hermoston#johtuminen',
#   'ioni#kuilu',
#   'toiminta',
#   'hermo#kimppu',
#   'hermo#kuitu',
#   'tumi',
#   'toiminta',
#   'synapsi',
#   'v盲litt盲j盲#aine',
#   'toiminto',
#   'hermo#lihas#liitos',
#   'yksikk枚',
#   'hallinta',
#   'tyyppi',
#   'pikku#aiva',
#   'toiminta'],
#  ['noudattaa',
#   'el盲in#l盲盲k盲rin#tarkastus',
#   'koskea',
#   'vaatimus',
#   'noudattaa',
#   'el盲in#l盲盲k盲rin#tarkastus',
#   'koskea',
#   'normi',
#   'noudattaa',
#   'el盲in#l盲盲k盲rin#tarkastus',
#   'koskea',
#   's盲盲nt枚',
#   'noudattaa',
#   'el盲in#l盲盲k盲rin#tarkastus',
#   'koskea',
#   'vaatimus',
#   'varmistaa',
#   'toimi',
#   's盲盲nt枚#vastaisuus',
#   'ilmet盲'],
#  ['k盲ytt盲盲',
#   'krematointi#v盲line',
#   'k盲ytt盲盲',
#   'vainaja',
#   'krematointi',
#   'tarkoittaa',
#   'v盲line',
#   'uuni',
#   'tuhka#k盲sittely#laite',
#   'magneetti'],
#  ['selviyty盲',
#   'vaatimus',
#   'vaihtelu',
#   'selviyty盲',
#   'vaatimus',
#   'vaihtelu',
#   'reagoida',
#   'tarjota',
#   'ratkaisu'],
#  ['antaa',
#   'asiakas',
#   'herkku#osasto',
#   'valikoima',
#   'koskea',
#   'neuvo',
#   'antaa',
#   'asiakas',
#   'tieto',
#   'herkku#osasto',
#   'tuote',
#   'herkku',
#   'antaa',
#   'tieto',
#   'saada',
#   'olla',
#   'tuote',
#   'tuottaja',
#   'alku#per盲',
#   'k盲ytt枚#p盲iv盲t',
#   'valmistus',
#   's盲ilytys'],
#  ['arvioida',
#   'vaara',
#   'riski#alue',
#   'arvioida',
#   'vaara',
#   'liitty盲',
#   'operaatio',
#   'riski#alue',
#   'taistelu#alue',
#   'luonnon#katastrofi',
#   'koetella',
#   'alue',
#   'j盲nnitty盲',
#   'alue'],
#  ['luoda',
#   'suhde',
#   'urheilu#kilpailija',
#   'luoda',
#   'kehitt盲盲',
#   'suhde',
#   'kilpailija',
#   'edustaja',
#   'kilpailu#s盲盲nt枚',
#   'noudattaa'],
#  ['valmis#ateria',
#   'valmis#ateria',
#   'ruoka',
#   'valmistus',
#   'valmistus#prosessi',
#   'valmistus',
#   'tarvittaa',
#   'teknologia',
#   'kohde#markkinat'],
#  ['merkit盲',
#   'laboratorio#n盲yte',
#   'tunniste',
#   'merkit盲',
#   'n盲ytteinen',
#   'tieto',
#   'laboratorio',
#   'k盲ytt枚',
#   'olla',
#   'laatu#j盲rjestelm盲'],
#  ['kouluttaa',
#   'nuohooja',
#   'tarjota',
#   'nuohooja',
#   'koulutus',
#   'ohjaus',
#   'ty枚',
#   'vastata',
#   'yritys',
#   'teollisuus',
#   'ty枚#normi',
#   'menettely'],
#  ['reagointi',
#   'terveys#uhka',
#   'reagointi',
#   'terveys',
#   'uhata',
#   'h盲t盲#tilanne',
#   'menetelm盲',
#   'reagoida',
#   'terveys',
#   'uhata',
#   'h盲t盲#tilanne',
#   'ty枚#paikka'],
#  ['mittaus',
#   'tekniikka',
#   'mittaaminen',
#   'tekniikka',
#   'mittaus',
#   'tieto#k盲sittely#menetelm盲',
#   'moninaisuus',
#   'kartoitus',
#   'ulottuvuus'],
#  ['laboratorio#k盲yt盲nt枚',
#   'valmistus#ala',
#   'soveltaa',
#   'vaatimus',
#   'laboratorio#k盲yt盲nt枚'],
#  ['kirkastaa',
#   '枚ljy',
#   'keitto#menetelm盲',
#   'selkeytt盲盲',
#   '枚ljy',
#   'keitt盲盲',
#   'vesi',
#   'kuumentaa',
#   'uuttaa',
#   '枚ljy',
#   'lis盲t盲',
#   'm盲盲r盲',
#   'vesi',
#   'kaataa',
#   '枚ljy',
#   'osa',
#   'vesi',
#   'kiehua',
#   'saostua',
#   'aine',
#   'j盲盲d盲',
#   'astia',
#   'pohja',
#   'pyrki盲',
#   'saada',
#   'aika',
#   'j盲盲m盲',
#   'sis盲lt盲盲',
#   'j盲盲nn枚s枚ljy'],
#  ['aurinko#s盲hk枚#paneeli#tyyppi',
#   'aurinko#kenno#tyyppi',
#   'valo#kenno#tyyppi',
#   'aurinko#s盲hk枚#kenna',
#   'paneeli',
#   'tehokkuus#etu',
#   's盲盲',
#   'kustannus',
#   'kest盲vyys',
#   'k盲ytt枚ik盲#arviointi',
#   'asennus#mahdollisuus'],
#  ['erotella',
#   'saha#tavara#tyyppi',
#   'erotella',
#   'saha#tavara',
#   'puu',
#   'vahvuus',
#   'vikko',
#   'perustua',
#   'luokka',
#   'saha#tavara',
#   'ryhmitell盲',
#   'koko#luokka'],
#  ['puhdistaa',
#   'verhoilla',
#   'huone#kalu',
#   'k盲ytt盲盲',
#   'puhdistus#menetelm盲',
#   'materiaali',
#   'verhoilla',
#   'huone#kalu',
#   'puhdistaminen',
#   'huone#kalu',
#   'valmistus',
#   'k盲ytt盲盲',
#   'puu#villa',
#   'kangas',
#   'mikro#kuitu',
#   'nahka'],
#  ['kirja',
#   'ajo#neuvo',
#   'poltto#aine#kulutus',
#   'kirja',
#   'ajo#neuvo',
#   'ajo#kilo#metri',
#   'poltto#aine',
#   'kulutus'],
#  ['ohjelmisto',
#   'poiketa',
#   'poikkeaminen',
#   'vakio',
#   'tapahtuma',
#   'ohjelmisto#j盲rjestelm盲',
#   'suoritus',
#   'aika',
#   'tapahtuma',
#   'tunnistaminen',
#   'muuttaa',
#   'virta',
#   'j盲rjestelm盲',
#   'toteuttaa#prosessi'],
#  ['opastaa',
#   'hius#tyyli',
#   'suositella',
#   'hiustyyli',
#   'antaa',
#   'asiakas',
#   'suositus',
#   'sopia',
#   'hius#tyyli',
#   'mieltymys',
#   'harkinta',
#   'peruste'],
#  ['keskustella',
#   'asiakas',
#   'kommunikoida',
#   'yritys',
#   'liike#toiminta#hanke',
#   'asiakas',
#   'idea',
#   'esitteleminen',
#   'palaute',
#   'saaminen',
#   'ratkaisu',
#   'l枚yt盲minen',
#   'ongelma'],
#  ['energia',
#   'muuntaminen',
#   'energia',
#   'l盲pi#k盲yd盲',
#   'prosessi',
#   'olo#muoto',
#   'muuttua'],
#  ['rakentaa',
#   'rakentaa',
#   'aito',
#   'k盲ytt盲盲',
#   'kaira',
#   'lapio',
#   'k盲sitiivistin',
#   'k盲si#ty枚#kalu'],
#  ['osoittaa',
#   'sitoutuminen',
#   'demokratia',
#   'osoittaa',
#   'omistautuminen',
#   'hallinto#j盲rjestelm盲',
#   'kansa',
#   'valta',
#   'vaali',
#   'valita',
#   'edustaja'],
#  ['tarkastaa',
#   'viini',
#   'laatu',
#   'tarkistaa',
#   'viini',
#   'laatu',
#   'varmistaa',
#   'viini',
#   'laatu',
#   'varmistaa',
#   'viini',
#   'laatu',
#   'palauttaa',
#   'pilaantua',
#   'viini',
#   'toimittaja',
#   'valvoa',
#   'viini',
#   'laatu',
#   'ilmoittaa',
#   'viini',
#   'palauttaa',
#   'tavara#toimittaja'],
#  ['muodostaa',
#   'hoito#suunnitelma',
#   'laatia',
#   'ker盲t盲',
#   'tieto',
#   'pohja',
#   'hoito#suunnitelma',
#   'arviointi',
#   'analyysi',
#   'p盲盲ttely#prosessi',
#   'perustua',
#   'arviointi'],
#  ['akku#testeri',
#   'akku',
#   'testaus#laite',
#   'akku',
#   'tila',
#   'testata',
#   'laite',
#   'akku#testeri',
#   'testata',
#   'akku#kento',
#   'lataus',
#   'testata',
#   'akku',
#   'lataus#kapasiteetti',
#   'havaita',
#   'vika',
#   'vaikuttaa',
#   'akku',
#   'suoritus#kyky',
#   'akku#testeri',
#   'tyyppi',
#   'riippua'],
#  ['tehd盲',
#   'huuto#kauppa#luettelo',
#   'tehd盲',
#   'huuto#kauppa#katalogi',
#   'laatia',
#   'luettelo',
#   'huuto#kaupata',
#   'tuote',
#   'sis盲llytt盲盲',
#   'luettelo',
#   'kuva',
#   'myynti#ehto'],
#  ['museo#tieto#kanta',
#   'museo#tieto#kanta',
#   'ty枚skentely',
#   'liitty盲',
#   'v盲line',
#   'prosessi'],
#  ['analysoida',
#   'elin#tarvike',
#   'ominaisuus',
#   'vastaanottaa',
#   'analysoida',
#   'vastaanottaa',
#   'elin#tarvike',
#   'ominaisuus',
#   'koostumus',
#   'ominaisuus'],
#  ['myyd盲',
#   'lippu',
#   'huolehtia',
#   'lippu',
#   'myynti#prosessi',
#   'huolehtia',
#   'lippu',
#   'myynti',
#   'huolehtia',
#   'lippu',
#   'myynti#vaihe',
#   'lippu',
#   'myynti',
#   'vaihtaa',
#   'raha',
#   'lippu',
#   'antaa',
#   'myynti#prosessi',
#   'loppu',
#   'lippu',
#   'maksu#tosite'],
#  ['raportoida',
#   'kasino#tapahtuminen',
#   'ilmoittaa',
#   'peli#alue',
#   'tapahtua',
#   'h盲iri枚#tilanne',
#   'koskea',
#   'kasino',
#   'asiakas'],
#  ['koordinoida',
#   'maan#tie',
#   'tavara#liikenne',
#   'koordinoida',
#   'maan#tie',
#   'tavara#kuljetus',
#   'suunnitella',
#   'koordinoida',
#   'maan#tie',
#   'tavara#liikenne',
#   'jakelu',
#   'matkustaja#liikenne#toimi',
#   'varmistaa',
#   'asiakas',
#   'tavara',
#   'saapua',
#   'm盲盲r盲n#p盲盲',
#   'aika#taulu'],
#  ['korjata',
#   'linssi',
#   'korjata',
#   'vaihtaa',
#   'asiakas',
#   'silm盲#lani',
#   'vaurioitua',
#   'linssi'],
#  ['k盲ytt盲盲',
#   'siivous#v盲line',
#   'k盲ytt盲盲',
#   'talon#mies',
#   'v盲line',
#   'k盲ytt盲盲',
#   'kiinteist枚#huolto#v盲line',
#   'siivous#v盲line',
#   'laite',
#   'lattia#kiillotin',
#   'p枚ly#huisku',
#   'imuri',
#   'siivous#kemikaali',
#   'k盲ytt盲minen'],
#  ['arvioida',
#   's盲de#hoito',
#   'antaminen',
#   'analysoida',
#   'arvioida',
#   's盲de#hoito',
#   'varmistaa',
#   'vastata',
#   'm盲盲r盲ys'],
#  ['hallita',
#   'logistiikka#palvelu',
#   'tarjoaja',
#   'koordinoida',
#   'varastointi',
#   'kuljetus',
#   'liitty盲',
#   'palvelu#tarjoaja',
#   'toimi'],
#  ['tulkita',
#   'testi',
#   'tulkita',
#   'testi',
#   'tieto',
#   'saaminen',
#   'potilas',
#   '盲lykkyys',
#   'saavutus',
#   'kiinnostus',
#   'kohde',
#   'persoonallisuus'],
#  ['k盲sitell盲',
#   'lento#kentt盲#valaistus',
#   'k盲sitell盲',
#   'suur#j盲nnite',
#   'sarja#piiri',
#   'valaisin#laitteisto',
#   'turvallisuus#menettely',
#   'varmistaa',
#   'j盲rjestelm盲',
#   'toimivuus',
#   'lento#asema',
#   'toiminta'],
#  ['tehd盲',
#   'el盲in',
#   'tarkastus',
#   'tehd盲',
#   'el盲in',
#   'ruumiina#vaus',
#   'tutkimus',
#   'tekeminen',
#   'el盲in',
#   'ruumis',
#   'kuolema',
#   'syy',
#   'tauti',
#   'etiologia',
#   'patofysiologia',
#   'selvitt盲minen',
#   'varmistaminen',
#   'elin#tarvike',
#   'k盲ytt盲盲',
#   'tuote'],
#  ['tarkastaa',
#   'pakata',
#   'pullo',
#   'tarkastaa',
#   'pakata',
#   'pullo',
#   'soveltaa',
#   'pullo',
#   'testaus#menettely',
#   'tarkastaa',
#   'soveltua',
#   'pullo',
#   'elin#tarvike',
#   'juoma#k盲ytt枚',
#   'noudattaa',
#   'pullottaminen',
#   'koskea',
#   'laki',
#   'yritys',
#   'm盲盲ritt盲盲',
#   'k盲yt盲nt枚'],
#  ['sitoutua',
#   'oppiminen',
#   'sosiaali#ty枚',
#   'sitoutua',
#   'kehittyminen',
#   'p盲ivitt盲盲',
#   'kehitt盲盲',
#   'tieto',
#   'taito',
#   'p盲tevyys',
#   'liitty盲',
#   'sosiaali#ty枚',
#   'harjoittaminen'],
#  ['k盲ytt盲盲',
#   'betoni#pumppu',
#   'k盲ytt盲盲',
#   'betoni#pumppu',
#   'robotti#varsi',
#   'et盲#ohjaus',
#   'seurata',
#   'kaataa#prosessi'],
#  ['auttaa',
#   'meri#navigointi',
#   'varmistaa',
#   'alus',
#   'aika',
#   'olla',
#   'kartta',
#   'meren#kulku#julkaisu',
#   'laatia',
#   'tiedote',
#   'matka#raportti',
#   'v盲yl盲#suunnitelma',
#   'sijainti#raportti'],
#  ['k盲ytt盲盲',
#   'kemikaali#analyysi#v盲line',
#   'laboratorio#laite',
#   'atomia#bsorptios#pektrometri',
#   'pH',
#   's盲hk枚n#johtavuus#mittari',
#   'suola#sumutus#kammio',
#   'k盲ytt盲minen'],
#  ['kehitt盲盲',
#   'e#opetus#suunnitelma',
#   'kehitt盲盲',
#   'e#opetus#strateg',
#   'kehitt盲盲',
#   'e#opetus',
#   'strategia',
#   'kehitt盲盲',
#   'verkko#opetus#suunnitelma',
#   'kehitt盲盲',
#   'e#opetus',
#   'suunnitelma',
#   'kehitt盲盲',
#   'verkko#opetus',
#   'suunnitelma',
#   'laatia',
#   'suunnitelma',
#   'koulutus#teknologia',
#   'tulos',
#   'maksimoiminen',
#   'organisaatio'],
#  ['tiedotus#v盲line',
#   'koskea',
#   'lain#s盲盲d盲nt枚',
#   'joukko',
#   'laki',
#   'koskea',
#   'viihde',
#   'televi#estint盲#teollisuus',
#   's盲盲ntely',
#   'koskea',
#   'radio',
#   'televisio#l盲hetys#palvelu',
#   'mainonta',
#   'sensurointi',
#   'verkko#palvelu'],
#  ['jakaa',
#   'vedon#ly枚nti',
#   'voitto',
#   'ker盲t盲',
#   'tappio',
#   'maksaa',
#   'voitto',
#   'ker盲t盲',
#   'tappio',
#   'peli',
#   's盲盲nt枚',
#   'menettely'],
#  ['k盲sitell盲',
#   'matkailu#ala',
#   'tieto',
#   'k盲sitell盲',
#   'matkailija#tieto',
#   'k盲sitell盲',
#   'matkailu',
#   'liitty盲',
#   'tieto',
#   'k盲sitell盲',
#   'data',
#   'matkailu#ala',
#   'ker盲t盲',
#   'k盲sitell盲',
#   'esitt盲盲',
#   'matkailu#ala',
#   'tieto',
#   'n盲ht盲vyys',
#   'tapahtuma',
#   'matkustaminen',
#   'majoitus'],
#  ['tarkkuus',
#   'huolellisuus',
#   'yksityis#kohta',
#   'huomioiminen',
#   'teht盲v盲',
#   'suorittaminen',
#   'ottaa',
#   'huomio',
#   'n盲k枚#kohta'],
#  ['huolehtia',
#   'peruukki',
#   'j盲rjest盲盲',
#   'yll盲pit盲盲',
#   'korjata',
#   'peruukki',
#   'hius#lis盲ke'],
#  ['laatia',
#   'meren#kulu',
#   'tehokkuus#suunnitelma',
#   'rahti#tila',
#   'alus',
#   'liikkuminen',
#   'hy枚dynt盲minen',
#   'j盲rjest盲minen',
#   'saada',
#   'olla',
#   'nosturi',
#   'm盲盲r盲',
#   'laituri#tila',
#   'seuranta',
#   'alus',
#   'olo#suhteet',
#   'alus',
#   'vakaus',
#   'rahti',
#   'paino',
#   'aiheutua',
#   'vaikutus',
#   'arviointi'],
#  ['suorittaa',
#   'koulutus#soveltuvuus#testaus',
#   'tehd盲',
#   'koulutus#soveltuvuus#testi',
#   'liitty盲',
#   'opiskelija',
#   'mielen#kiinto',
#   'kohde',
#   'persoonallisuus',
#   'valmius',
#   'taito'],
#  ['asentaa',
#   'katto#huopa',
#   'asentaa',
#   'huopakate',
#   'katto#huova',
#   'asentaminen',
#   'katto',
#   'katto#huova',
#   'asentaminen',
#   'tarvita',
#   'katto',
#   's盲盲nkest盲vyys',
#   'varmistaminen',
#   'tarkistaa',
#   'ett盲#ei',
#   'asennus',
#   'j盲盲d盲',
#   'aukko',
#   'huova',
#   'kiinnitt盲minen',
#   'katto'],
#  ['tiedottaa',
#   'vero#velvoite',
#   'organisaatio',
#   'yksityis#henkil枚',
#   'tiedottaminen',
#   'vero#velvoite',
#   'verotus#prosessi',
#   'koskea',
#   'lain#s盲盲d盲nt枚',
#   'm盲盲r盲ys',
#   'vero#velvollisuus'],
#  ['vaaka',
#   'punnitus#j盲rjestelm盲',
#   'vaaka',
#   'mitata',
#   'kulkea',
#   'ajo#neuvo',
#   'paino',
#   'l盲hett盲盲',
#   'h盲lytys',
#   'ajo#neuvo',
#   'yli#kuormittaa',
#   'ep盲#tasa#paino'],
#  ['hoitaa',
#   'metalli#kiinnike#kone',
#   'k盲ytt盲盲',
#   'kone',
#   'leikata',
#   'metalli#kiinnike',
#   'poimuttaa',
#   'metalli',
#   'kiinnitt盲盲',
#   'kartonki#kappale',
#   'asettaa',
#   'metalliru',
#   'kone',
#   'pujottaa',
#   'p盲盲',
#   'sy枚tt枚#p盲盲',
#   'puristin'],
#  ['arvioida',
#   'el盲in',
#   'k盲ytt盲ytyminen',
#   'tarkkailla',
#   'arvioida',
#   'el盲in',
#   'k盲ytt盲ytyminen',
#   'ty枚skennell盲',
#   'tunnistaa',
#   'poiketa',
#   'k盲ytt盲ytyminen',
#   'viitata',
#   'terveys',
#   'hyvin#vointi',
#   'heikkeneminen'],
#  ['ommella',
#   'paperi#materiaali',
#   'asettaa',
#   'kirja',
#   'materiaali',
#   'neula',
#   's盲盲t盲盲',
#   'painin#jalka',
#   'kirja',
#   'paksuus',
#   's盲盲t盲盲',
#   'ompele',
#   'pituus',
#   's盲盲t枚#ruuvi',
#   'ty枚nt盲盲',
#   'materiaali',
#   'paininjala',
#   'aktivoida',
#   'neula',
#   'ommella',
#   'paperi',
#   'pituus',
#   'katkaista',
#   'materiaali',
#   'yhdist盲盲',
#   's盲ie',
#   'pinota',
#   'tuote'],
#  ['k盲ytt盲盲',
#   'n盲ytt盲m枚',
#   'liikutus#j盲rjestelm盲',
#   'k盲ytt盲盲',
#   'ohjaus#j盲rjestelm盲',
#   'liikuttaa',
#   'lava',
#   'ilma#akro#batia#j盲rjestelm盲',
#   'valmistella',
#   'ohjelmoida',
#   'j盲rjestelm盲',
#   'lukea',
#   'liike'],
#  ['peri盲',
#   'maksu',
#   'vaate#s盲ilytys',
#   'peri盲',
#   'vaate#s盲ilytys',
#   'palvelu#maksu',
#   'k盲sitell盲',
#   'asiakas',
#   'saada',
#   'vaates#盲ilytys#maksu',
#   'tarvita'],
#  ['tunnistaa',
#   'tuholainen#tartunta',
#   'l盲hde',
#   'tarkastaa',
#   'rakennus',
#   'ymp盲rist枚',
#   'm盲盲ritt盲盲',
#   'tuholainen',
#   'tehd盲',
#   'omaisuus#vahinko',
#   'alku#per盲',
#   'laajuus'],
#  ['suklaa',
#   'valmistaminen',
#   'kaakao',
#   'prosessi',
#   'muuttaa',
#   'kaakao',
#   'suklaa',
#   'kaaka#opu',
#   'siemen',
#   'fermentoida',
#   'maku',
#   'saaminen',
#   'prosessi',
#   'papu',
#   'kuivata',
#   'puhdistaa',
#   'paahtaa',
#   'jauhaa',
#   'kaakao#rouhe',
#   'kaakaomassa',
#   'saaminen',
#   'jalostaa'],
#  ['auttaa',
#   'ajo#neuvo',
#   'tankkaaminen',
#   'auttaa',
#   'huolto#asema',
#   'asiakas',
#   'tankata',
#   'bensiini',
#   'diesel',
#   'k盲ytt盲盲',
#   'poltto#aine#pumppu'],
#  ['tutkia',
#   'ilmasto#prosessi',
#   'tehd盲',
#   'tutkimus',
#   'ilma#keh盲',
#   'esiinty盲',
#   'tapahtuma',
#   'ilma#keh盲',
#   'osa',
#   'olo#suhteet',
#   'vuoro#vaikutus',
#   'muutos',
#   'aika'],
#  ['ryhm盲#ty枚skentely',
#   'periaate',
#   'ihminen',
#   'yhteis#ty枚',
#   'sitoutuminen',
#   'tavoite',
#   'saavuttaminen',
#   'osallistuminen',
#   'viestint盲',
#   'idea',
#   'k盲ytt枚',
#   'helpottaminen'],
#  ['ohjata', 'alus', 'laituri', 'alus', 'ohjaaminen', 'satama', 'ankkurointi'],
#  ['niitti#tyyppi',
#   'valmistus',
#   'k盲ytt盲盲',
#   'niitti',
#   'kuumentaa',
#   'niitti',
#   'sokkoniitti',
#   'ly枚nti#niitti',
#   'niitti#mutteri',
#   'vetoniitti',
#   'yleis#niitti'],
#  ['valvoa',
#   'kierr盲tys#j盲rjestelm盲',
#   'valvoa',
#   'kierr盲tys',
#   'ilmastus#j盲rjestelm盲',
#   'soveltaa',
#   'analyysi'],
#  ['levitt盲盲',
#   'pinnoite',
#   'valu#malli',
#   'kuvio',
#   'suojaaminen',
#   'maalattu',
#   'ruiskuttaa',
#   'suoja#kerros',
#   'lakka'],
#  ['hius',
#   'kasvot',
#   'karva',
#   'tarkoittaa',
#   'valmiste',
#   'hius',
#   'k盲ytt盲盲',
#   'muotoilu#tuote',
#   'hius#voide',
#   'hius#lakko',
#   'samppa',
#   'hoito#aine',
#   'ominaisuus',
#   'k盲ytt枚#tarkoitus'],
#  ['huolehtia',
#   's盲hk枚#posti#alusta',
#   'toiminta',
#   'valvoa',
#   's盲hk枚#posti#j盲rjestelm盲',
#   'toiminta',
#   'yll盲pit盲盲',
#   'parantaa',
#   'sopia',
#   'palvelu',
#   'roska#posti',
#   'suodatus',
#   'virus#suojaus',
#   'mainonta',
#   'est盲minen',
#   'verkko#sivusto',
#   'muokkaus',
#   'haku#kone#optimointi'],
#  ['tiedo#tea#alyysi',
#   'uutinen#kirje',
#   'tutkiminen',
#   'kattavuus',
#   'k盲ytt枚#kelpoisuus',
#   'm盲盲ritt盲minen'],
#  ['tahdistaa',
#   '盲盲ni',
#   'kuva',
#   'synkronoida',
#   '盲盲ni',
#   'kuva',
#   'tahdistaa',
#   'nauhoittaa',
#   '盲盲ni',
#   'video#kuva'],
#  ['tehd盲',
#   'pinta#k盲sittely',
#   'tehd盲',
#   'kivi',
#   'pinta#k盲sittely',
#   'k盲ytt盲盲',
#   'ty枚#kalu',
#   'tekniikka',
#   'puhallus',
#   'hiominen',
#   'kaiverrus',
#   'kiillottaminen',
#   'karhentaminen',
#   'liekitys',
#   'ottaa',
#   'kivi',
#   'ominaisuus',
#   'huomio',
#   'tekniikka',
#   'valinta'],
#  ['kuuma#vulkanointi',
#   'tekniikka',
#   'k盲ytt盲盲',
#   'rengas',
#   'korjaaminen',
#   'repe盲minen',
#   'kynsi',
#   'aiheuttaa',
#   'repe盲minen',
#   'ruiskuttaa',
#   'kumi#liuko',
#   'rengas',
#   't盲ytt盲minen',
#   'tehd盲',
#   'rengas',
#   'l盲mp枚#k盲sittely',
#   'kumi#materiaali',
#   'yhdist盲盲'],
#  ['mitata', 'valaistus', 'voimakkuus', 'mitata', 'valo', 'kirkkaus#taso'],
#  ['hankkia',
#   'j盲rjestelm盲#komponentti',
#   'hankkia',
#   'laitteisto',
#   'ohjelmisto',
#   'verkko#komponentti',
#   'vastata',
#   'j盲rjestelm盲',
#   'osa',
#   'laajentaminen',
#   'tarvita',
#   'teht盲v盲',
#   'suorittaminen'],
#  ['kirjoittaa',
#   'raportti',
#   'el盲in',
#   'tieto',
#   'peruste',
#   'laatia',
#   'raportti',
#   'el盲in',
#   'tausta',
#   'el盲in',
#   'hoito',
#   'hallinnointi',
#   'liitty盲',
#   'yhteen#veto#raportti',
#   'laitos'],
#  ['kuuluttaa',
#   'bingo#numero',
#   'kuuluttaa',
#   'bingo#numero',
#   'peli',
#   'aika',
#   'yleis枚'],
#  ['opettaa',
#   'psykologia',
#   'psykologia',
#   'teoria',
#   'k盲yt盲nt枚',
#   'opettaminen',
#   'opiskelija',
#   'ihminen#mieli',
#   'k盲ytt盲ytyminen',
#   'yksil枚',
#   'mieli',
#   'prosessi',
#   'kehitys',
#   'liitty盲',
#   'asia',
#   'opettaminen'],
#  ['k盲ytt盲盲',
#   'tyhji枚#j盲rjestelm盲',
#   'veden#poisto',
#   'k盲ytt盲盲',
#   'tyhji枚#j盲rjestelm盲',
#   'poistaa',
#   'neste',
#   'synnytt盲盲',
#   'materiaali',
#   'tyhji枚'],
#  ['osallistua',
#   'kokous',
#   'osallistua',
#   'kokous',
#   'toimittaja',
#   'journalisti',
#   'keskustella',
#   'aihe',
#   'jakaa',
#   'teht盲v盲',
#   'ty枚#m盲盲r盲'],
#  ['huolehtia',
#   'teatteri#lavaste',
#   'asentaa',
#   'tarkastaa',
#   'huoltaa',
#   'korjata',
#   'n盲ytt盲m盲',
#   'lavaste'],
#  ['asettaa',
#   'p盲盲te#pys盲ytin',
#   'asettaa',
#   'p盲盲te#pys盲ytin',
#   'leveys',
#   'pituus',
#   'mitata',
#   'ter盲',
#   'et盲isyys',
#   'kivi',
#   'halkaista',
#   'vaatimus'],
#  ['ryhty盲',
#   'toimen#pide',
#   'elin#tarvike#turvallisuus',
#   'rikkomus',
#   'toteuttaa',
#   'toimen#pide',
#   'elin#tarvike#turvallisuus',
#   'rikkomus',
#   'm盲盲ritt盲盲',
#   'olla',
#   'ryhty盲',
#   'toimi',
#   'elin#tarvike#turvallisuus',
#   'rikkomus',
#   'ker盲t盲',
#   'esitt盲盲',
#   'todistus#aineisto',
#   'toteuttaa',
#   'toimi'],
#  ['laatia',
#   'raportti',
#   'juna#rata',
#   'vio',
#   'laatia',
#   'asia#kirja',
#   'raportti',
#   'koskea',
#   'tutkia',
#   'viko',
#   'luonne',
#   'viko',
#   'sijainti',
#   'rata',
#   'sijainti#paikka'],
#  ['noudattaa',
#   'mainonta',
#   'koskea',
#   's盲盲nt枚',
#   'noudattaa',
#   'mainonta',
#   'koskea',
#   'lain#s盲盲d盲nt枚',
#   'noudattaa',
#   'lain#s盲盲d盲nt枚',
#   's盲盲nt枚',
#   'koskea',
#   'tuote',
#   'esitteleminen',
#   'yleis枚',
#   'teksti',
#   'kuva',
#   'symboli'],
#  ['ohjelmiston#kehitt盲minen',
#   'tekniikka',
#   'periaate',
#   'analyysi',
#   'algoritmi',
#   'koodaus',
#   'testaus',
#   'ohjelma#paradigma',
#   'laatiminen'],
#  ['tehd盲',
#   'ennuste',
#   'tehd盲',
#   'tilasto#ennuste',
#   'tutkimus',
#   'tekeminen',
#   'k盲ytt盲盲',
#   'tieto',
#   'ennuste',
#   'kohde',
#   'olla',
#   'j盲rjestelm盲',
#   'k盲ytt盲ytyminen',
#   'j盲rjestelm盲',
#   'ennuste',
#   'vaikuttaa',
#   'muuttuja',
#   'liitty盲',
#   'tieto'],
#  ['kuljettaa',
#   'matka#tavara',
#   'siirt盲盲',
#   'matka#tavara',
#   'siirt盲盲',
#   'rahti',
#   'matka#tavara',
#   'portti',
#   'lento#yhti枚',
#   'matkustaja'],
#  ['j盲rjest盲盲',
#   'resurssi',
#   'tuotanto',
#   'koordinoida',
#   'tuotanto',
#   'p盲盲#oma#resurssi',
#   'perustua',
#   'dokumentaatio',
#   'k盲si#kirjoitus'],
#  ['selviyty盲',
#   'valmistus#m盲盲r盲#aika',
#   'paine',
#   'valmistus#prosessi',
#   'asettaa',
#   'aika#taulu',
#   'seuraaminen',
#   'toimi',
#   'toteuttaminen',
#   'm盲盲r盲#aika',
#   'umpeutua',
#   'prosessi',
#   'menn盲',
#   'vika'],
#  ['hoitaa',
#   'potilas',
#   'kyns盲',
#   'ohentaa',
#   'paksuuntua',
#   'varpaan#kyns盲',
#   'kynsi#pora',
#   'poistaa',
#   'lika',
#   'reuna',
#   'kynsi#enhoito#tuote'],
#  ['kirjoittaa',
#   'teksti',
#   'asia#sana',
#   'peruste',
#   's盲hk枚#posti#viesti',
#   'kirje',
#   'asia#kirja',
#   'laatiminen',
#   'sis盲lt枚',
#   'tiivist盲盲',
#   'avain#sana',
#   'avain#k盲site',
#   'peruste',
#   'muoto',
#   'kieli',
#   'valinta',
#   'asia#kirja',
#   'tyyppi'],
#  ['mainostaa',
#   'huuto#kauppa',
#   'edist盲盲',
#   'huuto#kauppa',
#   'myynti',
#   'radio',
#   'televisio',
#   'ammatti#lehti',
#   'luettelo',
#   'jakelu',
#   'kanava'],
#  ['robotiikka',
#   'tekniikka',
#   'alkaa',
#   'sis盲lty盲',
#   'robotti',
#   'suunnittelu',
#   'k盲ytt枚',
#   'valmistus',
#   'sovellus',
#   'robotiikka',
#   'osa',
#   'koneen#rakennus',
#   's盲hk枚#tekniikka',
#   'tieto#k盲sittely#tiede',
#   'ala',
#   'yhteys',
#   'mekatroniikka',
#   'automaatio#tekniikka'],
#  ['luoda',
#   'el盲in#rekisteri',
#   'luoda',
#   'el盲in#rekisteri',
#   'ala',
#   'tieto',
#   'k盲ytt盲盲',
#   'kirjan#pito#j盲rjestelm盲'],
#  ['k盲ytt盲盲',
#   'suunnittelu#ohjelma',
#   'k盲ytt盲盲',
#   'CAD#ohjelma',
#   'suunnittelu#ohjelma',
#   'k盲ytt枚',
#   'suunnitelma',
#   'luominen',
#   'muokkaaminen',
#   'arviointi',
#   'optimointi'],
#  ['avustaa',
#   'yhteis枚',
#   'tukea',
#   'yhteis枚',
#   'palvelu',
#   'tilanne',
#   'aiheutua',
#   'yleis枚',
#   'kohdistua',
#   'riski',
#   'tarvita',
#   'tuki'],
#  ['kalibroida',
#   'instrumentti',
#   'korjata',
#   'instrumentti',
#   'varmistaa',
#   'luotettavuus',
#   'ottaa',
#   'mittaus',
#   'verrata',
#   'tulos',
#   'verrokki#instrumentti',
#   'suorittaa',
#   'mittaus',
#   'standardoida',
#   'tulos',
#   'tehd盲',
#   'valmistaja',
#   'm盲盲ritt盲盲',
#   'v盲li#aja',
#   'kalibrointi#laite'],
#  ['suositella',
#   'asiakas',
#   'jalkine',
#   'suositella',
#   'jalkine',
#   'asiakas',
#   'neuvoa',
#   'tyyli',
#   'istuvuus',
#   'liitty盲',
#   'seikka',
#   'kertoa',
#   'jalkine',
#   'saatavuus'],
#  ['luoda',
#   'suhde',
#   'asiakas',
#   'her盲tt盲盲',
#   'asiakas',
#   'mielenkiinto',
#   'voittaa',
#   'asiakas',
#   'luottamus',
#   'muodostaa',
#   'suhde',
#   'ihminen',
#   'viesti',
#   'tapa',
#   'ymm盲rt盲盲',
#   'asiakas',
#   'toive',
#   'tarve',
#   'vastata'],
#  ['yhdist盲盲',
#   'tieto#alo',
#   'yhdistell盲',
#   'tieto',
#   'ala',
#   'yhdist盲盲',
#   'ala',
#   'suunnittelu',
#   'ala',
#   'panos',
#   'n盲k枚#kohta',
#   'hanke',
#   'kehitt盲minen',
#   'ty枚'],
#  ['k盲ytt盲盲',
#   'etu#kuormaaja',
#   'k盲ytt盲盲',
#   'etu#kuormaaja',
#   'ajo#neuvo',
#   'kauha',
#   'k盲ytt盲盲',
#   'louhinta',
#   'toiminto',
#   'laite',
#   'k盲ytt枚'],
#  ['aromatisoida',
#   'viini',
#   'erityis#viini',
#   'maku',
#   'parantaminen',
#   'lis盲盲minen',
#   'tuote',
#   'menetelm盲',
#   'v盲line'],
#  ['purkaa',
#   'tarvike',
#   'saapua',
#   'tarvike',
#   'paikka',
#   'purkaa',
#   'saapua',
#   'tarvike',
#   'vied盲',
#   'tarvike',
#   'ty枚#piste',
#   'varasto',
#   'purkaa',
#   'toimitus',
#   'kuorma#auto',
#   'siirt盲盲',
#   'tarvike',
#   'ty枚skentely',
#   'varasto#alue'],
#  ['avustaa',
#   'fysioterapeutti',
#   'auttaa',
#   'fysioterapeutti',
#   'asiakas#hallinto'],
#  ['ihmis#oikeus',
#   'koskea',
#   'oikeus',
#   'ihmis#oikeus#lain#s盲盲d盲nt枚',
#   'oikeus',
#   'osa#alue',
#   'koskea',
#   'ihmis#oikeus',
#   'edist盲minen',
#   'suojelu',
#   'asia',
#   'liitty盲',
#   'valtio',
#   'yleis#sopimus',
#   'sopimus',
#   'oikeus#vaikutus',
#   'ihmis#oikeus',
#   'koskea',
#   'lain#s盲盲d盲nt枚',
#   'kehitt盲minen',
#   'paneminen',
#   'tehd盲',
#   'toimen#pide'],
#  ['k盲ytt盲盲',
#   'musiikki#terapia',
#   'lopettaa#menetelm盲',
#   'p盲盲tt盲盲',
#   'potilas',
#   'musiikki#terapia#istunto',
#   'lopettaa'],
#  ['pit盲盲',
#   'lento#asema',
#   'kiito#tie',
#   'k盲ytt盲盲',
#   'lakaisu#kone',
#   'lakaisu#laite',
#   'integroida',
#   'lakaisu',
#   'puhallus#kone',
#   'puhdistaa',
#   'lento#asema',
#   'kiito#tie',
#   'roska',
#   'romu',
#   'vaurioitua',
#   'p盲盲llyste',
#   'ruoho',
#   'leikkaus',
#   'olla',
#   'kivi',
#   'ilma#alus',
#   'rengas',
#   'olla',
#   'kumi',
#   'kuolla',
#   'lintu',
#   'ilma#alus',
#   'metalli#osa'],
#  ['k盲ytt盲盲',
#   'happi#leikkaus#poltin',
#   'k盲ytt盲盲',
#   'happi#leikkaus#poltin',
#   'k盲ytt盲盲',
#   'happi',
#   'ase#tyleeni',
#   'ty枚#kappale',
#   'leikkaaminen'],
#  ['soveltaa',
#   'tuonti#strategia',
#   'k盲ytt盲盲',
#   'tuonti#strategia',
#   'seurata',
#   'toteuttaa',
#   'tuonti#strategia',
#   'yritys',
#   'koko',
#   'tuote',
#   'luonne',
#   'saada',
#   'olla',
#   'asian#tuntemus',
#   'markkina',
#   'vallita',
#   'liike#toiminta#olo#suhteet',
#   'strategia',
#   'kuulua',
#   'menettely',
#   'strategia#kysymys',
#   'k盲ytt盲盲',
#   'tulli#asioitsija',
#   'v盲litt盲j盲'],
#  ['sekoittaa',
#   'elin#tarvike',
#   'aines#osa',
#   'sekoittaa',
#   'kultivoida',
#   'aines#osa',
#   'saada',
#   'reagenssi',
#   'valmistaa',
#   'elin#tarvike',
#   'juoma#tuote',
#   'tehd盲',
#   'analyysi'],
#  ['auditoida',
#   'sopimus#kumppani',
#   'tarkastaa',
#   'sopimus#kumppani',
#   'toimi#ala',
#   'toimeksisaaja',
#   'tutkiminen',
#   'dokumentointi',
#   'm盲盲ritt盲minen',
#   'noudattaa',
#   'turvallisuus',
#   'ymp盲rist枚',
#   'suunnittelu',
#   'rakentaminen',
#   'testaus',
#   'laatu',
#   'jnen',
#   'koskea',
#   'm盲盲r盲ys',
#   'vaatimus'],
#  ['teknologia',
#   'tekniikka',
#   'teknologia',
#   'luoda',
#   'muokata',
#   'tekij盲',
#   'auttaa',
#   'luonto',
#   'selviytyminen',
#   'k盲si#ty枚',
#   'selviyty盲#ty枚#kalu',
#   'ase'],
#  ['k盲ytt盲盲',
#   'tieto',
#   'tallentaminen',
#   'ohjelmisto',
#   'k盲ytt盲盲',
#   'tieto',
#   'tallentaminen',
#   'ohjelmisto',
#   's盲ilytt盲盲',
#   'todiste',
#   'k盲ytt盲盲',
#   'tieto',
#   'tallennus#ohjelmisto',
#   'k盲ytt盲盲',
#   'data',
#   'tallentaminen',
#   'ohjelmisto',
#   'huolehtia',
#   'todistus#aineisto',
#   'tallentaminen',
#   'k盲ytt盲盲',
#   'erikois#sovellus',
#   'ohjelmisto',
#   'tieto',
#   'ker盲盲minen',
#   's盲ilytt盲minen'],
#  ['ultra#盲盲ni#tutkimus',
#   'kaiku#tutkimus',
#   'raskaus',
#   'aika',
#   'k盲ytt盲盲',
#   'ultra#盲盲ni',
#   'antaa',
#   'tieto',
#   'raskaus',
#   'alku#p盲iv盲',
#   'eteneminen',
#   'siki枚',
#   'visualisointi',
#   '盲iti',
#   'kohtu'],
#  ['j盲rjest盲盲',
#   'riistan#mets盲stys#retk盲',
#   'suunnitella',
#   'j盲rjest盲盲',
#   'riistan#mets盲stys',
#   'kalastus#retki'],
#  ['audio#metri',
#   'kuulo#mittaus',
#   'kuulo#mittaus',
#   'liitty盲',
#   '盲盲nen#voimakkuus',
#   '盲盲nen#korkeus',
#   'puhtaus',
#   'apu',
#   'diagnosoida',
#   'huono#kuuloisuus',
#   'liitty盲',
#   'h盲iri枚'],
#  ['k盲ytt盲盲',
#   'ohjelmointi',
#   'hy枚dynt盲盲',
#   'tieto',
#   'viestint盲#tekniikka',
#   'erikois#v盲line',
#   'luoda',
#   'tieto#kone#koodi',
#   'k盲sitell盲',
#   'laskenta',
#   'funktio',
#   'pyrki盲',
#   'v盲ltt盲盲',
#   'tieto',
#   'k盲ytt盲盲',
#   'ohjelmointi#kieli',
#   'tukea',
#   'menetelm盲'],
#  ['valmistella',
#   '枚ljy#l盲hde',
#   'rakenne',
#   'arviointi#ohjelma',
#   'valmistella',
#   '枚ljy#l盲hde',
#   'rakenne',
#   'arviointi#ohjelma',
#   'viesti盲',
#   '枚ljy#netsint盲#tiimi',
#   'tehd盲',
#   'yhteis#ty枚'],
#  ['laite',
#   'testaus#menetelm盲',
#   'terveyden#huolto',
#   'laite',
#   'testaus#menetelm盲',
#   'menetelm盲',
#   'testata',
#   'laite',
#   'materiaali',
#   'komponentti',
#   'laatu',
#   'tarkkuus',
#   'suoritus#kyky',
#   'j盲rjestelm盲',
#   'rakentaminen',
#   'aika'],
#  ['perfuusio',
#   'terveys#tiede',
#   'alkaa',
#   'liitty盲',
#   'veri',
#   'happi',
#   'pumppaaminen',
#   'henkil枚',
#   'keho',
#   'sanoa',
#   'keho',
#   'veren#kierto'],
#  ['diagnosoida',
#   'ep盲#muodostuma',
#   'leua',
#   'hammas',
#   'rakenne',
#   'leuka',
#   'ep盲#muodostuma',
#   'hammas',
#   'paikka',
#   'hammas',
#   'kasvot',
#   'rakenne',
#   'poikkeavuus',
#   'arvioiminen'],
#  ['tehd盲',
#   'ravitsemus#tutkimus',
#   'tehd盲',
#   'ravitsemus#tutkimus',
#   'parantaa',
#   'v盲est枚',
#   'terveys',
#   'keskitty盲',
#   'kysymys',
#   'riski',
#   'lihavuus',
#   'suolisto',
#   'toiminta',
#   'tuki',
#   'liikunta#elin',
#   'terveys',
#   'heikkous'],
#  ['nessus',
#   'tieto#kone#ohjelma',
#   'erikoistua',
#   'tieto',
#   'ty枚#kalu',
#   'testata',
#   'j盲rjestelm盲#tieto',
#   'k盲ytt枚',
#   'koskea',
#   'tieto#turva#heikkous',
#   'kehitt盲盲',
#   'ohjelmis#toyritys'],
#  ['antaa',
#   'opiskelija',
#   'ohje',
#   'laite',
#   'k盲ytt枚',
#   'antaa',
#   'opiskelija',
#   'apu',
#   'v盲line',
#   'ty枚skentely',
#   'k盲ytt盲盲',
#   'k盲yt盲nt枚',
#   'oppi#tunti',
#   'ratkaista',
#   'ongelma',
#   'tarvita'],
#  ['opettaa',
#   'perus#aste',
#   'keski#aste',
#   'opetus#sis盲lt枚',
#   'opettaa',
#   'yl盲#koulu',
#   'lukio',
#   'opetus#sis盲lt枚',
#   'opettaa',
#   'erikoistua#ala',
#   'liitty盲',
#   'perus#aste',
#   'keski#aste',
#   'opetus#sis盲lt枚',
#   'ottaa',
#   'huomio',
#   'oppilas',
#   'ik盲',
#   'k盲ytt盲盲',
#   'opetus#menetelm盲'],
#  ['s盲盲nt枚',
#   'yhteent枚rm盲盲minen',
#   'ehk盲iseminen',
#   'meri',
#   'meride',
#   's盲盲nt枚',
#   'yhteent枚rm盲盲minen',
#   'ehk盲iseminen',
#   'meri',
#   'koskea',
#   's盲盲nt枚',
#   'perus#n盲k枚#kohta',
#   'alus',
#   'toiminta',
#   'alus',
#   'n盲k枚#kentt盲',
#   'kulku#valo',
#   'merkki#valo',
#   'valo',
#   '盲盲ni#merkki',
#   'meren#kulu',
#   'merkinanto#laite',
#   'poiju'],
#  ['laatia',
#   'lento#lehtinen',
#   'laatia',
#   'laatia',
#   'esite',
#   'ty枚#h枚notto#esite',
#   'esite',
#   'laatiminen',
#   'ihminen',
#   'saaminen',
#   'ty枚',
#   'mainos#ilmoitus',
#   'laatiminen',
#   'mainos#kampanja',
#   'kehitt盲minen',
#   'edist盲minen'],
#  ['osallistua',
#   'tarjous#kilpailu',
#   'esitt盲盲',
#   'tarjous',
#   'organisaatio',
#   'pyyt盲盲',
#   'tarjous#pyynt枚',
#   'tehd盲',
#   'ty枚',
#   'toimittaa',
#   'tavara',
#   'sopia',
#   'tarjous#menettely',
#   'aika'],
#  ['reunos#pohjaus#menetelm盲',
#   'valmistaa',
#   'kenk盲',
#   'kokota#prosessi',
#   'tekniikka',
#   'menetelm盲',
#   'valmistaa',
#   'kenk盲',
#   'kokota#prosessi',
#   'tekniikka',
#   'kenk盲',
#   'reunos#pohjaus#menetelm盲',
#   'valmistaminen',
#   'k盲ytt盲盲',
#   'teknologia',
#   'laite',
#   'kone',
#   'ty枚#kalu'],
#  ['halkaista',
#   'piikide',
#   'kiekka',
#   'halkaista',
#   'lanka#saha#kone',
#   'piikide',
#   'ultra#ohu',
#   'kiekka',
#   'paksuus',
#   'milli#metri'],
#  ['huoltaa',
#   'ajo#neuvo',
#   'seurata',
#   'ajo#neuvo',
#   'kunto',
#   'toteuttaa',
#   'toimi',
#   'optimoida',
#   'huolto',
#   'korjaus',
#   'viesti盲',
#   'korjaama',
#   'auto#liike'],
#  ['koota',
#   'kamera',
#   'asentaa',
#   'kamera',
#   'runko',
#   'osa',
#   'sulkea',
#   'peili',
#   'salama#valo',
#   'kuva#prosessori',
#   'n盲ytt枚#ruutu',
#   'akku',
#   'penta#prisma',
#   'etsi盲',
#   'kuva#anturi',
#   'kamera',
#   'linssi',
#   'linssi',
#   'asentaa',
#   'k盲ytt盲盲',
#   'kierteitt盲盲',
#   'kiinni#tysrengas',
#   'levitt盲盲',
#   'liima',
#   'ulko#reuna',
#   'linssi',
#   'pysy盲'],
#  ['varmistaa',
#   'vaatimus',
#   'noudattaminen',
#   'huolehtia',
#   'vaatimus',
#   'noudattaminen',
#   'varmistua',
#   'vaatimus',
#   'noudattaminen',
#   'varmistaa',
#   'yhdenmukaisuus',
#   'vaatimus',
#   'huolehtia',
#   'standardi',
#   'laki',
#   'noudattaminen',
#   'varmistua',
#   'yhdenmukaisuus',
#   'vaatimus',
#   'sopia',
#   'soveltua',
#   'standardi',
#   'vaatimus',
#   'noudattaminen',
#   'varmistaminen',
#   'organisaatio',
#   'noudattaa',
#   'saavuttaa',
#   'tavoite',
#   'eritelm盲',
#   'toiminta#linja',
#   'standardi',
#   'lain#s盲盲d盲nt枚'],
#  ['kehitt盲盲',
#   'charter#matka#ohjelma',
#   'laatia',
#   'charter#matka#ohjelma',
#   'kehitt盲盲',
#   'ohjelma',
#   'tilaus#matka',
#   'laatia',
#   'ohjelma',
#   'charter#matka',
#   'laatia',
#   'tilaus#matka#ohjelma',
#   'luoda',
#   'charter#ohjelma',
#   'organisaatio',
#   'k盲yt盲nt枚',
#   'markkina#kysynt盲'],
#  ['k盲sittely', 'elin#tarvike', 'prosessi', 'k盲ytt盲盲', 'k盲sittely'],
#  ['l盲盲ke#valmiste',
#   'kehitt盲minen',
#   'l盲盲ke#kehitys',
#   'l盲盲ke',
#   'kehitt盲minen',
#   'l盲盲ke',
#   'valmistus#vaihe',
#   'vaihe',
#   'el盲in',
#   'koskea',
#   'tutkimus',
#   'testaus',
#   'vaihe',
#   'ihminen',
#   'teht盲v盲',
#   'tutkimus',
#   'osa#vaihe',
#   'vaatia',
#   'loppu#tuote',
#   'l盲盲ke'],
#  ['hallita',
#   'ICT#virtualisointi#kone',
#   'hallita',
#   'palvelin',
#   'ty枚#asema',
#   'virtualisoiminen',
#   'hallita',
#   'palvelin',
#   'virtualisointi',
#   'hallita',
#   'ict#virtualisointi#kone',
#   'hallita',
#   'ty枚#asema',
#   'virtualisointi',
#   'hallita',
#   'palvelin',
#   'ty枚#asema',
#   'virtualisointi',
#   'valvoa',
#   'ty枚#kalu',
#   'luoda',
#   'kone#ymp盲rist枚',
#   'toimia',
#   'ohjelmisto#ymp盲rist枚'],
#  ['tarkastaa',
#   'kuivatus#kanava',
#   'tarkastaa',
#   'viem盲ri#kanava',
#   'huoltaa',
#   'tyhjent盲盲',
#   'r盲yst盲',
#   'viem盲ri#j盲rjestelm盲',
#   'veden#siirto#j盲rjestelm盲',
#   'varmistaa',
#   'vesi',
#   'kuivatus',
#   'ehk盲ist盲',
#   'infrastruktuuri',
#   'tie',
#   'rauta#tie',
#   'vahingoittuminen'],
#  ['j盲rjest盲盲',
#   'n盲yttely',
#   'j盲rjest盲盲',
#   'j盲set盲',
#   'n盲yttely',
#   'taide#teos',
#   'yleis枚',
#   'saada'],
#  ['luoda',
#   'rakenne',
#   'luoda',
#   'musiikin#teoria',
#   'apu',
#   '盲盲ni#rakenne',
#   'harmonia',
#   'melodio'],
#  ['antaa',
#   'hoito#ohje',
#   'antaa',
#   'asiakas',
#   'potilas',
#   'tieto',
#   'keino',
#   'varmistaa',
#   'haava',
#   'paranemis#prosessi'],
#  ['edist盲盲',
#   'sisustus#suunnittelu',
#   'edist盲盲',
#   'sisustus#suunnittelu',
#   'tehd盲',
#   'sis盲#tila',
#   'suunnitelma',
#   'edist盲盲',
#   'kustannus#tehokas',
#   'uusiutua',
#   'materiaali',
#   'k盲ytt枚'],
#  ['tarkastaa',
#   'turvallisuus',
#   'alus',
#   'tarkastaa',
#   'turvallisuus',
#   'alus',
#   'tunnistaa',
#   'poistaa',
#   'alus',
#   'miehist枚',
#   'koskemattomuus',
#   'kohdistua',
#   'uhka'],
#  ['ty枚skennell盲',
#   'yhteis#ty枚',
#   'viran#omainen',
#   'ruumis#huone#palvelu',
#   'tehd盲',
#   'yhteis#ty枚',
#   'poliisi',
#   'hautaus#toimisto',
#   'ty枚#tekij盲',
#   'vainaja',
#   'perhe'],
#  ['tarjota',
#   'koira',
#   'ulkoilutus#palvelu',
#   'tarjota',
#   'koira#ulkoilutus#palvelu',
#   'tarjota',
#   'koira',
#   'ulkoilutus#palvelu',
#   'lukea',
#   'toimi',
#   'sopimus',
#   'teko',
#   'palvelu',
#   'asiakas',
#   'k盲sittely',
#   'tarvita',
#   'varuste',
#   'valitseminen',
#   'k盲ytt盲minen',
#   'vuoro#vaikutus',
#   'koira',
#   'koira',
#   'ulkoilutus'],
#  ['huolehtia',
#   'tilan#k盲ytt枚',
#   'valvoa',
#   'tilan#k盲ytt枚',
#   'suunnitelma',
#   'laatiminen',
#   'kehitt盲minen',
#   'varmistaa',
#   'tila',
#   'k盲ytt盲j盲',
#   'tarve',
#   'toive',
#   'ottaa',
#   'huomio'],
#  ['ottaa',
#   'k盲ytt枚',
#   'lento#kentt盲#alue',
#   'turvallisuus#auditointi#j盲rjestelm盲',
#   'ottaa',
#   'k盲ytt枚',
#   'lento#kentt盲#alue',
#   'turvallisuus#auditointi#j盲rjestelm盲',
#   'osasto'],
#  ['varmistaa',
#   'kaasu',
#   'paine',
#   'varmistaa',
#   'tarvita',
#   'vakio',
#   'kaasu',
#   'paine',
#   'kone',
#   'laite',
#   'hitsaus#laite',
#   'osa',
#   'kaasu',
#   'toimia',
#   'k盲ytt盲盲',
#   'metalli',
#   'ty枚st盲minen',
#   'metalli#teollisuus'],
#  ['jalkine',
#   'luominen#prosessi',
#   'jalkine',
#   'luominen#prosessi',
#   'alkaa',
#   'inspiraatio',
#   'seurata',
#   'suunnittelu',
#   'valmistus',
#   'vaihe',
#   'jalkine',
#   'materiaali',
#   'komponentti',
#   'prosessi',
#   'k盲site',
#   'suuntaus'],
#  ['kehitt盲盲',
#   'puolustus#politiikka',
#   'strategia',
#   'laatiminen',
#   'puolustus#politiikka',
#   'kehitt盲minen',
#   't盲yt盲nt枚枚npano',
#   'puolustus#organisaatio',
#   'operaatio',
#   'turvallisuus',
#   'parantaminen',
#   'toiminta',
#   'parantaminen',
#   'vaara',
#   'uhka#tilanne'],
#  ['tulkita',
#   'teksti',
#   'lukea',
#   'ymm盲rt盲盲',
#   'teksti',
#   'antaa',
#   'vaihe',
#   'kerta',
#   'tieto',
#   'teht盲v盲',
#   'suorittaa'],
#  ['huolehtia',
#   'alus',
#   'moottori',
#   'j盲rjestelm盲',
#   'hallita',
#   'p盲盲#moottori',
#   'h枚yry',
#   'kaasu',
#   'diesel#moottori',
#   'j盲盲hdytys#j盲rjestelm盲',
#   'alus',
#   'moottori#j盲rjestelm盲',
#   'kuulua',
#   'laite'],
#  ['neuvo',
#   'riski#raskaus',
#   'tunnistaa',
#   'riski#raskaus',
#   'merkki',
#   'antaa',
#   'koskea',
#   'neuvo'],
#  ['perustus#laki',
#   'valtio#s盲盲nt枚#oikeus',
#   'valtio',
#   'organisaatio',
#   'periaate',
#   'vakiintua',
#   'k盲yt盲nt枚'],
#  ['siirt盲盲',
#   'tuote',
#   'v盲line',
#   'k盲ytt盲minen',
#   'tuote',
#   'siirt盲minen',
# ...
#   'j盲盲hdytt盲盲',
#   'vied盲',
#   'upottaa',
#   'vesi'],
#  ['huolehtia',
#   'palaute',
#   'v盲litt盲minen',
#   'palaute',
#   'antaminen',
#   'kollega',
#   'asiakas',
#   'viestint盲',
#   'vastaaminen',
#   'arviointi'],
#  ['hoitaa',
#   'lasin#j盲盲hdytys#uuni',
#   'k盲ytt盲盲',
#   'l盲mp枚#tila#s盲盲dell盲',
#   'uuni',
#   'k盲ytt盲盲',
#   'temperointi',
#   'prosessi',
#   'lasi',
#   'j盲盲hdytt盲盲',
#   'v盲ltt盲盲',
#   'j盲nnitys'],
#  ['umpi#eritys#j盲rjestelm盲',
#   'fysiologia',
#   'umpi#rauhas',
#   'toiminto',
#   'komponentti',
#   'hormoni',
#   'kemia',
#   'hormoni',
#   'solu#vaikutus'],
#  ['jalkine',
#   'nahka#tuote',
#   'markkinointi',
#   'suunnittelu',
#   'markkinointi#suunnitelma',
#   'laatiminen',
#   'periaate',
#   'menetelm盲',
#   'yritys',
#   'sijoittautua',
#   'suhde',
#   'kilpailija',
#   'ottaa',
#   'huomio',
#   'jalkine',
#   'nahka#tuote',
#   'markkinat',
#   'erityis#piirre'],
#  ['kehitt盲盲',
#   'koulutus#ohjelma',
#   'suunnitella',
#   'ohjelma',
#   'ty枚#tekij盲',
#   'tulla',
#   'ty枚#tekij盲',
#   'opettaa',
#   'ty枚',
#   'tarvita',
#   'taito',
#   'parantaa',
#   'laajentaa',
#   'taito',
#   'toiminto',
#   'teht盲v盲',
#   'valita',
#   'suunnitella',
#   'toimi',
#   'tarkoitus',
#   'esitell盲',
#   'ty枚',
#   'j盲rjestelm盲',
#   'parantaa',
#   'yksil枚',
#   'ryhm盲',
#   'toiminta',
#   'organisaatio#ymp盲rist枚'],
#  ['merkit盲', 'hihna', 'merkit盲', 'hihna', 'tunniste#nauha'],
#  ['varmistaa',
#   'vesi#viljelm盲#ty枚#tekij盲',
#   'terveys',
#   'turvallisuus',
#   'varmistaa',
#   'terveys',
#   'turvallisuus#menettely',
#   'laatia',
#   'noudattaa',
#   'vesi#viljely#laitos',
#   'tila',
#   'h盲kki',
#   'varmistaa',
#   'henkil枚st枚',
#   'yleis枚',
#   'antaa',
#   'ohje',
#   'ty枚#teht盲v盲',
#   'suorittaa',
#   'terveys',
#   'turvallisuus#m盲盲r盲ys'],
#  ['suunnitella',
#   'mainos',
#   'laatia',
#   'mainos',
#   'hy枚dynt盲盲',
#   'luovuus',
#   'pit盲盲',
#   'mieli',
#   'asiakas',
#   'vaatimus',
#   'kohde#yleis枚',
#   'media',
#   'markkinointi#tavoite'],
#  ['valvoa',
#   'miehist枚',
#   'liikkuminen',
#   'valvoa',
#   'miehist枚',
#   'nouseminen',
#   'alus',
#   'poistuminen',
#   'alus',
#   'varmistaa',
#   'turvallisuus#m盲盲r盲ys',
#   'noudattaa',
#   'eritelm盲'],
#  ['ennustaa',
#   'tuote',
#   'kysynt盲',
#   'ker盲t盲',
#   'analysoida',
#   'laskea',
#   'tuote',
#   'palvelu',
#   'kysynt盲',
#   'raportti',
#   'asiakas',
#   'osto#toiminta',
#   'peruste'],
#  ['tuki',
#   'todistaja',
#   'tukea',
#   'todistaja',
#   'tuomio#istuin#k盲sittely',
#   'aika',
#   'todistaja',
#   'tuntea',
#   'olo',
#   'valmistautua',
#   'oikeuden#k盲ynti',
#   'auttaa',
#   'todistaja',
#   'laatia',
#   'kertomus',
#   'valmistautua',
#   'asian#ajaja',
#   'kysymys'],
#  ['tuki',
#   'nuori',
#   'my枚nteisyys',
#   'auttaa',
#   'lapsi',
#   'nuori',
#   'arvioida',
#   'identiteetti#tarve',
#   'kehitt盲盲',
#   'oma#kuva',
#   'parantaa',
#   'itsetunto',
#   'edist盲盲',
#   'itseluottamus'],
#  ['kehitt盲盲',
#   'el盲ke#j盲rjestelm盲',
#   'laatia',
#   'suunnitelma',
#   'el盲ke#etuus',
#   'ottaa',
#   'huomio',
#   'etuus',
#   'j盲rjest盲minen',
#   'liitty盲',
#   'riski',
#   'toteuttaa#vaikeus'],
#  ['kirjaa',
#   'tavara#toimitus',
#   'kirja',
#   'kauppa#tavara',
#   'kuljetus',
#   'kirja',
#   'pit盲minen',
#   'tavara',
#   'toimitus',
#   'poikkeavuus',
#   'ilmoittaminen',
#   'kulu',
#   'hallitseminen',
#   'varasto#m盲盲r盲',
#   's盲ilytt盲minen'],
#  ['valmistaa',
#   'turkis#tuote',
#   'valmistaa',
#   'turkis#tuote',
#   'vuota',
#   'k盲sitell盲',
#   'leikata',
#   'raaka#materiaali',
#   'k盲ytt盲盲',
#   'kemikaali',
#   'tarvita',
#   'noudattaa',
#   'laatu#varmistus#k盲yt盲nt枚',
#   'viimeistell盲',
#   'tuote'],
#  ['suorittaa',
#   'turvallisuus#tarkastus',
#   'varmistaa',
#   'turvallisuus#tarkastus',
#   'koskea',
#   'vaatimus',
#   'noudattaa',
#   'kirjata',
#   'turva#menettely',
#   'tiedottaa',
#   'asiakas'],
#  ['noudattaa',
#   'tuotanto#suunnitelma',
#   'noudattaa',
#   'tuotanto#aika#taulu',
#   'noudattaa',
#   'tuotanto',
#   'aika#taulu#suunnittelu',
#   'seurata',
#   'teollisuus#yritys',
#   'johtaja',
#   'laatia',
#   'suunnitelma',
#   'pyrki盲',
#   'varmistaa',
#   'tuotanto#prosessi',
#   'viiv盲sty盲',
#   'tuotanto#prosessi',
#   'seurata'],
#  ['lemmikki#el盲in#tuote',
#   'tuote#tyyppi',
#   'tuote#merkki',
#   'k盲ytt盲盲',
#   'lemmikki#el盲in',
#   'hoito'],
#  ['k盲ytt盲盲',
#   'korko#puristin',
#   'asentaa',
#   'k盲ytt盲盲',
#   'korko#puristin',
#   'kohokuvioida',
#   'ohjain',
#   'asettaa',
#   'paperi#pina',
#   'arkki',
#   'luoda',
#   'korottaa',
#   'kohokuvioida',
#   'kuva',
#   'poistaa',
#   'puristin',
#   'pinota'],
#  ['kuunnella',
#   'riita',
#   'osa#puoli',
#   'kertomus',
#   'kuunnella',
#   'riita',
#   'osa#puoli',
#   'argumentti',
#   'selvitt盲盲',
#   'v盲盲rin#k盲sitys',
#   'virhe',
#   'kommunikaatio'],
#  ['laskea',
#   'raha',
#   'laskea',
#   'raha',
#   'laskea',
#   'raha',
#   'lajitella',
#   'seteli',
#   'kolikko'],
#  ['poltto#aine',
#   'jakelu#j盲rjestelm盲',
#   'poltto#aine',
#   'jakelu#j盲rjestelm盲',
#   'rakenne#osa',
#   'putki#j盲rjestelm盲',
#   'venttiili',
#   'pumppu',
#   'suodatin',
#   'poltto#aine#n盲ytt枚',
#   'n盲k枚#kohta',
#   'tuntemus'],
#  ['liitt盲minen',
#   'puristaa',
#   'metalli#kappale',
#   'yhdist盲盲',
#   'kappale',
#   'kappale',
#   'muotoilla',
#   'sopia'],
#  ['hallinnoida',
#   'kiinteist枚#rekisteri',
#   'yhteis枚',
#   'kiinteist枚#rekisteri',
#   'hallinnointi',
#   'maan#mittaus#toimitus',
#   'kiinteist枚#rekisteri#kartta',
#   'apu'],
#  ['myyd盲',
#   'talous#tavara',
#   'myyd盲',
#   'koti#talous#laite',
#   'tarvike',
#   'mikro#aalto#uuni',
#   'teho#sekoitin',
#   'keitti枚#tarvike',
#   'asiakas',
#   'mieltymys',
#   'tarve'],
#  ['hoitaa',
#   'sopimus#kiista',
#   'ehdottaa',
#   'ratkaisu',
#   'oikeus#juttu',
#   'v盲ltt盲minen',
#   'ratkaista',
#   'sopimus',
#   'liitty盲',
#   'eri#mielisyys',
#   'hoitaa',
#   'sopimus',
#   'liitty盲',
#   'kiista',
#   'ratkaista',
#   'sopimus#kiista',
#   'valvoa',
#   'sopimus#puoli',
#   'synty盲',
#   'ongelma',
#   'tarjota',
#   'ratkaisu',
#   'oikeuden#k盲ynti',
#   'v盲ltt盲minen'],
#  ['laboratorio',
#   'diagnostiikka#menetelm盲',
#   'laboratorio',
#   'diagnostiikka#menetelm盲',
#   'menetelm盲',
#   'menetelm盲',
#   'menetelm盲',
#   'menetelm盲',
#   'menetelm盲',
#   'menetelm盲'],
#  ['luoda',
#   'kauppa',
#   'turva#suunnitelma',
#   'luoda',
#   'myym盲l盲',
#   'turva#suunnitelma',
#   'laatia',
#   'laitos',
#   'turvallisuus#suunnitelma',
#   'spesifikaatio',
#   'turvallisuus#tarve',
#   'est盲盲',
#   'myym盲l盲#varkaus',
#   'turvallisuus#uhka',
#   'syntyminen'],
#  ['antaa',
#   'merkki',
#   'kuuluttaja',
#   'antaa',
#   'merkki',
#   'kuuluttaja',
#   'laulu',
#   'mainos',
#   'loppua',
#   'alkaa',
#   'tiet盲盲',
#   'aloittaa',
#   'lopettaa',
#   'puhuminen'],
#  ['opettaa',
#   'asiakas',
#   'viestint盲',
#   'opettaa',
#   'asiakas',
#   'viestint盲#taito',
#   'antaa',
#   'asiakas',
#   'vinkki',
#   'kommunikoida',
#   'opettaa',
#   'etiketti',
#   'tilanne',
#   'auttaa',
#   'asiakas',
#   'tehostaa',
#   'selkiytt盲盲',
#   'viestint盲',
#   'viestint盲#taito'],
#  ['valvoa',
#   'vedon#ly枚nti#toimisto',
#   'henkil枚#kunta',
#   'tarkkailla',
#   'valvoa',
#   'vedon#ly枚nti#toimisto',
#   'henkil枚#kunta',
#   'aika#tauluttaa',
#   'ty枚#teht盲v盲'],
#  ['valita',
#   'aihe',
#   'valita',
#   'syy',
#   'kiinnostaa',
#   'aihe',
#   'aihe',
#   'julkaisija',
#   'agentti',
#   'm盲盲r盲t盲'],
#  ['johtaa', 'yritys', 'johtaa', 'yritys', 'toiminta'],
#  ['valmistella',
#   'ikkuna#pesu#v盲line',
#   'ikkunan#pesu',
#   'paikka',
#   'k盲ytt盲盲',
#   'pesu#tuote',
#   'v盲line',
#   'tikas',
#   'teline',
#   'turva#k枚ysi',
#   'valmistelu',
#   'varmistaminen'],
#  ['tehd盲',
#   'seuranta',
#   'terveyden#huolto',
#   'asiakas',
#   'hoito',
#   'tarkastella',
#   'arvioida',
#   'm盲盲r盲t盲',
#   'hoito',
#   'edistyminen',
#   'tehd盲',
#   'lis盲#p盲盲t枚s',
#   'terveyden#huolto',
#   'k盲ytt盲j盲',
#   'hoitaja'],
#  ['opettaa',
#   'kirjallisuus',
#   'periaate',
#   'opiskelija',
#   'ohjaaminen',
#   'kirjallisuus',
#   'teoria',
#   'k盲yt盲nt枚',
#   'luku',
#   'kirjoitus#tekniikka',
#   'ety#mologia',
#   'analyysi'],
#  ['valmistella',
#   'soitin',
#   'esitys',
#   'asentaa',
#   'liitt盲盲',
#   'viritt盲盲',
#   'soittaa',
#   'soitin',
#   'soinnin#tarkastus',
#   'harjoitus',
#   'esitys'],
#  ['mikro#talous#tiede',
#   'talous',
#   'ala',
#   'tutkia',
#   'talous',
#   'toimija',
#   'kuluttaja',
#   'yritys',
#   'k盲ytt盲ytyminen',
#   'vuoro#vaikutus',
#   'ala',
#   'analysoida',
#   'yksityis#henkil枚',
#   'p盲盲t枚ksen#teko#menettely',
#   'osto#p盲盲t枚s',
#   'vaikuttaa',
#   'tekij盲'],
#  ['asentaa',
#   'k盲ytt枚#j盲rjestelm盲',
#   'k盲ytt枚#j盲rjestelm盲',
#   'ohjelmisto',
#   'asentaminen',
#   'hallinnoida',
#   'tieto#kone#j盲rjestelm盲',
#   'k盲ytt盲盲',
#   'ohjelmisto',
#   'laitteis#tore#surssi',
#   'k盲ytt枚#j盲rjestelm盲',
#   'osa',
#   'tieto#kone#j盲rjestelm盲',
#   'toimia',
#   'v盲litt盲j盲',
#   'laitteisto',
#   'sovellus#ohjelma',
#   'loppu#k盲ytt盲j盲',
#   'esi#merkki',
#   'tieto#kone',
#   'k盲ytt枚#j盲rjestelm盲'],
#  ['lintu#tiede', 'ornitologia', 'biologia', 'alkaa', 'tutkia', 'lintu'],
#  ['kehitt盲盲',
#   'palvelu',
#   'kehitt盲盲',
#   'toiminto',
#   'kehitt盲盲',
#   'palvelu',
#   'kertoa',
#   'tulos',
#   'johto',
#   'muuntaa',
#   'k盲yt盲nt枚',
#   'toimi',
#   'asiakas#palvelu',
#   'parantaminen',
#   'tunnistaa',
#   'mahdollisuus',
#   'laajentaa',
#   'liike#toiminta'],
#  ['seurata',
#   'ilmailu',
#   'kasvu#trendi',
#   'seurata',
#   'lento#liikenne',
#   'kasvu',
#   'suuntaus',
#   'aika',
#   'pysyminen',
#   'ilmailu',
#   'kasvu#trendi',
#   'innovaatio',
#   'lento#asema',
#   'aika#v盲li',
#   'kehitys#suunnitelma',
#   'ymm盲rt盲minen'],
#  ['k盲ytt盲盲',
#   'muutos#hallinta#taito',
#   'hallita',
#   'organisaatio',
#   'kehitys',
#   'ennakoida',
#   'muutos',
#   'tehd盲',
#   'p盲盲t枚s',
#   'varmistaa',
#   'j盲sen',
#   'toiminta',
#   'h盲iriinty盲'],
#  ['suunnitella',
#   'alus',
#   'auditointi#j盲rjestelm盲',
#   'alus',
#   'auditointi#j盲rjestelm盲',
#   'suunnittelu',
#   'valmistelu',
#   'tarve',
#   'vaatia',
#   'toimen#pide',
#   'arviointi',
#   'toimi',
#   'ryhtyminen',
#   'arviointi',
#   'peruste'],
#  ['kirja',
#   'antaa',
#   'hoito',
#   'pit盲盲',
#   'kirja',
#   'm盲盲r盲t盲',
#   'hoito',
#   'l盲盲kitys',
#   'laatia',
#   'liitty盲',
#   'raportti'],
#  ['k盲sitell盲',
#   'kiista',
#   'k盲sitell盲',
#   'riita',
#   'k盲sitell盲',
#   'yksityis#henkil枚',
#   'organisaatio',
#   'riita',
#   'kyse',
#   'seikka',
#   'kirjan#pito',
#   'verotus'],
#  ['k盲ytt盲盲',
#   'musiikki#terapia',
#   'menetelm盲',
#   'musiikki#terapia',
#   'menetelm盲',
#   'tekniikka',
#   'materiaali',
#   'v盲line',
#   'soveltaminen',
#   'potilas',
#   'hoito#tarve',
#   'tehd盲',
#   'hoito#suunnitelma'],
#  ['k盲ytt盲盲',
#   'kadun#lakaisu#ty枚#kalu',
#   'k盲ytt盲盲',
#   'kadun#lakaisija',
#   'k盲ytt盲盲',
#   's盲盲t盲盲',
#   'laite',
#   'imuri',
#   'harja',
#   'sumutin',
#   'vesi#letku',
#   'poistaa',
#   'lika',
#   'katu'],
#  ['puu#tynnyri',
#   'valmistus',
#   'puu#tynnyri',
#   'valmistaminen',
#   'liitty盲',
#   'prosessi',
#   'materiaali',
#   'valinta',
#   'muotoilu',
#   'l盲mmitt盲minen',
#   'sovittaminen',
#   'h枚yl盲盲minen',
#   'hionta'],
#  ['ennustaa',
#   'energia',
#   'hinta',
#   'energia#markkinat',
#   'tekij盲',
#   'vaikuttaa',
#   'energia#markkinat',
#   'kehitys',
#   'arviointi',
#   'energia',
#   'hy枚ty#kulutus',
#   'hinta',
#   'kehitys',
#   'ennustaminen'],
#  ['l盲盲ke#tiede', 'tauti', 'ehk盲isemis#toimi', 'alue', 'ihminen#ryhm盲'],
#  ['pysy盲',
#   'aika',
#   'innovaatio',
#   'pysy盲',
#   'aika',
#   'innovaatio',
#   'k盲ytt盲盲',
#   'tutkimus',
#   'menetelm盲'],
#  ['tarkastaa',
#   'alus',
#   'tarkastaa',
#   'alus',
#   'toiminta',
#   'varmistaminen',
#   'alus',
#   'varuste',
#   'pit盲minen',
#   's盲盲nn枚s'],
#  ['kehitt盲minen',
#   'kehitt盲minen',
#   'kehitt盲minen',
#   'kehitys',
#   'kehitys',
#   'tarkentava',
#   'kehitys#ty枚',
#   'kehitys#malli',
#   'menetelm盲',
#   'apu',
#   'suunnitella',
#   'ohjelmisto#j盲rjestelm盲',
#   'sovellus'],
#  ['viljell盲', 'humala', 'viljell盲', 'humala', 'olut', 'tuotanto', 'tarkoitus'],
#  ['suunnitella',
#   'valaistus#tila',
#   'valaistus#tila',
#   'suunnittelu',
#   'testaaminen'],
#  ['noudattaa',
#   'tulen#k盲sittely#m盲盲r盲ys',
#   'noudattaa',
#   'sytty盲',
#   'materiaali',
#   'varastointi',
#   'k盲ytt枚',
#   'koskea',
#   'laki',
#   'organisaatio',
#   's盲盲nt枚'],
#  ['raaka#aine',
#   'meri',
#   'laskeminen',
#   'koskea',
#   'm盲盲r盲ys',
#   'raaka#aine',
#   'meri',
#   'laskeminen',
#   'koskea',
#   'ymp盲rist枚#m盲盲r盲ys',
#   'tunteminen',
#   'desinfiointi',
#   'kloorin#poisto',
#   'varmistaminen',
#   'j盲te',
#   'saada',
#   'laskea',
#   'meri'],
#  ['paino#tuote',
#   'asemointi',
#   'paino#tekniikka',
#   'painaa',
#   'sivu',
#   'j盲rjest盲盲',
#   'kuvio',
#   'paino#laatto',
#   'luominen',
#   'suunnitella',
#   'painaa',
#   'materiaali',
#   'taittaa',
#   'tuottaa',
#   'pyyt盲盲',
#   'esite',
#   'kirja',
#   'sivutus',
#   'leikata',
#   'painatus'],
#  ['rakentaa',
#   'ty枚skentely#lava',
#   'rakennus#teline',
#   'rakenne#osa',
#   'kiinnitt盲盲',
#   'ty枚skentely#lava',
#   'l盲hesty盲',
#   'koskettaa',
#   'rakenne',
#   'asettaa',
#   'kansi',
#   'lava',
#   'poistaa',
#   'turva#kaide',
#   'erottaa',
#   'p盲盲#rakennusteline'],
#  ['suorittaa',
#   'lento#asema',
#   'valaistus',
#   'huolto#toimen#pide',
#   'huoltaa',
#   'lento#asema',
#   'valo',
#   'suorittaa',
#   'lento#asema',
#   'valaistus',
#   'huolto#toimen#pide',
#   'yhteys',
#   'poistaa',
#   'osa',
#   'vaihtaa',
#   'osa',
#   'vied盲',
#   'korjaamo',
#   'korjata'],
#  ['tutkia',
#   'kohde#yhteis枚',
#   'sovittaa',
#   'taito',
#   'kohde#yhteis枚',
#   'kohde#yhteis枚',
#   'tutkia'],
#  ['karja#el盲in#laji',
#   'koti#el盲in#laji',
#   'hy枚ty#el盲in#laji',
#   'karja#el盲in#laji',
#   'liitty盲',
#   'genetiikka'],
#  ['ottaa',
#   'esiintymis#tila',
#   'mitta',
#   'esiintymis#tila',
#   'mittaaminen',
#   'tarvita',
#   'valaistus#laite',
#   'm盲盲r盲',
#   'm盲盲ritt盲minen',
#   'p盲盲tt盲minen',
#   'valaistus#laite',
#   'sijoittaa'],
#  ['soveltaa',
#   'tieto',
#   'laatu#prosessi',
#   'tarkistaa',
#   'tieto',
#   'tarkistaa',
#   'tieto',
#   'tarkistaa',
#   'data',
#   'ottaa',
#   'tieto',
#   'laatu#prosessi',
#   'noudattaa',
#   'tieto',
#   'laatu#prosessi',
#   'tarkistaa',
#   'data',
#   'tarkastaa',
#   'tieto',
#   'laatu',
#   'soveltaa',
#   'laatuanalyysi',
#   'validointi',
#   'todentaa#tekniikka'],
#  ['muodostaa',
#   'yhteys',
#   'kulttuuri',
#   'pyrki盲',
#   'ymm盲rt盲盲',
#   'yhteis#kunta',
#   'kulttuuri#koodi',
#   'yritys',
#   'toimia',
#   'luoda',
#   'yhteys',
#   'ymm盲rt盲mys',
#   'j盲sen'],
#  ['huolehtia',
#   'dokumentointi',
#   'laatia',
#   'toimittaa',
#   'asia#kirja',
#   'varmistaa',
#   'tuotanto',
#   'olla',
#   'henkil枚',
#   'saada',
#   'tieto'],
#  ['hallita',
#   'multimodaali#liikenne',
#   'logistiikka',
#   'hallita',
#   'multimodaalilogistiikka',
#   'hallita',
#   'logistiikka',
#   'hallinnoida',
#   'tuote#virta',
#   'kuljetus',
#   'apu'],
#  ['valvoa',
#   'raide#liikenne',
#   'kulku#neuvo',
#   'koskea',
#   'm盲盲r盲ys',
#   'noudattaminen',
#   'liikkua',
#   'kalusto',
#   'osa',
#   'j盲rjestelm盲',
#   'tarkastaminen',
#   'varmistaa',
#   'standardi',
#   'eritelm盲',
#   'noudattaminen'],
#  ['muokata',
#   'esi#mies',
#   'tehd盲',
#   'luonnos',
#   'ty枚st盲盲',
#   'p盲盲llikk枚',
#   'tehd盲',
#   'luonnos',
#   'muokata',
#   'johto',
#   'tehd盲',
#   'luonnos',
#   'kattavuus',
#   'oikeellisuus',
#   'esitys#tapa',
#   'tarkastaminen'],
#  ['valmistella',
#   'alue',
#   'nurmikko',
#   'istuttaminen',
#   'valmistella',
#   'nurmikko#alue',
#   'levitt盲盲',
#   'multa',
#   'istuttaa',
#   'ruoho',
#   'asentaa',
#   'valmis#nurmikko'],
#  ['k盲ytt盲盲',
#   'testaus#laite',
#   'k盲ytt盲盲',
#   'kone',
#   'suoritus#kyky',
#   'toiminta',
#   'testaaminen',
#   'k盲ytt盲盲',
#   'laite'],
#  ['asentaa',
#   'louhinta#kone',
#   'koota',
#   'asentaa',
#   'purkaa',
#   'louhinta#kone',
#   'edellytt盲盲',
#   'silm盲',
#   'k盲si',
#   'yhteis#toiminta',
#   'hahmottaminen'],
#  ['musiikki#teollisuus',
#   'koskea',
#   'lain#s盲盲d盲nt枚',
#   'musiikki',
#   'luominen',
#   'jakelu',
#   'esitt盲minen',
#   'liitty盲',
#   'laki',
#   'asetus'],
#  ['tehd盲',
#   'juusto',
#   'juoksetus#k盲sittely',
#   'tehd盲',
#   'juusto',
#   'juoksetus#k盲sittely',
#   'juusto',
#   'valuttaa',
#   'suolata',
#   'pakata',
#   'leikata',
#   'juustoa',
#   'kuutio',
#   'vesi',
#   'valua',
#   'kuutio',
#   'k盲ytt盲盲',
#   'l盲mp枚',
#   'kuivatus'],
#  ['harjoittaa',
#   'extreme#laji',
#   'harjoittaa',
#   'ekstreemi#laji',
#   'urheilu#laji',
#   'harrastaminen',
#   'vaarallisuus',
#   'taso',
#   'liitty盲',
#   'nopeus',
#   'korkeus',
#   'kuormitus',
#   'erikoistua',
#   'laite'],
#  ['antaa',
#   'ohje',
#   'henkil枚st枚',
#   'neuvo',
#   'henkil枚st枚',
#   'ohjeistaa',
#   'henkil枚#kunta',
#   'ohje',
#   'antaminen',
#   'henkil枚st枚',
#   'viestint盲#tekniikka',
#   'apu',
#   'viestint盲#tyyli',
#   'muokkaaminen',
#   'kohde#yleis枚'],
#  ['kartoittaa',
#   'viko',
#   'juna#rata',
#   'kartoittaa',
#   'toiminta#h盲iri枚',
#   'juna#rata',
#   'tunnistaa',
#   'analysoida',
#   'juna#raide',
#   'laite',
#   'vaurio',
#   'toiminta#h盲iri枚',
#   'm盲盲ritt盲盲',
#   'huolto',
#   'korjaus#ty枚'],
#  ['valmistella',
#   'pinta',
#   'rappaaminen',
#   'valmistella',
#   'sein盲',
#   'pinta',
#   'rappaaminen',
#   'varmistaa',
#   'ett盲#ei',
#   'sein盲',
#   'ep盲#puhtaus',
#   'ei',
#   'kosteus',
#   'ett盲#ei',
#   'est盲盲',
#   'rappaus#materiaali',
#   'kiinnittyminen',
#   'p盲盲tt盲盲',
#   'liimata',
#   'sein盲#pinnoite',
#   'sein盲'],
#  ['s盲teily#annos',
#   'suunnittelu',
#   'suunnittelu',
#   's盲teily#m盲盲r盲',
#   'suunnittelu',
#   'mittaaminen',
#   'terminologia'],
#  ...]

# %%
import gensim

# %%
model_cbow = gensim.models.Word2Vec(documents, min_count=1, size=100, window=3)
# Out:
# C:\Users\dianm\anaconda3\envs\nlp_course\lib\site-packages\gensim\models\word2vec.py:930: UserWarning: C extension not loaded for Word2Vec, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded for Word2Vec, training will be slow. "

# %%
word_1 = 'paketti'
word_2 = 'posti'
print(f"Cosine similarity between '{word_1}' and '{word_2}' - Skip Gram : {model_cbow.similarity('paketti', 'posti')}")

# %%
model_skipgram = gensim.models.Word2Vec(documents, min_count=1, size=100, window=5, sg=1)

# %%
word_1 = 'paketti'
word_2 = 'posti'
print(f"Cosine similarity between '{word_1}' and '{word_2}' - Skip Gram : {model_skipgram.similarity('paketti', 'posti')}")
